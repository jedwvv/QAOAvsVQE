# %%
import qiskit
import numpy as np

# %%
from qiskit import QuantumCircuit, execute, QuantumRegister
from qiskit import Aer
from qiskit.quantum_info import Statevector

# %%
result = execute(qc, backend = Aer.get_backend('qasm_simulator')).result()

# %%
Statevector(qc).probabilities_dict()
# Out:
# {'001001001': 0.03703703703703707,
#  '001001010': 0.03703703703703707,
#  '001001100': 0.03703703703703705,
#  '001010001': 0.03703703703703705,
#  '001010010': 0.03703703703703705,
#  '001010100': 0.03703703703703705,
#  '001100001': 0.03703703703703704,
#  '001100010': 0.03703703703703704,
#  '001100100': 0.03703703703703704,
#  '010001001': 0.03703703703703706,
#  '010001010': 0.03703703703703706,
#  '010001100': 0.03703703703703706,
#  '010010001': 0.03703703703703706,
#  '010010010': 0.03703703703703706,
#  '010010100': 0.03703703703703706,
#  '010100001': 0.03703703703703704,
#  '010100010': 0.03703703703703704,
#  '010100100': 0.03703703703703704,
#  '100001001': 0.03703703703703705,
#  '100001010': 0.03703703703703705,
#  '100001100': 0.03703703703703705,
#  '100010001': 0.03703703703703705,
#  '100010010': 0.03703703703703705,
#  '100010100': 0.03703703703703705,
#  '100100001': 0.03703703703703703,
#  '100100010': 0.03703703703703703,
#  '100100100': 0.03703703703703703}

# %%
qc.draw('mpl')

# %%
R = 3
N = 3

# %%
def construct_initial_state(args):
    """[summary]

    Args:
        args ([type]): [description]

    Returns:
        [type]: [description]
    """
    R = args["no_routes"]
    N = args["no_cars"]
    w_one = QuantumCircuit(R)
    for r in range(0,R-1):
        if r == 0:
            w_one.ry(2*np.arccos(1/np.sqrt(R-r)),r)
        elif r != R-1:
            w_one.cry(2*np.arccos(1/np.sqrt(R-r)), r-1, r)
    for r in range(1,R):
        w_one.cx(R-r-1,R-r)
    w_one.x(0)
    initial_state = w_one.copy()
    for _ in range(0,N-1):
        initial_state = initial_state.tensor(w_one)
    return initial_state

# %%
R = 3
N = 3
initial_state = construct_initial_state({"no_routes":R, "no_cars":N})
initial_state.draw('mpl')

# %%
Statevector(initial_state).probabilities_dict()
# Out:
# {'001001001': 0.03703703703703707,
#  '001001010': 0.03703703703703705,
#  '001001100': 0.03703703703703707,
#  '001010001': 0.03703703703703704,
#  '001010010': 0.03703703703703704,
#  '001010100': 0.03703703703703704,
#  '001100001': 0.03703703703703705,
#  '001100010': 0.03703703703703705,
#  '001100100': 0.03703703703703705,
#  '010001001': 0.03703703703703705,
#  '010001010': 0.03703703703703705,
#  '010001100': 0.03703703703703705,
#  '010010001': 0.03703703703703703,
#  '010010010': 0.03703703703703703,
#  '010010100': 0.03703703703703703,
#  '010100001': 0.03703703703703705,
#  '010100010': 0.03703703703703705,
#  '010100100': 0.03703703703703705,
#  '100001001': 0.03703703703703706,
#  '100001010': 0.03703703703703706,
#  '100001100': 0.03703703703703706,
#  '100010001': 0.03703703703703704,
#  '100010010': 0.03703703703703704,
#  '100010100': 0.03703703703703704,
#  '100100001': 0.03703703703703706,
#  '100100010': 0.03703703703703706,
#  '100100100': 0.03703703703703706}

# %%
qiskit.qiskit.__qiskit_version__
# Out:
# {'qiskit-terra': '0.17.4', 'qiskit-aer': '0.8.2', 'qiskit-ignis': '0.6.0', 'qiskit-ibmq-provider': '0.13.1', 'qiskit-aqua': '0.9.1', 'qiskit': '0.26.2', 'qiskit-nature': None, 'qiskit-finance': None, 'qiskit-optimization': '0.1.0', 'qiskit-machine-learning': None}

# %%
def construct_initial_state(args):
    """[summary]

    Args:
        args ([type]): [description]

    Returns:
        [type]: [description]
    """
    R = args["no_routes"]
    N = args["no_cars"]
    #Using gates
    w_one = QuantumCircuit(R)
    for r in range(0,R-1):
        if r == 0:
            w_one.ry(2*np.arccos(1/np.sqrt(R-r)),r)
        elif r != R-1:
            w_one.cry(2*np.arccos(1/np.sqrt(R-r)), r-1, r)
    for r in range(1,R):
        w_one.cx(R-r-1,R-r)
    w_one.x(0)

    # #Using Initial Instruction
    # w_one = QuantumCircuit(R)
    # probs = [0 for _ in range(2**R)]
    # for i in range(R):
    #     probs[2**i] += 1/np.sqrt(R)
    # w_one.initialize(probs)

    #Tensor product for N cars
    initial_state = w_one.copy()
    for _ in range(0,N-1):
        initial_state = initial_state.tensor(w_one)
    return initial_state, w_one

# %%
args = {"no_routes":3, "no_cars":3}
qc, w_one = construct_initial_state(args)

# %%
# Out:
#      ┌───┐                      ┌─────────────┐
# q_0: ┤ X ├──■────────────■──────┤ RY(-1.9106) ├
#      └───┘┌─┴─┐     ┌────┴─────┐└─────────────┘
# q_1: ─────┤ X ├──■──┤ RY(-π/2) ├───────────────
#           └───┘┌─┴─┐└──────────┘
# q_2: ──────────┤ X ├───────────────────────────
#                └───┘

# %%
from qiskit.opflow import I, Swap, H, X

# %%
mixer_terms = [(I ^ left) ^ X ^ (I ^ (args["no_routes"] - left - 1))
                   for left in range(args["no_routes"])]
mixer = cast(OperatorBase, mixer)
mixer = sum(mixer_terms)

# %%
from typing import cast
from qiskit.opflow import OperatorBase
from qiskit.opflow import CircuitStateFn, EvolutionFactory

# %%
initial_state = QuantumCircuit(3)
initial_state.h(range(3))

# %%
circuit_op = CircuitStateFn(initial_state)

# %%
circuit_op = ((mixer * np.pi/2).exp_i()).compose(circuit_op)

# %%
evolution = EvolutionFactory.build(mixer)
evolution.convert(circuit_op)

# %%
circuit_op

# %%
"""[summary]

Raises:
    TypeError: [description]

Returns:
    [type]: [description]
"""
from sys import float_info
from time import time
import warnings
import argparse
import multiprocessing as mp
import numpy as np
# import osmnx as ox
import pickle as pkl
import matplotlib.pyplot as plt
from qiskit import Aer, QuantumCircuit
from qiskit.algorithms.minimum_eigen_solvers import NumPyMinimumEigensolver
from qiskit.algorithms.optimizers import (
                                        ADAM,
                                        CG,
                                        COBYLA,
                                        L_BFGS_B,
                                        NELDER_MEAD,
                                        NFT,
                                        POWELL,
                                        SLSQP,
                                        SPSA,
                                        TNC,
                                        P_BFGS,
                                        BOBYQA
                                        )
from qiskit_optimization.algorithms import MinimumEigenOptimizer
from qiskit.utils.quantum_instance import QuantumInstance
from qiskit.opflow import I, X, Swap
from qiskit.quantum_info import Statevector
# from qiskit.opflow.primitive_ops import PauliSumOp
# from generate_problem import import_map
from generate_qubo import main as generate_qubo
import QAOAEx


warnings.filterwarnings('ignore')

def main(raw_args = None):
    """[summary]

    Args:
        raw_args ([type], optional): [description]. Defaults to None.
    """
    start = time()
    args = parse(raw_args)
    qubo_prob_s_s = []
    qubo_no = args["no_samples"]
    print("__"*50, "\nQUBO NO: {}\n".format(qubo_no), "__"*50)
    # #Generate and save valid qubos
    # for qubo_no in range(args["no_samples"]):
    #     qubo, max_coeff, operator, offset, routes = generate_valid_qubo(args)
    #     with open('qubos_{}_car_{}_routes/qubo_{}.pkl'.format(args["no_cars"], args["no_routes"], qubo_no), 'wb') as f:
    #         pkl.dump([qubo, max_coeff, operator, offset, routes],f)

    #Load generated qubo_no
    with open('qubos_{}_car_{}_routes/qubo_{}.pkl'.format(args["no_cars"], args["no_routes"], qubo_no), 'rb') as f:
        qubo, max_coeff, operator, offset, routes = pkl.load(f)

    classical_result = solve_classically(qubo)   
    x_arr = classical_result.x
    x_str = arr_to_str(x_arr)
    no_qubits = len(x_arr)

    sort_values = get_costs(qubo, no_qubits)

#         print("_"*50)
#         print("10 lowest states:")
#         avg = 0
#         for i in range(27):
#             print(sort_values[i])
#             avg += sort_values[i][1]
#         print("_"*50)
#         print("Avg: {}".format(avg/27))
    ground_energy = sort_values[0][1]
    x_s = [x_str]
    for i in range(1,10):
        if np.round(sort_values[i][1], 4) == np.round(ground_energy, 4):
            print("Other ground state(s) found: '{}'".format(sort_values[i][0]))
            x_s.append(sort_values[i][0])

    # # Visualise
    # if args["visual"]:
    #     graph = import_map('melbourne.pkl')
    #     visualise_solution(graph, routes)

    #Solve QAOA from QUBO with valid solution
    # print(qubo, operator)
    # no_couplings = count_coupling_terms(operator)
    # print("Number of couplings: {}".format(no_couplings))
    print("Solving with QAOA...")
    no_shots = 10000
    backend = Aer.get_backend('statevector_simulator')
    quantum_instance = QuantumInstance(backend, shots = no_shots)

    #Optimizers available from QISKIT - as chosen from parsed argument.
    optimizers = {"ADAM":ADAM(),
    "CG":CG(),
    "COBYLA":COBYLA(),
    "L_BFGS_B":L_BFGS_B(),
    "NELDER_MEAD":NELDER_MEAD(),
    "NFT":NFT(),
    "POWELL":POWELL(),
    "SLSQP":SLSQP(),
    "SPSA":SPSA(),
    "TNC":TNC(),
    "P_BFGS": P_BFGS(),
    "BOBYQA": BOBYQA()}
    optimizer = optimizers[args["optimizer"]]
    # print("_"*50,"\n"+optimizer.__class__.__name__)
    # print("_"*50)

    quantum_instance = QuantumInstance(backend)

    # for p in range(1, args["p_max"]+1):
        # print("p = {}".format(p))
    prob_s_s = []
    P = 1
    p=1
    print("p=1")
    points = [[0,0]] + [[ 1.99*np.pi*np.random.rand() - np.pi for _ in range(2) ] for _ in range(args["no_restarts"])]
    r = 0
    qc, w_one = construct_initial_state(args)
#         qc = None

#         mixer_terms = [(I ^ left) ^ X ^ (I ^ (args["no_routes"]*args["no_cars"] - left - 1))
#                            for left in range(args["no_routes"]*args["no_cars"])]
#         mixer = sum(mixer_terms)
    mixer = n_qbit_mixer(args["no_routes"]*args["no_cars"])
#     mixer = None
#     mixer = mixer_one.copy()
#     for _ in range(0,args["no_cars"]-1):
#         mixer = mixer.tensor(mixer_one)
#     print(mixer.draw(fold=200))
    exp_vals = []
    results = []
    prob_s_2 = []
    for point in points:
        r+=1
        qaoa_results, _, qc = Fourier_QAOA(operator, quantum_instance, optimizer, p, point, initial_state = qc, mixer = mixer)
        results.append((qaoa_results, qc))
        exp_val = qaoa_results.eigenvalue*max_coeff + offset
        exp_vals.append(exp_val)
        prob_s = 0
        for string in x_s:
            prob_s += qaoa_results.eigenstate[string] if string in qaoa_results.eigenstate else 0
        print("Restart_no: {}, Exp_val: {}, Prob_s: {}".format(r, exp_val, prob_s))
        prob_s_2.append(prob_s)
    minim_index = np.argmin(exp_vals)
    optimal_qaoa_result, qc = results[minim_index]
    print(qc.draw(fold = 200))
    minim_exp_val = exp_vals[minim_index]
    optimal_prob_s = prob_s_2[minim_index]
    print("Minimum: {}, prob_s: {}".format(minim_exp_val, optimal_prob_s))
    prob_s_s.append(optimal_prob_s)
    minim_exp_val_B = minim_exp_val
    optimal_fourier_point = np.array(optimal_qaoa_result.optimal_point)
    optimal_fourier_point_B = optimal_fourier_point.copy()

    for p in range(2, args["p_max"]+1):
        print("p={}".format(p))
        # if args["optimizer"] == 'SLSQP':
        #     optimizer.set_options(maxiter = )
        # elif args["optimizer"] == 'L_BFGS_B' or 'P_BFGS':
        #     optimizer.set_options(maxfun = 1000*p)
        # print("Optimizer options: {}".format(optimizer.setting))
        next_fourier_point = QAOAEx.convert_from_fourier_point(optimal_fourier_point, 2*p)
        next_fourier_point_B = QAOAEx.convert_from_fourier_point(optimal_fourier_point_B, 2*p)
#         next_fourier_point = interp_point(next_fourier_point)
#         next_fourier_point_B = interp_point(next_fourier_point_B)
        next_fourier_point = QAOAEx.convert_to_fourier_point(next_fourier_point, 2*p)
        next_fourier_point_B = QAOAEx.convert_to_fourier_point(next_fourier_point_B, 2*p)

        # next_fourier_point[0:p-1] = optimal_fourier_point[0:p-1]
        # next_fourier_point[p:2*p-1] = optimal_fourier_point[p-1:2*p-2]

        # next_fourier_point_B[0:p-1] = optimal_fourier_point_B[0:p-1]
        # next_fourier_point_B[p:2*p-1] = optimal_fourier_point_B[p-1:2*p-2]

        qaoa_results, _, _ = Fourier_QAOA(operator, quantum_instance, optimizer, p, next_fourier_point, qc, mixer = mixer)
        optimal_fourier_point = np.array(qaoa_results.optimal_point)
        minim_exp_val = qaoa_results.eigenvalue*max_coeff + offset
        # print("Length_L:",len(optimal_fourier_point))
        optimal_prob_s = 0
        for string in x_s:
            optimal_prob_s += qaoa_results.eigenstate[string] if string in qaoa_results.eigenstate else 0
        print("Minim_exp_val_L: {}, prob_s_L: {}".format(minim_exp_val, optimal_prob_s))
        optimal_prob_s_B = optimal_prob_s
        t1 = time()
        t = 0
        results = []
        exp_vals = []
        while True:
            t+=1
            penalty = 1.2
            perturbed_points = generate_points(next_fourier_point_B, 10, penalty)
            for point in perturbed_points:
                qaoa_results_B, _, _ = Fourier_QAOA(operator, quantum_instance, optimizer, p, point, qc, mixer = mixer)
                exp_val = qaoa_results_B.eigenvalue*max_coeff + offset
                results.append(qaoa_results_B)
                exp_vals.append(exp_val)
            exp_val_index = np.argmin(exp_vals)
            minim_exp_val_B_2 = exp_vals[exp_val_index]
            qaoa_results_B_2 = results[exp_val_index]
            optimal_fourier_point_B_2 = np.array(qaoa_results_B_2.optimal_point)
            optimal_prob_s_B_2 = 0
            for string in x_s:
                optimal_prob_s_B_2 += qaoa_results_B_2.eigenstate[string] if string in qaoa_results_B_2.eigenstate else 0
            print("Comparison (t={}): B_next: {}, B_before: {}".format(t, minim_exp_val_B_2, minim_exp_val_B))
            if minim_exp_val_B_2 < minim_exp_val_B or t>=2 and minim_exp_val_B_2 == minim_exp_val_B or t==4:
                minim_exp_val_B = minim_exp_val_B_2
                optimal_prob_s_B = optimal_prob_s_B_2
                optimal_fourier_point_B = optimal_fourier_point_B_2
                # print("\a")
                break
            else:
                penalty *= 1.2 if t <= 4 else 1
        if minim_exp_val_B >= minim_exp_val:
            optimal_fourier_point_B = optimal_fourier_point.copy()
        t2 = time()
        print("Time for intialising with perturbed values {} no. of times: {}".format(t, t2-t1))
        print("Minim_exp_val_B: {}, prob_s_B: {}".format(minim_exp_val_B, optimal_prob_s_B))
        if minim_exp_val <= minim_exp_val_B:
            prob_s_s.append(optimal_prob_s)
        else:
            prob_s_s.append(optimal_prob_s_B)
        print("Length_B:", len(optimal_fourier_point_B))
        print("Optimal_L:", QAOAEx.convert_from_fourier_point(optimal_fourier_point, len(optimal_fourier_point)))
        point_B = QAOAEx.convert_from_fourier_point(optimal_fourier_point_B, len(optimal_fourier_point_B))
        print("Optimal_B: {}, length: {}".format(point_B, len(point_B)))

    print(prob_s_s)

    with open('results/{}cars{}routes_qubo{}_{}.csv'.format(args["no_cars"], args["no_routes"], args["no_samples"], args["optimizer"]), 'w') as f:
        np.savetxt(f, prob_s_s, delimiter=',')
    finish = time()
    print("Time Taken: {}".format(finish - start))


def Fourier_QAOA(operator, quantum_instance, optimizer, p, initial_fourier_point, initial_state=None, mixer = None, qubo = None):
    qaoa_instance = QAOAEx.QAOACustom(quantum_instance = quantum_instance,
                                        reps = p,
                                        force_shots = False,
                                        optimizer = optimizer,
                                        qaoa_name = "example_qaoa",
                                        initial_state = initial_state,
                                        mixer = mixer,
                                        include_custom = False,
                                        max_evals_grouped = 2
                                        )
    # qaoa_instance.set_parameterise_point_for_energy_evaluation(QAOAEx.convert_from_fourier_point)
#     bounds = [(-np.pi, np.pi)]*len(initial_fourier_point)
    qaoa_results = qaoa_instance.solve(operator, initial_fourier_point)
    optimal_parameterised_point = qaoa_instance.latest_parameterised_point
    if not isinstance(qaoa_results.eigenstate, dict):
        qaoa_results.eigenstate = Statevector(qaoa_results.eigenstate).probabilities_dict()
    qc = qaoa_instance.get_optimal_circuit()
#     print(qaoa_results.eigenstate)
    # qc.draw(output = 'mpl', scale = 0.5, fold = 30*p)
    # plt.show()
    return qaoa_results, optimal_parameterised_point, qc

def generate_points(point, no_perturb, penalty):
    points = [point.copy() for _ in range(no_perturb+1)]
    for r in range(1,no_perturb+1):
        for i in range(len(point)):
            if point[i] == 0:
                noise = np.random.choice([-0.05*np.pi, 0, 0.05*np.pi])
                points[r][i] += penalty*noise
            else:
                noise = np.random.normal(0, point[i]**2)
                points[r][i] += penalty*noise
    return points

def parse(raw_args):
    """Parse inputs for no_cars (number of cars),
                        no_routes (number of routes)

    Args:
        raw_args (list): list of strings describing the inputs e.g. ["-N 3", "-R 3"]

    Returns:
        dict: A dictionary of the inputs as values, and the name of variables as the keys
    """
    optimizer_choices = ["ADAM", "CG", "COBYLA", "L_BFGS_B",\
                        "NELDER_MEAD", "NFT", "POWELL",\
                         "SLSQP", "SPSA", "TNC", "P_BFGS", "BOBYQA"]
    parser = argparse.ArgumentParser()
    required_named = parser.add_argument_group('Required arguments')
    required_named.add_argument("--no_cars", "-N",
                                required = True,
                                help="Set the number of cars",
                                type = int
                                )
    required_named.add_argument("--no_routes", "-R",
                                required = True,
                                help="Set the number of routes for each car",
                                type = int
                                )
    required_named.add_argument("--penalty_multiplier", "-P",
                                required = True,
                                help="Set the penalty multiplier for QUBO constraint",
                                type = float
                                )
    required_named.add_argument("--optimizer", "-O",
                                required = True,
                                help = "Choose from Qiskit's optimizers",
                                type = str,
                                choices=optimizer_choices
                                )
    required_named.add_argument("--p_max", "-M",
                                required = True,
                                help = "Set maximum number of layers for QAOA",
                                type = int
                                )
    required_named.add_argument("--no_restarts", "-T", required = True,
                                help = "Set number of restarts for QAOA",
                                type = int
                                )
    required_named.add_argument("--no_samples", "-S", required = True,
                                help = "Set number of samples/qubos with given no_cars no_routes",
                                type=int
                                )
    parser.add_argument("--visual",
                        "-V", default = False,
                        help="Activate routes visualisation with '-V' ",
                        action="store_true"
                        )
    args = parser.parse_args(raw_args)
    args = vars(args)
    return args

def solve_classically(qubo):
    """[summary]

    Args:
        qubo ([type]): [description]

    Returns:
        [type]: [description]
    """
    exact_mes = NumPyMinimumEigensolver()
    exact = MinimumEigenOptimizer(exact_mes)
    exact_result = exact.solve(qubo)
    print(exact_result)
    return exact_result

def arr_to_str(x_arr):
    """[summary]

    Args:
        x_arr ([type]): [description]

    Returns:
        [type]: [description]
    """
    x_arr = x_arr[::-1]
    string = ''.join(str(int(x_i)) for x_i in x_arr)
    return string

def filter_solutions(results, qaoa_dict, no_cars):
    """[summary]

    Args:
        results ([type]): [description]
        qaoa_dict ([type]): [description]
        no_cars ([type]): [description]

    Returns:
        [type]: [description]
    """
    routes = []
    variables = []
    for var_route, var_value in zip( results.items(), qaoa_dict.items() ):
        if var_route[0] == var_value[0] and int(var_value[1]) == 1 \
            and var_route[0] not in variables:
            routes.append(var_route[1])
            variables.append(var_route[0])
        elif var_route[0] != var_value[0]:
            print("Error, function returned non-matching variables")
            return None
        elif var_route[0] in variables:
            print("Error: Solution found two routes for one car")
            return None
    if len(variables) != no_cars:
        print("Error: At least one car did not have a valid route")
        return None
    return routes

def eval_cost(x_str_arr, qubo_problem, no_qubits):
    """[summary]

    Args:
        x ([type]): [description]
        qubo_problem ([type]): [description]
        no_qubits ([type]): [description]
        max_coeff ([type]): [description]
        offset ([type]): [description]

    Returns:
        [type]: [description]
    """
    if isinstance(x_str_arr, np.ndarray):
        cost = qubo_problem.objective.evaluate([int(x_str_arr[i]) for i in range(no_qubits)])
    else:
        cost = qubo_problem.objective.evaluate([int(x_str_arr[no_qubits-1-i]) \
                                                for i in range(no_qubits)]
                                            )
    return x_str_arr, cost

# def visualise_solution(graph, routes):
#     """[summary]

#     Args:ca
#         graph ([type]): [description]
#         routes ([type]): [description]

#     Returns:
#         [type]: [description]
#     """
#     colors = np.array(["r", "y", "b", "g", "w"]*10)[0:len(routes)]
#     fig, axes = ox.plot_graph_routes(graph,
#                                     routes,
#                                     route_colors=colors,
#                                     route_linewidth=4,
#                                     node_size=10
#                                     )
#     return fig, axes

def get_costs(qubo, no_qubits):
    """[summary]

    Args:
        qubo ([type]): [description]
        no_qubits ([type]): [description]

    Returns:
        [type]: [description]
    """
    # values = ['{}'.format()]
    cpus = mp.cpu_count()
    pool = mp.Pool(cpus-1)
    params = ( ('0'*(no_qubits-len('{0:b}'.format(k)))+'{0:b}'.format(k),
            qubo,
            no_qubits
            ) for k in range(2**no_qubits))
    values = pool.starmap(eval_cost, params)
    values = dict(values)
    pool.close()
    pool.join()
    sort_values = sorted(values.items(), key=lambda x: x[1])
    return sort_values

def check_solutions(routes):
    """[summary]

    Args:
        routes ([type]): [description]

    Raises:
        TypeError: [description]
    """
    try:
        len(routes)
        print("This is a valid solution")
    except TypeError as typ:
        raise TypeError("This is not a valid solution") from typ

def count_coupling_terms(operator):
    """[summary]

    Args:
        operator ([type]): [description]
    """
    count = 0
    for op_i in operator.to_pauli_op().oplist:
        op_str = str(op_i.primitive)
        if op_str.count('Z') == 2:
            count += 1
    return count

def generate_valid_qubo(args):
    while True: #Generate valid QUBO
        try:
            #Generate a QUBO
            if args["visual"] is True:
                qubo, max_coeff, operator, offset, _, _, results = \
                    generate_qubo( [
                                    "-N "+str(args["no_cars"]),
                                    "-R "+str(args["no_routes"]),
                                    "-P "+str(args["penalty_multiplier"]),
                                    "-V"
                                    ]
                                )
            else:
                qubo, max_coeff, operator, offset, _, _, results = \
                    generate_qubo( [
                                    "-N "+str(args["no_cars"]),
                                    "-R "+str(args["no_routes"]),
                                    "-P "+str(args["penalty_multiplier"])
                                    ]
                                )
            #Classically solve generated QUBO
            classical_result = solve_classically(qubo)

            #Check solution
            variables_dict = classical_result.variables_dict
            routes = filter_solutions(results, variables_dict, args["no_cars"])
            check_solutions(routes)

            #If valid solution, save the solution.
            x_arr = classical_result.x
            x_str = arr_to_str(x_arr)

            break #break loop if valid solution, else increase penalty.

        except TypeError:
            #QUBO has invalid solution, start again with increased penalty.
            print("Starting with new qubo")
            args["penalty_multiplier"] += 0.05
    return qubo, max_coeff, operator, offset, routes

def interp_point(optimal_point):
    """Method to interpolate to next point from the optimal point found from the previous layer   
    
    Args:
        optimal_point (np.array): Optimal point from previous layer
    
    Returns:
        point (list): the informed next point
    """
    optimal_point = list(optimal_point)
    p = int(len(optimal_point)/2)
    gammas = [0]+optimal_point[0:p]+[0]
    betas = [0]+optimal_point[p:2*p]+[0]
    interp_gammas = [0]+gammas
    interp_betas = [0]+betas    
    for i in range(1,p+2):
        interp_gammas[i] = gammas[i-1]*(i-1)/p+gammas[i]*(p+1-i)/p
        interp_betas[i] = betas[i-1]*(i-1)/p+betas[i]*(p+1-i)/p    
    
    point = interp_gammas[1:p+2] + interp_betas[1:p+2]

    return point

def construct_initial_state(args):
    """[summary]

    Args:
        args ([type]): [description]

    Returns:
        [type]: [description]
    """
    R = args["no_routes"]
    N = args["no_cars"]
    #Using gates
    w_one = QuantumCircuit(R)
    for r in range(0,R-1):
        if r == 0:
            w_one.ry(2*np.arccos(1/np.sqrt(R-r)),r)
        elif r != R-1:
            w_one.cry(2*np.arccos(1/np.sqrt(R-r)), r-1, r)
    for r in range(1,R):
        w_one.cx(R-r-1,R-r)
    w_one.x(0)

    # #Using Initial Instruction
    # w_one = QuantumCircuit(R)
    # probs = [0 for _ in range(2**R)]
    # for i in range(R):
    #     probs[2**i] += 1/np.sqrt(R)
    # w_one.initialize(probs)

    #Tensor product for N cars
    initial_state = w_one.copy()
    for _ in range(0,N-1):
        initial_state = initial_state.tensor(w_one)
    return initial_state, w_one

# def n_qbit_mixer(n):
# #     from qiskit.circuit.parameter import Parameter
# #     from qiskit.circuit.parametervector import ParameterVector
    
# #     t = Parameter('t')
# #     qc = QuantumCircuit(n)
    
# #     for r in range(n-1):
# #         qc.cx(r,r+1)
# #         qc.crx(2*t, r+1, r)
# #         qc.cx(r,r+1)
    
# #     qc.cx(0,n-1)
# #     qc.crx(2*t, n-1, 0)
# #     qc.cx(0,n-1)
    
# #     #Using classical mixer
# #     qc.rx(2*t, range(n))
#     paulis = []
#     for (i,j) in comb(list(range(n)),2):
#         X_iX_j = (I^(n-j-1))^X^(I^(j-i-1))^X^(I^i)
#         paulis.append(X_iX_j)
#         Y_iY_j = (I^(n-j-1))^Y^(I^(j-i-1))^Y^(I^i)
#         paulis.append(Y_iY_j)
#     mixer = sum(paulis)
    
#     return mixer

def n_qbit_mixer(n):
    from qiskit.circuit.parameter import Parameter
#     from qiskit.circuit.parametervector import ParameterVector
    
    t = Parameter('t')
    qc = QuantumCircuit(n)
    qc_two = QuantumCircuit(2)
    qc_two.sdg(1)
    qc_two.cx(1,0)
    qc_two.ry(-2*t,1)
    qc_two.cx(0,1)
    qc_two.ry(2*t,1)
    qc_two.cx(1,0)
    qc_two.s(0)
    if n%2:
        for i in range(int((n-1)/2)):
            qc.append(qc_two,(2*i,2*i+1))
            qc.swap(2*i,2*i+1)
        for i in range(int((n-1)/2)):
            qc.append(qc_two,(2*i+1,2*i+2))
            qc.swap(2*i+1,2*i+2)
        for i in range(int((n-1)/2)):
            qc.append(qc_two,(2*i,2*i+1))
            qc.swap(2*i,2*i+1)
        for i in range(int((n-1)/2)):
            qc.append(qc_two,(2*i+1,2*i+2))
    else:
        for i in range(int((n)/2)):
            qc.append(qc_two,(2*i,2*i+1))
            qc.swap(2*i,2*i+1)
        for i in range(1,int((n)/2)):
            qc.append(qc_two,(2*i-1,2*i))
            qc.swap(2*i-1,2*i)
        for i in range(int((n)/2)):
            qc.append(qc_two,(2*i,2*i+1))
            qc.swap(2*i,2*i+1)
        for i in range(1,int((n)/2)):
            qc.append(qc_two,(2*i-1,2*i))
    
    return qc

# main()
# main(["-N 3", "-R 3", "-P 1.5", "-OSLSQP", "-M 10", "-T 2", "-S 1"])


# operator, offset = quadratic_program.to_ising()

# initial_point = [0.40784, 0.73974, -0.53411, -0.28296]
# print()
# print("Solving QAOA...")
# qaoa_results = qaoa_instance.solve(operator, initial_point)

# qaoa_results_eigenstate = qaoa_results.eigenstate
# print("optimal_value:", qaoa_results.optimal_value)
# print("optimal_parameters:", qaoa_results.optimal_parameters)
# print("optimal_point:", qaoa_results.optimal_point)
# print("optimizer_evals:", qaoa_results.optimizer_evals)

# solutions = qaoa_instance.get_optimal_solutions_from_statevector(qaoa_results_eigenstate, quadratic_program)
# print_qaoa_solutions(solutions)

# %%
main(["-N 3", "-R 3", "-P 1.5", "-OSLSQP", "-M 5", "-T 3", "-S 3"])
# Out:
# ____________________________________________________________________________________________________
# QUBO NO: 3
#  ____________________________________________________________________________________________________
# optimal function value: 3.960833000000001
# optimal value: [0. 1. 0. 1. 0. 0. 1. 0. 0.]
# status: SUCCESS
# Other ground state(s) found: '001010001'
# Solving with QAOA...
# p=1
# Restart_no: 1, Exp_val: 8.642262199999994, Prob_s: 0
# Restart_no: 2, Exp_val: 4.724383379219795, Prob_s: 0.07418685726318561
# Restart_no: 3, Exp_val: 7.220924795373271, Prob_s: 0.00567277157225262
# Restart_no: 4, Exp_val: 5.985368585296172, Prob_s: 0.06886752963056514
#      ┌────────────┐                     ┌───┐┌───┐┌───────┐┌───┐┌───┐┌───────┐┌───┐┌───┐┌───────┐         ┌───┐     ┌───┐┌───────┐         ┌───┐     ┌───┐┌───────┐                  ┌───┐          »
# q_0: ┤ RY(1.9106) ├─────■────────────■──┤ X ├┤ X ├┤ RZ(0) ├┤ X ├┤ X ├┤ RZ(0) ├┤ X ├┤ X ├┤ RZ(0) ├─────────┤ X ├─────┤ X ├┤ RZ(0) ├─────────┤ X ├─────┤ X ├┤ RZ(0) ├──────────────────┤ X ├──────────»
#      └────────────┘┌────┴────┐     ┌─┴─┐└───┘└─┬─┘└───────┘└─┬─┘└─┬─┘└───────┘└─┬─┘└─┬─┘└─┬───┬─┘┌───────┐└─┬─┘┌───┐└─┬─┘└─┬───┬─┘┌───────┐└─┬─┘┌───┐└─┬─┘└─┬───┬─┘┌───────┐         └─┬─┘┌───┐     »
# q_1: ──────────────┤ RY(π/2) ├──■──┤ X ├───────■─────────────■────┼─────────────┼────┼────┤ X ├──┤ RZ(0) ├──┼──┤ X ├──┼────┤ X ├──┤ RZ(0) ├──┼──┤ X ├──┼────┤ X ├──┤ RZ(0) ├───────────┼──┤ X ├─────»
#                    └─────────┘┌─┴─┐└───┘                          │             │    │    └─┬─┘  └───────┘  │  └─┬─┘  │    └─┬─┘  └───────┘  │  └─┬─┘  │    └─┬─┘  └─┬───┬─┘┌───────┐  │  └─┬─┘┌───┐»
# q_2: ─────────────────────────┤ X ├───────────────────────────────■─────────────■────┼──────■───────────────┼────■────┼──────┼───────────────┼────┼────┼──────┼──────┤ X ├──┤ RZ(0) ├──┼────┼──┤ X ├»
#      ┌────────────┐           └───┘     ┌───┐                                        │                      │         │      │               │    │    │      │      └─┬─┘  └───────┘  │    │  └─┬─┘»
# q_3: ┤ RY(1.9106) ├─────■────────────■──┤ X ├────────────────────────────────────────■──────────────────────■─────────┼──────■───────────────┼────■────┼──────┼────────■───────────────┼────┼────■──»
#      └────────────┘┌────┴────┐     ┌─┴─┐└───┘                                                                         │                      │         │      │                        │    │       »
# q_4: ──────────────┤ RY(π/2) ├──■──┤ X ├──────────────────────────────────────────────────────────────────────────────■──────────────────────■─────────┼──────■────────────────────────┼────■───────»
#                    └─────────┘┌─┴─┐└───┘                                                                                                               │                               │            »
# q_5: ─────────────────────────┤ X ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────■───────────────────────────────■────────────»
#      ┌────────────┐           └───┘     ┌───┐                                                                                                                                                       »
# q_6: ┤ RY(1.9106) ├─────■────────────■──┤ X ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
#      └────────────┘┌────┴────┐     ┌─┴─┐└───┘                                                                                                                                                       »
# q_7: ──────────────┤ RY(π/2) ├──■──┤ X ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
#                    └─────────┘┌─┴─┐└───┘                                                                                                                                                            »
# q_8: ─────────────────────────┤ X ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
#                               └───┘                                                                                                                                                                 »
# «     ┌───┐┌───────┐                  ┌───┐          ┌───┐┌───────┐                           ┌───┐               ┌───┐┌───────┐                           ┌───┐┌───────┐                        »
# «q_0: ┤ X ├┤ RZ(0) ├──────────────────┤ X ├──────────┤ X ├┤ RZ(0) ├───────────────────────────┤ X ├───────────────┤ X ├┤ RZ(0) ├───────────────────────────┤ X ├┤ RZ(0) ├────────────────────────»
# «     └─┬─┘└─┬───┬─┘┌───────┐         └─┬─┘┌───┐     └─┬─┘└─┬───┬─┘┌───────┐                  └─┬─┘┌───┐          └─┬─┘└─┬───┬─┘┌───────┐                  └─┬─┘└─┬───┬─┘          ┌───┐┌───────┐»
# «q_1: ──┼────┤ X ├──┤ RZ(0) ├───────────┼──┤ X ├───────┼────┤ X ├──┤ RZ(0) ├────────────────────┼──┤ X ├────────────┼────┤ X ├──┤ RZ(0) ├────────────────────┼────┤ X ├────────────┤ X ├┤ RZ(0) ├»
# «       │    └─┬─┘  └─┬───┬─┘┌───────┐  │  └─┬─┘┌───┐  │    └─┬─┘  └─┬───┬─┘┌───────┐           │  └─┬─┘┌───┐       │    └─┬─┘  └─┬───┬─┘┌───────┐           │    └─┬─┘  ┌───┐     └─┬─┘└─┬───┬─┘»
# «q_2: ──┼──────┼──────┤ X ├──┤ RZ(0) ├──┼────┼──┤ X ├──┼──────┼──────┤ X ├──┤ RZ(0) ├───────────┼────┼──┤ X ├───────┼──────┼──────┤ X ├──┤ RZ(0) ├───────────┼──────┼────┤ X ├───────┼────┤ X ├──»
# «       │      │      └─┬─┘  └───────┘  │    │  └─┬─┘  │      │      └─┬─┘  └─┬───┬─┘┌───────┐  │    │  └─┬─┘┌───┐  │      │      └─┬─┘  └─┬───┬─┘┌───────┐  │      │    └─┬─┘┌───┐  │    └─┬─┘  »
# «q_3: ──┼──────┼────────┼───────────────┼────┼────┼────┼──────┼────────┼──────┤ X ├──┤ RZ(0) ├──┼────┼────┼──┤ X ├──┼──────┼────────┼──────┤ X ├──┤ RZ(0) ├──┼──────┼──────┼──┤ X ├──┼──────┼────»
# «       │      │        │               │    │    │    │      │        │      └─┬─┘  └───────┘  │    │    │  └─┬─┘  │      │        │      └─┬─┘  └───────┘  │      │      │  └─┬─┘  │      │    »
# «q_4: ──┼──────┼────────■───────────────┼────┼────■────┼──────┼────────┼────────■───────────────┼────┼────┼────■────┼──────┼────────┼────────┼───────────────┼──────┼──────┼────┼────┼──────┼────»
# «       │      │                        │    │         │      │        │                        │    │    │         │      │        │        │               │      │      │    │    │      │    »
# «q_5: ──┼──────■────────────────────────┼────■─────────┼──────┼────────■────────────────────────┼────┼────■─────────┼──────┼────────┼────────■───────────────┼──────┼──────┼────■────┼──────┼────»
# «       │                               │              │      │                                 │    │              │      │        │                        │      │      │         │      │    »
# «q_6: ──■───────────────────────────────■──────────────┼──────■─────────────────────────────────┼────■──────────────┼──────┼────────■────────────────────────┼──────┼──────■─────────┼──────┼────»
# «                                                      │                                        │                   │      │                                 │      │                │      │    »
# «q_7: ─────────────────────────────────────────────────■────────────────────────────────────────■───────────────────┼──────■─────────────────────────────────┼──────■────────────────┼──────■────»
# «                                                                                                                   │                                        │                       │           »
# «q_8: ──────────────────────────────────────────────────────────────────────────────────────────────────────────────■────────────────────────────────────────■───────────────────────■───────────»
# «                                                                                                                                                                                                »
# «                                              ┌───────────────────────┐                                                                                                                               »
# «q_0: ─────────────────────────────────────────┤0                      ├──X────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                                ┌───┐┌───────┐│  circuit-8884151(0.0) │  │                                                                                                                            »
# «q_1: ───────────────────────────┤ X ├┤ RZ(0) ├┤1                      ├──X────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «     ┌───────┐                  └─┬─┘└─┬───┬─┘└───────────────────────┘     ┌───┐┌───────┐                  ┌───┐┌───────┐                                                   ┌───────────────────────┐»
# «q_2: ┤ RZ(0) ├────────────────────┼────┤ X ├────────────────────────────────┤ X ├┤ RZ(0) ├──────────────────┤ X ├┤ RZ(0) ├───────────────────────────────────────────────────┤0                      ├»
# «     └─┬───┬─┘┌───────┐           │    └─┬─┘            ┌───┐               └─┬─┘└─┬───┬─┘┌───────┐         └─┬─┘└─┬───┬─┘     ┌───┐┌───────┐                  ┌───┐┌───────┐│  circuit-8884151(0.0) │»
# «q_3: ──┤ X ├──┤ RZ(0) ├───────────┼──────┼──────────────┤ X ├─────────────────┼────┤ X ├──┤ RZ(0) ├───────────┼────┤ X ├───────┤ X ├┤ RZ(0) ├──────────────────┤ X ├┤ RZ(0) ├┤1                      ├»
# «       └─┬─┘  └─┬───┬─┘┌───────┐  │      │              └─┬─┘          ┌───┐  │    └─┬─┘  └─┬───┬─┘┌───────┐  │    └─┬─┘  ┌───┐└─┬─┘└─┬───┬─┘┌───────┐         └─┬─┘└─┬───┬─┘└───────────────────────┘»
# «q_4: ────┼──────┤ X ├──┤ RZ(0) ├──┼──────┼────────────────┼────────────┤ X ├──┼──────┼──────┤ X ├──┤ RZ(0) ├──┼──────┼────┤ X ├──┼────┤ X ├──┤ RZ(0) ├───────────┼────┤ X ├───────────────────────────»
# «         │      └─┬─┘  └───────┘  │      │                │            └─┬─┘  │      │      └─┬─┘  └───────┘  │      │    └─┬─┘  │    └─┬─┘  └─┬───┬─┘┌───────┐  │    └─┬─┘            ┌───┐          »
# «q_5: ────┼────────■───────────────┼──────┼────────────────┼──────────────■────┼──────┼────────┼───────────────┼──────┼──────┼────┼──────┼──────┤ X ├──┤ RZ(0) ├──┼──────┼──────────────┤ X ├──────────»
# «         │                        │      │                │                   │      │        │               │      │      │    │      │      └─┬─┘  └───────┘  │      │              └─┬─┘          »
# «q_6: ────■────────────────────────┼──────┼────────────────■───────────────────┼──────┼────────■───────────────┼──────┼──────■────┼──────┼────────■───────────────┼──────┼────────────────■────────────»
# «                                  │      │                                    │      │                        │      │           │      │                        │      │                             »
# «q_7: ─────────────────────────────┼──────■────────────────────────────────────┼──────■────────────────────────┼──────■───────────┼──────■────────────────────────┼──────■─────────────────────────────»
# «                                  │                                           │                               │                  │                               │                                    »
# «q_8: ─────────────────────────────■───────────────────────────────────────────■───────────────────────────────■──────────────────■───────────────────────────────■────────────────────────────────────»
# «                                                                                                                                                                                                      »
# «                                            ┌───────────────────────┐                                                                                                                  »
# «q_0: ───────────────────────────────────────┤0                      ├────X─────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «          ┌───────────────────────┐         │  circuit-8884151(0.0) │    │                                                                                                             »
# «q_1: ─────┤0                      ├────X────┤1                      ├────X─────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «          │  circuit-8884151(0.0) │    │    └───────────────────────┘                                                                                                                  »
# «q_2: ──X──┤1                      ├────X───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «       │  └───────────────────────┘                                                                                                                  ┌───────────────────────┐         »
# «q_3: ──X─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤0                      ├────X────»
# «     ┌───┐        ┌───────┐                           ┌───┐          ┌───────┐                                     ┌───────────────────────┐         │  circuit-8884151(0.0) │    │    »
# «q_4: ┤ X ├────────┤ RZ(0) ├───────────────────────────┤ X ├──────────┤ RZ(0) ├─────────────────────────────────────┤0                      ├────X────┤1                      ├────X────»
# «     └─┬─┘        └─┬───┬─┘        ┌───────┐          └─┬─┘          └─┬───┬─┘┌───┐┌───────┐         ┌───┐┌───────┐│  circuit-8884151(0.0) │    │    └───────────────────────┘         »
# «q_5: ──┼────────────┤ X ├──────────┤ RZ(0) ├────────────┼──────────────┤ X ├──┤ X ├┤ RZ(0) ├─────────┤ X ├┤ RZ(0) ├┤1                      ├────X──────────────────────────────────────»
# «       │            └─┬─┘          └───────┘            │              └─┬─┘  └─┬─┘└─┬───┬─┘┌───────┐└─┬─┘└─┬───┬─┘└─────────┬───┬─────────┘┌───────┐          ┌───┐          ┌───────┐»
# «q_6: ──┼──────────────┼─────────────────────────────────┼────────────────┼──────┼────┤ X ├──┤ RZ(0) ├──┼────┤ X ├────────────┤ X ├──────────┤ RZ(0) ├──────────┤ X ├──────────┤ RZ(0) ├»
# «       │              │                                 │                │      │    └─┬─┘  └───────┘  │    └─┬─┘            └─┬─┘          └───────┘          └─┬─┘          └─┬───┬─┘»
# «q_7: ──┼──────────────■─────────────────────────────────┼────────────────■──────┼──────■───────────────┼──────■────────────────┼─────────────────────────────────┼──────────────┤ X ├──»
# «       │                                                │                       │                      │                       │                                 │              └─┬─┘  »
# «q_8: ──■────────────────────────────────────────────────■───────────────────────■──────────────────────■───────────────────────■─────────────────────────────────■────────────────■────»
# «                                                                                                                                                                                       »
# «                                                                      ┌───┐          ┌──────────────────────┐          ┌───┐          ┌───┐ ┌──────────────────────┐┌───┐                         »
# «q_0: ─────────────────────────────────────────────────────────────────┤ X ├──────────┤ RZ(15.3582549439580) ├──────────┤ X ├──────────┤ X ├─┤ RZ(16.2377105830025) ├┤ X ├─────────────────────────»
# «                                   ┌───────────────────────┐          └─┬─┘          └──────────────────────┘          └─┬─┘          └─┬─┘ └──────────────────────┘└─┬─┘          ┌───┐          »
# «q_1: ──────────────────────────────┤0                      ├────────────■────────────────────────────────────────────────■──────────────┼─────────────────────────────┼────────────┤ X ├──────────»
# «     ┌───────────────────────┐     │  circuit-8884151(0.0) │                                                                            │                             │            └─┬─┘          »
# «q_2: ┤0                      ├──X──┤1                      ├────────────────────────────────────────────────────────────────────────────■─────────────────────────────■──────────────■────────────»
# «     │  circuit-8884151(0.0) │  │  └───────────────────────┘                                                                                                             ┌───────────────────────┐»
# «q_3: ┤1                      ├──X────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤0                      ├»
# «     └───────────────────────┘                                                                                                             ┌───────────────────────┐     │  circuit-8884151(0.0) │»
# «q_4: ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤0                      ├──X──┤1                      ├»
# «                                                                                                             ┌───────────────────────┐     │  circuit-8884151(0.0) │  │  ├───────────────────────┤»
# «q_5: ────────────────────────────────────────────────────────────────────────────────────────────────────────┤0                      ├──X──┤1                      ├──X──┤0                      ├»
# «                                                            ┌───────────────────────┐                        │  circuit-8884151(0.0) │  │  ├───────────────────────┤     │  circuit-8884151(0.0) │»
# «q_6: ───────────────────────────────────────────────────────┤0                      ├───────────X────────────┤1                      ├──X──┤0                      ├──X──┤1                      ├»
# «             ┌───────┐        ┌───┐        ┌───────┐        │  circuit-8884151(0.0) │           │            ├───────────────────────┤     │  circuit-8884151(0.0) │  │  ├───────────────────────┤»
# «q_7: ────────┤ RZ(0) ├────────┤ X ├────────┤ RZ(0) ├────────┤1                      ├───────────X────────────┤0                      ├──X──┤1                      ├──X──┤0                      ├»
# «             └───────┘        └─┬─┘        ├───────┤        └───────────────────────┘                        │  circuit-8884151(0.0) │  │  └───────────────────────┘     │  circuit-8884151(0.0) │»
# «q_8: ───────────────────────────■──────────┤ RZ(0) ├─────────────────────────────────────────────────────────┤1                      ├──X────────────────────────────────┤1                      ├»
# «                                           └───────┘                                                         └───────────────────────┘                                   └───────────────────────┘»
# «     ┌───┐┌──────────────────────┐┌───┐     ┌───┐┌──────────────────────┐                        ┌───┐     ┌───┐┌──────────────────────┐                                                ┌───┐     »
# «q_0: ┤ X ├┤ RZ(2.90698752462155) ├┤ X ├─────┤ X ├┤ RZ(1.87712794575245) ├────────────────────────┤ X ├─────┤ X ├┤ RZ(2.75658358479688) ├────────────────────────────────────────────────┤ X ├─────»
# «     └─┬─┘├──────────────────────┤└─┬─┘┌───┐└─┬─┘└────────┬───┬─────────┘┌──────────────────────┐└─┬─┘┌───┐└─┬─┘└────────┬───┬─────────┘┌──────────────────────┐                        └─┬─┘┌───┐»
# «q_1: ──┼──┤ RZ(15.3762124040329) ├──┼──┤ X ├──┼───────────┤ X ├──────────┤ RZ(1.87712794575245) ├──┼──┤ X ├──┼───────────┤ X ├──────────┤ RZ(2.91053665700028) ├──────────────────────────┼──┤ X ├»
# «       │  └──────────────────────┘  │  └─┬─┘  │           └─┬─┘          └──────────────────────┘  │  └─┬─┘  │           └─┬─┘          └────────┬───┬─────────┘┌──────────────────────┐  │  └─┬─┘»
# «q_2: ──┼────────────────────────────┼────■────┼─────────────┼──────────────────────────────────────┼────┼────┼─────────────┼─────────────────────┤ X ├──────────┤ RZ(2.75658358479688) ├──┼────┼──»
# «       │                            │         │             │                                      │    │    │             │                     └─┬─┘          └──────────────────────┘  │    │  »
# «q_3: ──■────────────────────────────■─────────┼─────────────■──────────────────────────────────────┼────■────┼─────────────┼───────────────────────■──────────────────────────────────────┼────┼──»
# «                                              │                                                    │         │             │                                                              │    │  »
# «q_4: ─────────────────────────────────────────■────────────────────────────────────────────────────■─────────┼─────────────■──────────────────────────────────────────────────────────────┼────■──»
# «                                                                                                             │                                                                            │       »
# «q_5: ────────────────────────────────────────────────────────────────────────────────────────────────────────■────────────────────────────────────────────────────────────────────────────■───────»
# «                                                                                                                                                                                                  »
# «q_6: ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                                                                                                                  »
# «q_7: ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                                                                                                                  »
# «q_8: ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                                                                                                                  »
# «          ┌───┐┌───────────────────────┐                                                ┌───┐          ┌───┐┌───────────────────────┐                                                 »
# «q_0: ─────┤ X ├┤ RZ(0.213168817969941) ├────────────────────────────────────────────────┤ X ├──────────┤ X ├┤ RZ(0.623104197622439) ├─────────────────────────────────────────────────»
# «          └─┬─┘└─────────┬───┬─────────┘┌──────────────────────┐                        └─┬─┘┌───┐     └─┬─┘└─────────┬───┬─────────┘┌───────────────────────┐                        »
# «q_1: ───────┼────────────┤ X ├──────────┤ RZ(1.89508540582727) ├──────────────────────────┼──┤ X ├───────┼────────────┤ X ├──────────┤ RZ(0.213168817969941) ├────────────────────────»
# «     ┌───┐  │            └─┬─┘          └────────┬───┬─────────┘┌──────────────────────┐  │  └─┬─┘┌───┐  │            └─┬─┘          └─────────┬───┬─────────┘┌──────────────────────┐»
# «q_2: ┤ X ├──┼──────────────┼─────────────────────┤ X ├──────────┤ RZ(1.89508540582727) ├──┼────┼──┤ X ├──┼──────────────┼──────────────────────┤ X ├──────────┤ RZ(2.92944720889037) ├»
# «     └─┬─┘  │              │                     └─┬─┘          └──────────────────────┘  │    │  └─┬─┘  │              │                      └─┬─┘          └────────┬───┬─────────┘»
# «q_3: ──■────┼──────────────┼───────────────────────┼──────────────────────────────────────┼────┼────┼────┼──────────────┼────────────────────────┼─────────────────────┤ X ├──────────»
# «            │              │                       │                                      │    │    │    │              │                        │                     └─┬─┘          »
# «q_4: ───────┼──────────────┼───────────────────────■──────────────────────────────────────┼────┼────■────┼──────────────┼────────────────────────┼───────────────────────■────────────»
# «            │              │                                                              │    │         │              │                        │                                    »
# «q_5: ───────┼──────────────■──────────────────────────────────────────────────────────────┼────■─────────┼──────────────┼────────────────────────■────────────────────────────────────»
# «            │                                                                             │              │              │                                                             »
# «q_6: ───────■─────────────────────────────────────────────────────────────────────────────■──────────────┼──────────────■─────────────────────────────────────────────────────────────»
# «                                                                                                         │                                                                            »
# «q_7: ────────────────────────────────────────────────────────────────────────────────────────────────────■────────────────────────────────────────────────────────────────────────────»
# «                                                                                                                                                                                      »
# «q_8: ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                                                                                                      »
# «                             ┌───┐               ┌───┐┌───────────────────────┐                                                                          ┌───┐┌───────────────────────┐               »
# «q_0: ────────────────────────┤ X ├───────────────┤ X ├┤ RZ(0.623104197622439) ├──────────────────────────────────────────────────────────────────────────┤ X ├┤ RZ(-32.4295695829013) ├───────────────»
# «                             └─┬─┘┌───┐          └─┬─┘└─────────┬───┬─────────┘┌───────────────────────┐                                                 └─┬─┘└─────────┬───┬─────────┘          ┌───┐»
# «q_1: ──────────────────────────┼──┤ X ├────────────┼────────────┤ X ├──────────┤ RZ(0.623104197622439) ├───────────────────────────────────────────────────┼────────────┤ X ├────────────────────┤ X ├»
# «                               │  └─┬─┘┌───┐       │            └─┬─┘          └─────────┬───┬─────────┘┌───────────────────────┐                          │            └─┬─┘          ┌───┐     └─┬─┘»
# «q_2: ──────────────────────────┼────┼──┤ X ├───────┼──────────────┼──────────────────────┤ X ├──────────┤ RZ(0.213168817969941) ├──────────────────────────┼──────────────┼────────────┤ X ├───────┼──»
# «     ┌──────────────────────┐  │    │  └─┬─┘┌───┐  │              │                      └─┬─┘          └─────────┬───┬─────────┘┌──────────────────────┐  │              │            └─┬─┘┌───┐  │  »
# «q_3: ┤ RZ(14.1901183839803) ├──┼────┼────┼──┤ X ├──┼──────────────┼────────────────────────┼──────────────────────┤ X ├──────────┤ RZ(15.0695740230248) ├──┼──────────────┼──────────────┼──┤ X ├──┼──»
# «     └──────────────────────┘  │    │    │  └─┬─┘  │              │                        │                      └─┬─┘          └──────────────────────┘  │              │              │  └─┬─┘  │  »
# «q_4: ──────────────────────────┼────┼────┼────■────┼──────────────┼────────────────────────┼────────────────────────┼──────────────────────────────────────┼──────────────┼──────────────┼────┼────┼──»
# «                               │    │    │         │              │                        │                        │                                      │              │              │    │    │  »
# «q_5: ──────────────────────────┼────┼────■─────────┼──────────────┼────────────────────────┼────────────────────────■──────────────────────────────────────┼──────────────┼──────────────┼────■────┼──»
# «                               │    │              │              │                        │                                                               │              │              │         │  »
# «q_6: ──────────────────────────┼────■──────────────┼──────────────┼────────────────────────■───────────────────────────────────────────────────────────────┼──────────────┼──────────────■─────────┼──»
# «                               │                   │              │                                                                                        │              │                        │  »
# «q_7: ──────────────────────────■───────────────────┼──────────────■────────────────────────────────────────────────────────────────────────────────────────┼──────────────■────────────────────────┼──»
# «                                                   │                                                                                                       │                                       │  »
# «q_8: ──────────────────────────────────────────────■───────────────────────────────────────────────────────────────────────────────────────────────────────■───────────────────────────────────────■──»
# «                                                                                                                                                                                                      »
# «                                                                                                                                      ┌─────────────────────────────────────┐          »
# «q_0: ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤0                                    ├──X───────»
# «     ┌───────────────────────┐                                                                          ┌───┐┌───────────────────────┐│  circuit-8884151(-1.57250051802218) │  │       »
# «q_1: ┤ RZ(0.623104197622439) ├──────────────────────────────────────────────────────────────────────────┤ X ├┤ RZ(-30.7136714897196) ├┤1                                    ├──X───────»
# «     └─────────┬───┬─────────┘┌───────────────────────┐                                                 └─┬─┘└─────────┬───┬─────────┘└─────────────────────────────────────┘     ┌───┐»
# «q_2: ──────────┤ X ├──────────┤ RZ(0.623104197622439) ├───────────────────────────────────────────────────┼────────────┤ X ├──────────────────────────────────────────────────────┤ X ├»
# «               └─┬─┘          └─────────┬───┬─────────┘┌───────────────────────┐                          │            └─┬─┘                           ┌───┐                      └─┬─┘»
# «q_3: ────────────┼──────────────────────┤ X ├──────────┤ RZ(0.248865888561816) ├──────────────────────────┼──────────────┼─────────────────────────────┤ X ├────────────────────────┼──»
# «                 │                      └─┬─┘          └─────────┬───┬─────────┘┌──────────────────────┐  │              │                             └─┬─┘                 ┌───┐  │  »
# «q_4: ────────────┼────────────────────────┼──────────────────────┤ X ├──────────┤ RZ(14.2080758440552) ├──┼──────────────┼───────────────────────────────┼───────────────────┤ X ├──┼──»
# «                 │                        │                      └─┬─┘          └──────────────────────┘  │              │                               │                   └─┬─┘  │  »
# «q_5: ────────────┼────────────────────────┼────────────────────────■──────────────────────────────────────┼──────────────┼───────────────────────────────┼─────────────────────■────┼──»
# «                 │                        │                                                               │              │                               │                          │  »
# «q_6: ────────────┼────────────────────────■───────────────────────────────────────────────────────────────┼──────────────┼───────────────────────────────■──────────────────────────┼──»
# «                 │                                                                                        │              │                                                          │  »
# «q_7: ────────────■────────────────────────────────────────────────────────────────────────────────────────┼──────────────■──────────────────────────────────────────────────────────┼──»
# «                                                                                                          │                                                                         │  »
# «q_8: ─────────────────────────────────────────────────────────────────────────────────────────────────────■─────────────────────────────────────────────────────────────────────────■──»
# «                                                                                                                                                                                       »
# «                                                                                                                                                                                                   »
# «q_0: ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                                                                                                                   »
# «q_1: ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «     ┌───────────────────────┐                                                  ┌───┐┌───────────────────────┐                                                                                     »
# «q_2: ┤ RZ(0.623104197622439) ├──────────────────────────────────────────────────┤ X ├┤ RZ(-32.5104038715886) ├─────────────────────────────────────────────────────────────────────────────────────»
# «     └─────────┬───┬─────────┘┌───────────────────────┐                         └─┬─┘└─────────┬───┬─────────┘     ┌───┐┌───────────────────────┐                                                  »
# «q_3: ──────────┤ X ├──────────┤ RZ(0.213168817969941) ├───────────────────────────┼────────────┤ X ├───────────────┤ X ├┤ RZ(0.213168817969941) ├──────────────────────────────────────────────────»
# «               └─┬─┘          └─────────┬───┬─────────┘┌───────────────────────┐  │            └─┬─┘          ┌───┐└─┬─┘└─────────┬───┬─────────┘┌───────────────────────┐                         »
# «q_4: ────────────┼──────────────────────┤ X ├──────────┤ RZ(0.248865888561816) ├──┼──────────────┼────────────┤ X ├──┼────────────┤ X ├──────────┤ RZ(0.213168817969941) ├─────────────────────────»
# «                 │                      └─┬─┘          └───────────────────────┘  │              │            └─┬─┘  │            └─┬─┘          └─────────┬───┬─────────┘┌───────────────────────┐»
# «q_5: ────────────┼────────────────────────┼───────────────────────────────────────┼──────────────┼──────────────┼────┼──────────────┼──────────────────────┤ X ├──────────┤ RZ(0.248865888561816) ├»
# «                 │                        │                                       │              │              │    │              │                      └─┬─┘          └───────────────────────┘»
# «q_6: ────────────┼────────────────────────■───────────────────────────────────────┼──────────────┼──────────────■────┼──────────────┼────────────────────────■─────────────────────────────────────»
# «                 │                                                                │              │                   │              │                                                              »
# «q_7: ────────────■────────────────────────────────────────────────────────────────┼──────────────■───────────────────┼──────────────■──────────────────────────────────────────────────────────────»
# «                                                                                  │                                  │                                                                             »
# «q_8: ─────────────────────────────────────────────────────────────────────────────■──────────────────────────────────■─────────────────────────────────────────────────────────────────────────────»
# «                                                                                                                                                                                                   »
# «                                                                                                                                               ┌─────────────────────────────────────┐»
# «q_0: ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤0                                    ├»
# «                                                                               ┌─────────────────────────────────────┐                         │  circuit-8884151(-1.57250051802218) │»
# «q_1: ──────────────────────────────────────────────────────────────────────────┤0                                    ├────────────X────────────┤1                                    ├»
# «                                   ┌─────────────────────────────────────┐     │  circuit-8884151(-1.57250051802218) │            │            └─────────────────────────────────────┘»
# «q_2: ──────────────────────────────┤0                                    ├──X──┤1                                    ├────────────X───────────────────────────────────────────────────»
# «     ┌───┐┌───────────────────────┐│  circuit-8884151(-1.57250051802218) │  │  └─────────────────────────────────────┘                                                                »
# «q_3: ┤ X ├┤ RZ(-28.1409862142551) ├┤1                                    ├──X─────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «     └─┬─┘└─────────┬───┬─────────┘└─────────────────────────────────────┘┌───┐       ┌───────────────────────┐                                                 ┌───┐                 »
# «q_4: ──┼────────────┤ X ├─────────────────────────────────────────────────┤ X ├───────┤ RZ(0.213168817969941) ├─────────────────────────────────────────────────┤ X ├─────────────────»
# «       │            └─┬─┘                           ┌───┐                 └─┬─┘       └─────────┬───┬─────────┘       ┌───────────────────────┐                 └─┬─┘                 »
# «q_5: ──┼──────────────┼─────────────────────────────┤ X ├───────────────────┼───────────────────┤ X ├─────────────────┤ RZ(0.213168817969941) ├───────────────────┼───────────────────»
# «       │              │                             └─┬─┘                   │                   └─┬─┘                 └───────────────────────┘                   │                   »
# «q_6: ──┼──────────────┼───────────────────────────────■─────────────────────┼─────────────────────┼───────────────────────────────────────────────────────────────┼───────────────────»
# «       │              │                                                     │                     │                                                               │                   »
# «q_7: ──┼──────────────■─────────────────────────────────────────────────────┼─────────────────────■───────────────────────────────────────────────────────────────┼───────────────────»
# «       │                                                                    │                                                                                     │                   »
# «q_8: ──■────────────────────────────────────────────────────────────────────■─────────────────────────────────────────────────────────────────────────────────────■───────────────────»
# «                                                                                                                                                                                      »
# «                                                                                                                                                                                 »
# «q_0: ────────────X───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                 │                                                                                                                                                               »
# «q_1: ────────────X───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                                                                                                 »
# «q_2: ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                                                                                                 »
# «q_3: ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «     ┌───────────────────────┐                                                                                    ┌─────────────────────────────────────┐                        »
# «q_4: ┤ RZ(-26.4250881210733) ├────────────────────────────────────────────────────────────────────────────────────┤0                                    ├───────────X────────────»
# «     └─────────┬───┬─────────┘┌───┐┌───────────────────────┐                        ┌───┐┌───────────────────────┐│  circuit-8884151(-1.57250051802218) │           │            »
# «q_5: ──────────┤ X ├──────────┤ X ├┤ RZ(0.213168817969941) ├────────────────────────┤ X ├┤ RZ(-28.2218205029424) ├┤1                                    ├───────────X────────────»
# «               └─┬─┘          └─┬─┘└─────────┬───┬─────────┘┌──────────────────────┐└─┬─┘└─────────┬───┬─────────┘└────────────────┬───┬────────────────┘┌──────────────────────┐»
# «q_6: ────────────┼──────────────┼────────────┤ X ├──────────┤ RZ(12.4904621856059) ├──┼────────────┤ X ├───────────────────────────┤ X ├─────────────────┤ RZ(12.4904621856059) ├»
# «                 │              │            └─┬─┘          └──────────────────────┘  │            └─┬─┘                           └─┬─┘                 └──────────────────────┘»
# «q_7: ────────────■──────────────┼──────────────■──────────────────────────────────────┼──────────────■───────────────────────────────┼───────────────────────────────────────────»
# «                                │                                                     │                                              │                                           »
# «q_8: ───────────────────────────■─────────────────────────────────────────────────────■──────────────────────────────────────────────■───────────────────────────────────────────»
# «                                                                                                                                                                                 »
# «                                                                                                                                                                                                  »
# «q_0: ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                                 ┌─────────────────────────────────────┐                                          »
# «q_1: ────────────────────────────────────────────────────────────────────────────────────────────────────────────┤0                                    ├──────────────────────────────────────────»
# «                                                                     ┌─────────────────────────────────────┐     │  circuit-8884151(-1.57250051802218) │                                          »
# «q_2: ────────────────────────────────────────────────────────────────┤0                                    ├──X──┤1                                    ├──────────────────────────────────────────»
# «     ┌─────────────────────────────────────┐                         │  circuit-8884151(-1.57250051802218) │  │  └─────────────────────────────────────┘                                          »
# «q_3: ┤0                                    ├────────────X────────────┤1                                    ├──X───────────────────────────────────────────────────────────────────────────────────»
# «     │  circuit-8884151(-1.57250051802218) │            │            └─────────────────────────────────────┘                                                                                      »
# «q_4: ┤1                                    ├────────────X─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «     └─────────────────────────────────────┘                                                                                                                                                      »
# «q_5: ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                      ┌───┐                 ┌───────────────────────┐                                                                                   ┌─────────────────────────────────────┐   »
# «q_6: ─────────────────┤ X ├─────────────────┤ RZ(-14.3386010117330) ├───────────────────────────────────────────────────────────────────────────────────┤0                                    ├─X─»
# «                      └─┬─┘                 └─────────┬───┬─────────┘        ┌──────────────────────┐       ┌───┐       ┌───────────────────────┐       │  circuit-8884151(-1.57250051802218) │ │ »
# «q_7: ───────────────────┼─────────────────────────────┤ X ├──────────────────┤ RZ(13.3091529264730) ├───────┤ X ├───────┤ RZ(-17.1076292525177) ├───────┤1                                    ├─X─»
# «                        │                             └─┬─┘                  └──────────────────────┘       └─┬─┘       ├───────────────────────┤       └─────────────────────────────────────┘   »
# «q_8: ───────────────────■───────────────────────────────■─────────────────────────────────────────────────────■─────────┤ RZ(-17.5777516238818) ├─────────────────────────────────────────────────»
# «                                                                                                                        └───────────────────────┘                                                 »
# «
# «q_0: ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# «
# «q_1: ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# «
# «q_2: ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# «                                                                                         ┌─────────────────────────────────────┐
# «q_3: ────────────────────────────────────────────────────────────────────────────────────┤0                                    ├
# «                                               ┌─────────────────────────────────────┐   │  circuit-8884151(-1.57250051802218) │
# «q_4: ──────────────────────────────────────────┤0                                    ├─X─┤1                                    ├
# «     ┌─────────────────────────────────────┐   │  circuit-8884151(-1.57250051802218) │ │ ├─────────────────────────────────────┤
# «q_5: ┤0                                    ├─X─┤1                                    ├─X─┤0                                    ├
# «     │  circuit-8884151(-1.57250051802218) │ │ ├─────────────────────────────────────┤   │  circuit-8884151(-1.57250051802218) │
# «q_6: ┤1                                    ├─X─┤0                                    ├─X─┤1                                    ├
# «     ├─────────────────────────────────────┤   │  circuit-8884151(-1.57250051802218) │ │ ├─────────────────────────────────────┤
# «q_7: ┤0                                    ├─X─┤1                                    ├─X─┤0                                    ├
# «     │  circuit-8884151(-1.57250051802218) │ │ └─────────────────────────────────────┘   │  circuit-8884151(-1.57250051802218) │
# «q_8: ┤1                                    ├─X───────────────────────────────────────────┤1                                    ├
# «     └─────────────────────────────────────┘                                             └─────────────────────────────────────┘
# Minimum: 4.724383379219795, prob_s: 0.07418685726318561
# p=2
# Minim_exp_val_L: 4.721733275933307, prob_s_L: 0.0751510211281973
# Comparison (t=1): B_next: 4.717539967171813, B_before: 4.724383379219795
# Time for intialising with perturbed values 1 no. of times: 42.94365906715393
# Minim_exp_val_B: 4.717539967171813, prob_s_B: 0.07608814244019164
# Length_B: 4
# Optimal_L: [1.4526062305367078, 2.798746183265514, -1.446894273270799, -0.6019473091565088]
# Optimal_B: [-0.43287649808649414, -2.4559370996138616, -2.8969230797365664, -1.196949991525297], length: 4
# p=3
# Minim_exp_val_L: 6.67271807774155, prob_s_L: 0.029594077559013644
# Comparison (t=1): B_next: 6.417195608215138, B_before: 4.717539967171813
# Comparison (t=2): B_next: 6.417195608215138, B_before: 4.717539967171813
# Comparison (t=3): B_next: 6.052503607079569, B_before: 4.717539967171813
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-345-ce5cde8727ae> in <module>
# ----> 1 main(["-N 3", "-R 3", "-P 1.5", "-OSLSQP", "-M 5", "-T 3", "-S 3"])
#
# <ipython-input-342-9213dea2c3a4> in main(raw_args)
#     203             perturbed_points = generate_points(next_fourier_point_B, 10, penalty)
#     204             for point in perturbed_points:
# --> 205                 qaoa_results_B, _, _ = Fourier_QAOA(operator, quantum_instance, optimizer, p, point, qc, mixer = mixer)
#     206                 exp_val = qaoa_results_B.eigenvalue*max_coeff + offset
#     207                 results.append(qaoa_results_B)
#
# <ipython-input-342-9213dea2c3a4> in Fourier_QAOA(operator, quantum_instance, optimizer, p, initial_fourier_point, initial_state, mixer, qubo)
#     258     # qaoa_instance.set_parameterise_point_for_energy_evaluation(QAOAEx.convert_from_fourier_point)
#     259     bounds = [(-np.pi, np.pi)]*len(initial_fourier_point)
# --> 260     qaoa_results = qaoa_instance.solve(operator, initial_fourier_point, bounds)
#     261     optimal_parameterised_point = qaoa_instance.latest_parameterised_point
#     262     if not isinstance(qaoa_results.eigenstate, dict):
#
# ~/QAOAvsVQE/QAOAEx.py in solve(self, ising_hamiltonian_operator, initial_point, bounds)
#     981         self.initial_point = initial_point
#     982         self.set_optimiser_parameter_bounds(bounds)
# --> 983         return self.compute_minimum_eigenvalue(ising_hamiltonian_operator)
#     984
#     985     def solve_from_ising_hamiltonian_terms(self,
#
# ~/anaconda3/envs/ox/lib/python3.9/site-packages/qiskit/algorithms/minimum_eigen_solvers/vqe.py in compute_minimum_eigenvalue(self, operator, aux_operators)
#     410         if not self._expect_op:
#     411             self._expect_op = self.construct_expectation(self._ansatz_params, operator)
# --> 412         vqresult = self.find_minimum(initial_point=self.initial_point,
#     413                                      ansatz=self.ansatz,
#     414                                      cost_fn=self._energy_evaluation,
#
# ~/QAOAvsVQE/QAOAEx.py in find_minimum(self, initial_point, ansatz, cost_fn, optimizer, gradient_fn)
#     618         logger.info('Starting optimizer.\nbounds=%s\ninitial point=%s', bounds, initial_point)
#     619
# --> 620         opt_params, opt_val, num_optimizer_evals = optimizer.optimize(len(self.initial_point),
#     621                                                                           cost_fn,
#     622                                                                           variable_bounds=bounds,
#
# ~/anaconda3/envs/ox/lib/python3.9/site-packages/qiskit/algorithms/optimizers/slsqp.py in optimize(self, num_vars, objective_function, gradient_function, variable_bounds, initial_point)
#      78                                                          self._max_evals_grouped))
#      79
# ---> 80         res = minimize(objective_function, initial_point, jac=gradient_function,
#      81                        tol=self._tol, bounds=variable_bounds, method="SLSQP",
#      82                        options=self._options)
#
# ~/anaconda3/envs/ox/lib/python3.9/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     625         return _minimize_cobyla(fun, x0, args, constraints, **options)
#     626     elif meth == 'slsqp':
# --> 627         return _minimize_slsqp(fun, x0, args, jac, bounds,
#     628                                constraints, callback=callback, **options)
#     629     elif meth == 'trust-constr':
#
# ~/anaconda3/envs/ox/lib/python3.9/site-packages/scipy/optimize/slsqp.py in _minimize_slsqp(func, x0, args, jac, bounds, constraints, maxiter, ftol, iprint, disp, eps, callback, finite_diff_rel_step, **unknown_options)
#     431
#     432         if mode == 1:  # objective and constraint evaluation required
# --> 433             fx = wrapped_fun(x)
#     434             c = _eval_constraint(x, cons)
#     435
#
# ~/anaconda3/envs/ox/lib/python3.9/site-packages/scipy/optimize/optimize.py in eval(x)
#     273     def eval(x):
#     274         x = _check_clip_x(x, bounds)
# --> 275         return func(x)
#     276
#     277     return eval
#
# ~/anaconda3/envs/ox/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun(self, x)
#     240         if not np.array_equal(x, self.x):
#     241             self._update_x_impl(x)
# --> 242         self._update_fun()
#     243         return self.f
#     244
#
# ~/anaconda3/envs/ox/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in _update_fun(self)
#     224     def _update_fun(self):
#     225         if not self.f_updated:
# --> 226             self._update_fun_impl()
#     227             self.f_updated = True
#     228
#
# ~/anaconda3/envs/ox/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in update_fun()
#     131
#     132         def update_fun():
# --> 133             self.f = fun_wrapped(self.x)
#     134
#     135         self._update_fun_impl = update_fun
#
# ~/anaconda3/envs/ox/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     128         def fun_wrapped(x):
#     129             self.nfev += 1
# --> 130             return fun(x, *args)
#     131
#     132         def update_fun():
#
# ~/QAOAvsVQE/QAOAEx.py in _energy_evaluation(self, parameters)
#     723         start_time = time.time()
#     724         #self._log_text("self._expect_op:", self._expect_op)
# --> 725         sampled_expect_op = self._circuit_sampler.convert(self._expect_op, params=param_bindings)
#     726         means = np.real(sampled_expect_op.eval())
#     727
#
# ~/anaconda3/envs/ox/lib/python3.9/site-packages/qiskit/opflow/converters/circuit_sampler.py in convert(self, operator, params)
#     205         circs = list(self._circuit_ops_cache.values()) if not self._transpiled_circ_cache else None
#     206         p_b = cast(List[Dict[Parameter, float]], param_bindings)
# --> 207         sampled_statefn_dicts = self.sample_circuits(circuit_sfns=circs,
#     208                                                      param_bindings=p_b)
#     209
#
# ~/QAOAvsVQE/QAOAEx.py in sample_circuits(self, circuit_sfns, param_bindings)
#     263             ready_circs = self._transpiled_circ_cache
#     264
# --> 265         results = self.quantum_instance.execute(ready_circs,
#     266                                                 had_transpiled=self._transpile_before_bind)
#     267
#
# ~/anaconda3/envs/ox/lib/python3.9/site-packages/qiskit/utils/quantum_instance.py in execute(self, circuits, had_transpiled)
#     478                                   run_config=self._run_config.to_dict(),
#     479                                   job_callback=self._job_callback) if circuit_job else \
# --> 480                      run_qobj(qobj, self._backend, self._qjob_config,
#     481                               self._backend_options, self._noise_config,
#     482                               self._skip_qobj_validation, self._job_callback)
#
# ~/anaconda3/envs/ox/lib/python3.9/site-packages/qiskit/utils/run_circuits.py in run_qobj(qobj, backend, qjob_config, backend_options, noise_config, skip_qobj_validation, job_callback)
#     327         results = []
#     328         for job in jobs:
# --> 329             results.append(job.result(**qjob_config))
#     330
#     331     result = _combine_result_objects(results) if results else None
#
# ~/anaconda3/envs/ox/lib/python3.9/site-packages/qiskit/providers/aer/aerjob.py in _wrapper(self, *args, **kwargs)
#      41         if self._future is None:
#      42             raise JobError("Job not submitted yet!. You have to .submit() first!")
# ---> 43         return func(self, *args, **kwargs)
#      44     return _wrapper
#      45
#
# ~/anaconda3/envs/ox/lib/python3.9/site-packages/qiskit/providers/aer/aerjob.py in result(self, timeout)
#     100             concurrent.futures.CancelledError: if job cancelled before completed.
#     101         """
# --> 102         return self._future.result(timeout=timeout)
#     103
#     104     @requires_submit
#
# ~/anaconda3/envs/ox/lib/python3.9/concurrent/futures/_base.py in result(self, timeout)
#     438                     return self.__get_result()
#     439
# --> 440                 self._condition.wait(timeout)
#     441
#     442                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# ~/anaconda3/envs/ox/lib/python3.9/threading.py in wait(self, timeout)
#     310         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311             if timeout is None:
# --> 312                 waiter.acquire()
#     313                 gotit = True
#     314             else:
#
# KeyboardInterrupt:

# %%
main(["-N 3", "-R 3", "-P 1.5", "-OSLSQP", "-M 5", "-T 3", "-S 4"])
# Out:
# ____________________________________________________________________________________________________
# QUBO NO: 4
#  ____________________________________________________________________________________________________
# optimal function value: 2.4699250000000035
# optimal value: [1. 0. 0. 0. 1. 0. 1. 0. 0.]
# status: SUCCESS
# Solving with QAOA...
# p=1
# Restart_no: 1, Exp_val: 2.9762597777778126, Prob_s: 0.03703703703703704
# Restart_no: 2, Exp_val: 2.976259777777816, Prob_s: 0.03703703703703688
# Restart_no: 3, Exp_val: 2.976259777777848, Prob_s: 0.037037037037036556
# Restart_no: 4, Exp_val: 2.972330965212265, Prob_s: 0.0382696392997337
#      ┌────────────┐                     ┌───┐┌───┐┌───────┐┌───┐┌───┐┌───────┐┌───┐  ┌───┐  ┌───────┐           ┌───┐         ┌───┐┌───────┐         ┌───┐     ┌───┐┌───────┐                  ┌───┐»
# q_0: ┤ RY(1.9106) ├─────■────────────■──┤ X ├┤ X ├┤ RZ(0) ├┤ X ├┤ X ├┤ RZ(0) ├┤ X ├──┤ X ├──┤ RZ(0) ├───────────┤ X ├─────────┤ X ├┤ RZ(0) ├─────────┤ X ├─────┤ X ├┤ RZ(0) ├──────────────────┤ X ├»
#      └────────────┘┌────┴────┐     ┌─┴─┐└───┘└─┬─┘└───────┘└─┬─┘└─┬─┘└───────┘└─┬─┘  └─┬─┘  └─┬───┬─┘┌───────┐  └─┬─┘   ┌───┐ └─┬─┘└─┬───┬─┘┌───────┐└─┬─┘┌───┐└─┬─┘└─┬───┬─┘┌───────┐         └─┬─┘»
# q_1: ──────────────┤ RY(π/2) ├──■──┤ X ├───────■─────────────■────┼─────────────┼──────┼──────┤ X ├──┤ RZ(0) ├────┼─────┤ X ├───┼────┤ X ├──┤ RZ(0) ├──┼──┤ X ├──┼────┤ X ├──┤ RZ(0) ├───────────┼──»
#                    └─────────┘┌─┴─┐└───┘                          │             │      │      └─┬─┘  └───────┘    │     └─┬─┘   │    └─┬─┘  └───────┘  │  └─┬─┘  │    └─┬─┘  └─┬───┬─┘┌───────┐  │  »
# q_2: ─────────────────────────┤ X ├───────────────────────────────■─────────────■──────┼────────■─────────────────┼───────■─────┼──────┼───────────────┼────┼────┼──────┼──────┤ X ├──┤ RZ(0) ├──┼──»
#      ┌────────────┐           └───┘     ┌───┐                                          │                          │             │      │               │    │    │      │      └─┬─┘  └───────┘  │  »
# q_3: ┤ RY(1.9106) ├─────■────────────■──┤ X ├──────────────────────────────────────────■──────────────────────────■─────────────┼──────■───────────────┼────■────┼──────┼────────■───────────────┼──»
#      └────────────┘┌────┴────┐     ┌─┴─┐└───┘                                                                                   │                      │         │      │                        │  »
# q_4: ──────────────┤ RY(π/2) ├──■──┤ X ├────────────────────────────────────────────────────────────────────────────────────────■──────────────────────■─────────┼──────■────────────────────────┼──»
#                    └─────────┘┌─┴─┐└───┘                                                                                                                         │                               │  »
# q_5: ─────────────────────────┤ X ├──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────■───────────────────────────────■──»
#      ┌────────────┐           └───┘     ┌───┐┌───┐┌───────┐┌───┐┌───┐┌───────┐┌───┐┌───────┐ ┌─────┐   ┌───┐                                                                                        »
# q_6: ┤ RY(1.9106) ├─────■────────────■──┤ X ├┤ X ├┤ RZ(0) ├┤ X ├┤ X ├┤ RZ(0) ├┤ X ├┤ RZ(0) ├─┤ SDG ├───┤ H ├────────────────────────────────────────────────────────────────────────────────────────»
#      └────────────┘┌────┴────┐     ┌─┴─┐└───┘└─┬─┘└───────┘└─┬─┘└─┬─┘└───────┘└─┬─┘└─┬───┬─┘┌┴─────┴┐  ├───┤  ┌───────┐┌─────┐┌───┐  ┌───┐  ┌───────┐┌───┐┌───┐┌───┐  ┌───┐    ┌───┐  ┌───────┐┌───┐»
# q_7: ──────────────┤ RY(π/2) ├──■──┤ X ├───────■─────────────■────┼─────────────┼────┤ X ├──┤ RZ(0) ├──┤ X ├──┤ RZ(0) ├┤ SDG ├┤ H ├──┤ X ├──┤ RZ(0) ├┤ X ├┤ H ├┤ S ├──┤ H ├────┤ X ├──┤ RZ(0) ├┤ X ├»
#                    └─────────┘┌─┴─┐└───┘                          │             │    └─┬─┘  └───────┘  └─┬─┘  ├───────┤├─────┤├───┤  └─┬─┘  └───────┘└─┬─┘├───┤├───┤  ├───┤    └─┬─┘  └───────┘└─┬─┘»
# q_8: ─────────────────────────┤ X ├───────────────────────────────■─────────────■──────■─────────────────■────┤ RZ(0) ├┤ SDG ├┤ H ├────■───────────────■──┤ H ├┤ S ├──┤ H ├──────■───────────────■──»
#                               └───┘                                                                           └───────┘└─────┘└───┘                       └───┘└───┘  └───┘                         »
# «     ┌───────┐┌─────┐┌───┐                                                                                                                                                                        »
# «q_0: ┤ RZ(0) ├┤ SDG ├┤ H ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «     └─┬───┬─┘└─────┘├───┤┌───────┐         ┌───┐┌───────┐┌─────┐  ┌───┐                                                                                                                          »
# «q_1: ──┤ X ├─────────┤ X ├┤ RZ(0) ├─────────┤ X ├┤ RZ(0) ├┤ SDG ├──┤ H ├──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «       └─┬─┘   ┌───┐ └─┬─┘└─┬───┬─┘┌───────┐└─┬─┘└─┬───┬─┘└┬───┬┘┌─┴───┴─┐           ┌───┐  ┌───────┐┌─────┐  ┌───┐                                                                               »
# «q_2: ────┼─────┤ X ├───┼────┤ X ├──┤ RZ(0) ├──┼────┤ X ├───┤ X ├─┤ RZ(0) ├───────────┤ X ├──┤ RZ(0) ├┤ SDG ├──┤ H ├───────────────────────────────────────────────────────────────────────────────»
# «         │     └─┬─┘   │    └─┬─┘  └───────┘  │    └─┬─┘   └─┬─┘ └─┬───┬─┘┌───────┐  └─┬─┘  └─┬───┬─┘└┬───┬┘┌─┴───┴─┐┌───┐┌───────┐ ┌─────┐ ┌───┐                                                 »
# «q_3: ────┼───────■─────┼──────┼───────────────┼──────┼───────┼─────┤ X ├──┤ RZ(0) ├────┼──────┤ X ├───┤ X ├─┤ RZ(0) ├┤ X ├┤ RZ(0) ├─┤ SDG ├─┤ H ├─────────────────────────────────────────────────»
# «         │             │      │               │      │       │     └─┬─┘  └───────┘    │      └─┬─┘   └─┬─┘ └───────┘└─┬─┘└─┬───┬─┘┌┴─────┴┐├───┤┌───────┐┌─────┐┌───┐                            »
# «q_4: ────■─────────────┼──────■───────────────┼──────■───────┼───────■─────────────────┼────────■───────┼──────────────┼────┤ X ├──┤ RZ(0) ├┤ X ├┤ RZ(0) ├┤ SDG ├┤ H ├────────────────────────────»
# «                       │                      │              │                         │                │              │    └─┬─┘  └───────┘└─┬─┘├───────┤├─────┤├───┤┌───┐┌───────┐┌───┐  ┌───┐  »
# «q_5: ──────────────────■──────────────────────■──────────────■─────────────────────────■────────────────■──────────────■──────■───────────────■──┤ RZ(0) ├┤ SDG ├┤ H ├┤ X ├┤ RZ(0) ├┤ X ├──┤ H ├──»
# «                            ┌───┐  ┌───────┐┌───┐  ┌───┐   ┌───┐   ┌───┐    ┌───┐  ┌───────┐  ┌───┐   ┌───┐  ┌─────┐ ┌───┐  ┌───┐  ┌───────┐┌───┐└─┬───┬─┘└┬───┬┘├───┤└─┬─┘└─┬───┬─┘└─┬─┘┌─┴───┴─┐»
# «q_6: ───────────────────────┤ X ├──┤ RZ(0) ├┤ X ├──┤ H ├───┤ S ├───┤ H ├────┤ X ├──┤ RZ(0) ├──┤ X ├───┤ H ├──┤ SDG ├─┤ H ├──┤ X ├──┤ RZ(0) ├┤ X ├──┤ H ├───┤ S ├─┤ H ├──┼────┤ X ├────┼──┤ RZ(0) ├»
# «       ┌───┐  ┌─────┐┌───┐  └─┬─┘  └───────┘└─┬─┘  └───┘   └───┘   └───┘    └─┬─┘  └───────┘  └─┬─┘   └───┘  └─────┘ └───┘  └─┬─┘  └───────┘└─┬─┘  ├───┤   ├───┤ ├───┤  │    └─┬─┘    │  └───────┘»
# «q_7: ──┤ H ├──┤ SDG ├┤ H ├────┼───────────────┼───────────────────────────────┼─────────────────┼─────────────────────────────■───────────────■────┤ H ├───┤ S ├─┤ H ├──┼──────■──────┼───────────»
# «       ├───┤  ├─────┤├───┤    │               │    ┌───┐   ┌───┐   ┌───┐      │                 │     ┌───┐  ┌─────┐ ┌───┐                         └───┘   └───┘ └───┘  │             │    ┌───┐  »
# «q_8: ──┤ H ├──┤ SDG ├┤ H ├────■───────────────■────┤ H ├───┤ S ├───┤ H ├──────■─────────────────■─────┤ H ├──┤ SDG ├─┤ H ├──────────────────────────────────────────────■─────────────■────┤ H ├──»
# «       └───┘  └─────┘└───┘                         └───┘   └───┘   └───┘                              └───┘  └─────┘ └───┘                                                                 └───┘  »
# «                                                                                                                                                                                                   »
# «q_0: ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                                                                                                                   »
# «q_1: ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                                                                                                                   »
# «q_2: ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                                                                       ┌───┐┌───────┐          ┌───┐┌───┐┌───┐┌───┐»
# «q_3: ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├┤ RZ(0) ├──────────┤ X ├┤ H ├┤ S ├┤ H ├»
# «                                                        ┌───┐┌───────┐     ┌───┐┌───┐┌───┐┌───┐     ┌───┐┌───────┐     ┌───┐┌───┐┌─────┐┌───┐     ┌───┐└─┬─┘├───────┤     ┌───┐└─┬─┘├───┤├───┤├───┤»
# «q_4: ───────────────────────────────────────────────────┤ X ├┤ RZ(0) ├─────┤ X ├┤ H ├┤ S ├┤ H ├─────┤ X ├┤ RZ(0) ├─────┤ X ├┤ H ├┤ SDG ├┤ H ├─────┤ X ├──┼──┤ RZ(0) ├─────┤ X ├──┼──┤ H ├┤ S ├┤ H ├»
# «     ┌───┐┌───┐┌───┐┌───────┐┌───┐┌───┐┌─────┐┌───┐┌───┐└─┬─┘├───────┤┌───┐└─┬─┘├───┤├───┤├───┤┌───┐└─┬─┘├───────┤┌───┐└─┬─┘├───┤├─────┤├───┤┌───┐└─┬─┘  │  ├───────┤┌───┐└─┬─┘  │  ├───┤├───┤├───┤»
# «q_5: ┤ S ├┤ H ├┤ X ├┤ RZ(0) ├┤ X ├┤ H ├┤ SDG ├┤ H ├┤ X ├──┼──┤ RZ(0) ├┤ X ├──┼──┤ H ├┤ S ├┤ H ├┤ X ├──┼──┤ RZ(0) ├┤ X ├──┼──┤ H ├┤ SDG ├┤ H ├┤ X ├──┼────┼──┤ RZ(0) ├┤ X ├──┼────┼──┤ H ├┤ S ├┤ H ├»
# «     ├───┤├───┤└─┬─┘└┬─────┬┘└─┬─┘├───┤└─────┘└───┘└─┬─┘  │  └───────┘└─┬─┘  │  └───┘└───┘└───┘└─┬─┘  │  └───────┘└─┬─┘  │  └───┘└─────┘└───┘└─┬─┘  │    │  └───────┘└─┬─┘  │    │  ├───┤├───┤├───┤»
# «q_6: ┤ X ├┤ H ├──┼───┤ SDG ├───┼──┤ H ├──────────────┼────┼─────────────┼────┼───────────────────┼────┼─────────────┼────┼─────────────────────■────┼────┼─────────────■────┼────┼──┤ H ├┤ S ├┤ H ├»
# «     └─┬─┘├───┤  │   ├─────┤   │  ├───┤              │    │             │    │  ┌───┐┌───┐┌───┐  │    │             │    │  ┌───┐┌─────┐┌───┐       │    │                  │    │  ├───┤├───┤├───┤»
# «q_7: ──■──┤ H ├──┼───┤ SDG ├───┼──┤ H ├──────────────■────┼─────────────■────┼──┤ H ├┤ S ├┤ H ├──■────┼─────────────■────┼──┤ H ├┤ SDG ├┤ H ├───────■────┼──────────────────■────┼──┤ H ├┤ S ├┤ H ├»
# «     ┌───┐├───┤  │   └─────┘   │  ├───┤┌─────┐┌───┐       │                  │  ├───┤├───┤├───┤       │                  │  ├───┤├─────┤├───┤            │                       │  ├───┤├───┤├───┤»
# «q_8: ┤ S ├┤ H ├──■─────────────■──┤ H ├┤ SDG ├┤ H ├───────■──────────────────■──┤ H ├┤ S ├┤ H ├───────■──────────────────■──┤ H ├┤ SDG ├┤ H ├────────────■───────────────────────■──┤ H ├┤ S ├┤ H ├»
# «     └───┘└───┘                   └───┘└─────┘└───┘                             └───┘└───┘└───┘                             └───┘└─────┘└───┘                                       └───┘└───┘└───┘»
# «                                                                                                                                                                                               »
# «q_0: ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                                                                                                          ┌───┐»
# «q_1: ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├»
# «                                                                       ┌───┐┌───────┐          ┌───┐┌───┐┌───┐┌───┐          ┌───┐┌───────┐          ┌───┐┌───┐┌─────┐┌───┐          ┌───┐└─┬─┘»
# «q_2: ──────────────────────────────────────────────────────────────────┤ X ├┤ RZ(0) ├──────────┤ X ├┤ H ├┤ S ├┤ H ├──────────┤ X ├┤ RZ(0) ├──────────┤ X ├┤ H ├┤ SDG ├┤ H ├──────────┤ X ├──┼──»
# «               ┌───┐┌───────┐          ┌───┐┌───┐┌─────┐┌───┐     ┌───┐└─┬─┘├───────┤     ┌───┐└─┬─┘├───┤├───┤├───┤     ┌───┐└─┬─┘├───────┤     ┌───┐└─┬─┘├───┤├─────┤├───┤     ┌───┐└─┬─┘  │  »
# «q_3: ──────────┤ X ├┤ RZ(0) ├──────────┤ X ├┤ H ├┤ SDG ├┤ H ├─────┤ X ├──┼──┤ RZ(0) ├─────┤ X ├──┼──┤ H ├┤ S ├┤ H ├─────┤ X ├──┼──┤ RZ(0) ├─────┤ X ├──┼──┤ H ├┤ SDG ├┤ H ├─────┤ X ├──┼────┼──»
# «          ┌───┐└─┬─┘├───────┤     ┌───┐└─┬─┘├───┤├─────┤├───┤┌───┐└─┬─┘  │  ├───────┤┌───┐└─┬─┘  │  ├───┤├───┤├───┤┌───┐└─┬─┘  │  ├───────┤┌───┐└─┬─┘  │  ├───┤├─────┤├───┤┌───┐└─┬─┘  │    │  »
# «q_4: ─────┤ X ├──┼──┤ RZ(0) ├─────┤ X ├──┼──┤ H ├┤ SDG ├┤ H ├┤ X ├──┼────┼──┤ RZ(0) ├┤ X ├──┼────┼──┤ H ├┤ S ├┤ H ├┤ X ├──┼────┼──┤ RZ(0) ├┤ X ├──┼────┼──┤ H ├┤ SDG ├┤ H ├┤ X ├──┼────┼────┼──»
# «     ┌───┐└─┬─┘  │  ├───────┤┌───┐└─┬─┘  │  ├───┤├─────┤├───┤└─┬─┘  │    │  └───────┘└─┬─┘  │    │  └───┘└───┘└───┘└─┬─┘  │    │  └───────┘└─┬─┘  │    │  └───┘└─────┘└───┘└─┬─┘  │    │    │  »
# «q_5: ┤ X ├──┼────┼──┤ RZ(0) ├┤ X ├──┼────┼──┤ H ├┤ SDG ├┤ H ├──┼────┼────┼─────────────┼────┼────┼───────────────────┼────┼────┼─────────────┼────┼────┼─────────────────────■────┼────┼────┼──»
# «     └─┬─┘  │    │  └───────┘└─┬─┘  │    │  ├───┤├─────┤├───┤  │    │    │             │    │    │  ┌───┐┌───┐┌───┐  │    │    │             │    │    │  ┌───┐┌─────┐┌───┐       │    │    │  »
# «q_6: ──■────┼────┼─────────────■────┼────┼──┤ H ├┤ SDG ├┤ H ├──■────┼────┼─────────────■────┼────┼──┤ H ├┤ S ├┤ H ├──■────┼────┼─────────────■────┼────┼──┤ H ├┤ SDG ├┤ H ├───────■────┼────┼──»
# «            │    │                  │    │  ├───┤├─────┤├───┤       │    │                  │    │  ├───┤├───┤├───┤       │    │                  │    │  ├───┤├─────┤├───┤            │    │  »
# «q_7: ───────■────┼──────────────────■────┼──┤ H ├┤ SDG ├┤ H ├───────■────┼──────────────────■────┼──┤ H ├┤ S ├┤ H ├───────■────┼──────────────────■────┼──┤ H ├┤ SDG ├┤ H ├────────────■────┼──»
# «                 │                       │  ├───┤├─────┤├───┤            │                       │  ├───┤├───┤├───┤            │                       │  ├───┤├─────┤├───┤                 │  »
# «q_8: ────────────■───────────────────────■──┤ H ├┤ SDG ├┤ H ├────────────■───────────────────────■──┤ H ├┤ S ├┤ H ├────────────■───────────────────────■──┤ H ├┤ SDG ├┤ H ├─────────────────■──»
# «                                            └───┘└─────┘└───┘                                       └───┘└───┘└───┘                                       └───┘└─────┘└───┘                    »
# «                                                                                                                                  ┌───┐┌───────┐               ┌───┐┌───┐┌───┐┌───┐               »
# «q_0: ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├┤ RZ(0) ├───────────────┤ X ├┤ H ├┤ S ├┤ H ├───────────────»
# «     ┌───────┐               ┌───┐┌───┐┌───┐┌───┐               ┌───┐┌───────┐               ┌───┐┌───┐┌─────┐┌───┐          ┌───┐└─┬─┘├───────┤          ┌───┐└─┬─┘├───┤├───┤├───┤          ┌───┐»
# «q_1: ┤ RZ(0) ├───────────────┤ X ├┤ H ├┤ S ├┤ H ├───────────────┤ X ├┤ RZ(0) ├───────────────┤ X ├┤ H ├┤ SDG ├┤ H ├──────────┤ X ├──┼──┤ RZ(0) ├──────────┤ X ├──┼──┤ H ├┤ S ├┤ H ├──────────┤ X ├»
# «     ├───────┤          ┌───┐└─┬─┘├───┤├───┤├───┤          ┌───┐└─┬─┘├───────┤          ┌───┐└─┬─┘├───┤├─────┤├───┤     ┌───┐└─┬─┘  │  ├───────┤     ┌───┐└─┬─┘  │  ├───┤├───┤├───┤     ┌───┐└─┬─┘»
# «q_2: ┤ RZ(0) ├──────────┤ X ├──┼──┤ H ├┤ S ├┤ H ├──────────┤ X ├──┼──┤ RZ(0) ├──────────┤ X ├──┼──┤ H ├┤ SDG ├┤ H ├─────┤ X ├──┼────┼──┤ RZ(0) ├─────┤ X ├──┼────┼──┤ H ├┤ S ├┤ H ├─────┤ X ├──┼──»
# «     ├───────┤     ┌───┐└─┬─┘  │  ├───┤├───┤├───┤     ┌───┐└─┬─┘  │  ├───────┤     ┌───┐└─┬─┘  │  ├───┤├─────┤├───┤┌───┐└─┬─┘  │    │  ├───────┤┌───┐└─┬─┘  │    │  ├───┤├───┤├───┤┌───┐└─┬─┘  │  »
# «q_3: ┤ RZ(0) ├─────┤ X ├──┼────┼──┤ H ├┤ S ├┤ H ├─────┤ X ├──┼────┼──┤ RZ(0) ├─────┤ X ├──┼────┼──┤ H ├┤ SDG ├┤ H ├┤ X ├──┼────┼────┼──┤ RZ(0) ├┤ X ├──┼────┼────┼──┤ H ├┤ S ├┤ H ├┤ X ├──┼────┼──»
# «     ├───────┤┌───┐└─┬─┘  │    │  ├───┤├───┤├───┤┌───┐└─┬─┘  │    │  ├───────┤┌───┐└─┬─┘  │    │  ├───┤├─────┤├───┤└─┬─┘  │    │    │  └───────┘└─┬─┘  │    │    │  └───┘└───┘└───┘└─┬─┘  │    │  »
# «q_4: ┤ RZ(0) ├┤ X ├──┼────┼────┼──┤ H ├┤ S ├┤ H ├┤ X ├──┼────┼────┼──┤ RZ(0) ├┤ X ├──┼────┼────┼──┤ H ├┤ SDG ├┤ H ├──┼────┼────┼────┼─────────────┼────┼────┼────┼───────────────────┼────┼────┼──»
# «     └───────┘└─┬─┘  │    │    │  ├───┤├───┤├───┤└─┬─┘  │    │    │  └───────┘└─┬─┘  │    │    │  ├───┤├─────┤├───┤  │    │    │    │             │    │    │    │  ┌───┐┌───┐┌───┐  │    │    │  »
# «q_5: ───────────■────┼────┼────┼──┤ H ├┤ S ├┤ H ├──■────┼────┼────┼─────────────■────┼────┼────┼──┤ H ├┤ SDG ├┤ H ├──■────┼────┼────┼─────────────■────┼────┼────┼──┤ H ├┤ S ├┤ H ├──■────┼────┼──»
# «                     │    │    │  ├───┤├───┤├───┤       │    │    │                  │    │    │  ├───┤├─────┤├───┤       │    │    │                  │    │    │  ├───┤├───┤├───┤       │    │  »
# «q_6: ────────────────■────┼────┼──┤ H ├┤ S ├┤ H ├───────■────┼────┼──────────────────■────┼────┼──┤ H ├┤ SDG ├┤ H ├───────■────┼────┼──────────────────■────┼────┼──┤ H ├┤ S ├┤ H ├───────■────┼──»
# «                          │    │  ├───┤├───┤├───┤            │    │                       │    │  ├───┤├─────┤├───┤            │    │                       │    │  ├───┤├───┤├───┤            │  »
# «q_7: ─────────────────────■────┼──┤ H ├┤ S ├┤ H ├────────────■────┼───────────────────────■────┼──┤ H ├┤ SDG ├┤ H ├────────────■────┼───────────────────────■────┼──┤ H ├┤ S ├┤ H ├────────────■──»
# «                               │  ├───┤├───┤├───┤                 │                            │  ├───┤├─────┤├───┤                 │                            │  ├───┤├───┤├───┤               »
# «q_8: ──────────────────────────■──┤ H ├┤ S ├┤ H ├─────────────────■────────────────────────────■──┤ H ├┤ SDG ├┤ H ├─────────────────■────────────────────────────■──┤ H ├┤ S ├┤ H ├───────────────»
# «                                  └───┘└───┘└───┘                                                 └───┘└─────┘└───┘                                                 └───┘└───┘└───┘               »
# «     ┌───┐┌───────┐               ┌───┐┌───┐┌─────┐┌───┐               ┌───┐┌───────┐               ┌───┐┌───┐┌───┐┌───┐               ┌───┐┌───────┐               ┌───┐┌───┐┌─────┐┌───┐          »
# «q_0: ┤ X ├┤ RZ(0) ├───────────────┤ X ├┤ H ├┤ SDG ├┤ H ├───────────────┤ X ├┤ RZ(0) ├───────────────┤ X ├┤ H ├┤ S ├┤ H ├───────────────┤ X ├┤ RZ(0) ├───────────────┤ X ├┤ H ├┤ SDG ├┤ H ├──────────»
# «     └─┬─┘├───────┤          ┌───┐└─┬─┘├───┤├─────┤├───┤          ┌───┐└─┬─┘├───────┤          ┌───┐└─┬─┘├───┤├───┤├───┤          ┌───┐└─┬─┘├───────┤          ┌───┐└─┬─┘├───┤├─────┤├───┤     ┌───┐»
# «q_1: ──┼──┤ RZ(0) ├──────────┤ X ├──┼──┤ H ├┤ SDG ├┤ H ├──────────┤ X ├──┼──┤ RZ(0) ├──────────┤ X ├──┼──┤ H ├┤ S ├┤ H ├──────────┤ X ├──┼──┤ RZ(0) ├──────────┤ X ├──┼──┤ H ├┤ SDG ├┤ H ├─────┤ X ├»
# «       │  ├───────┤     ┌───┐└─┬─┘  │  ├───┤├─────┤├───┤     ┌───┐└─┬─┘  │  ├───────┤     ┌───┐└─┬─┘  │  ├───┤├───┤├───┤     ┌───┐└─┬─┘  │  ├───────┤     ┌───┐└─┬─┘  │  ├───┤├─────┤├───┤┌───┐└─┬─┘»
# «q_2: ──┼──┤ RZ(0) ├─────┤ X ├──┼────┼──┤ H ├┤ SDG ├┤ H ├─────┤ X ├──┼────┼──┤ RZ(0) ├─────┤ X ├──┼────┼──┤ H ├┤ S ├┤ H ├─────┤ X ├──┼────┼──┤ RZ(0) ├─────┤ X ├──┼────┼──┤ H ├┤ SDG ├┤ H ├┤ X ├──┼──»
# «       │  ├───────┤┌───┐└─┬─┘  │    │  ├───┤├─────┤├───┤┌───┐└─┬─┘  │    │  ├───────┤┌───┐└─┬─┘  │    │  ├───┤├───┤├───┤┌───┐└─┬─┘  │    │  ├───────┤┌───┐└─┬─┘  │    │  ├───┤├─────┤├───┤└─┬─┘  │  »
# «q_3: ──┼──┤ RZ(0) ├┤ X ├──┼────┼────┼──┤ H ├┤ SDG ├┤ H ├┤ X ├──┼────┼────┼──┤ RZ(0) ├┤ X ├──┼────┼────┼──┤ H ├┤ S ├┤ H ├┤ X ├──┼────┼────┼──┤ RZ(0) ├┤ X ├──┼────┼────┼──┤ H ├┤ SDG ├┤ H ├──┼────┼──»
# «       │  └───────┘└─┬─┘  │    │    │  └───┘└─────┘└───┘└─┬─┘  │    │    │  └───────┘└─┬─┘  │    │    │  ├───┤├───┤├───┤└─┬─┘  │    │    │  └───────┘└─┬─┘  │    │    │  ├───┤├─────┤├───┤  │    │  »
# «q_4: ──┼─────────────┼────┼────┼────┼─────────────────────■────┼────┼────┼─────────────■────┼────┼────┼──┤ H ├┤ S ├┤ H ├──■────┼────┼────┼─────────────■────┼────┼────┼──┤ H ├┤ SDG ├┤ H ├──■────┼──»
# «       │             │    │    │    │  ┌───┐┌─────┐┌───┐       │    │    │                  │    │    │  ├───┤├───┤├───┤       │    │    │                  │    │    │  ├───┤├─────┤├───┤       │  »
# «q_5: ──┼─────────────■────┼────┼────┼──┤ H ├┤ SDG ├┤ H ├───────■────┼────┼──────────────────■────┼────┼──┤ H ├┤ S ├┤ H ├───────■────┼────┼──────────────────■────┼────┼──┤ H ├┤ SDG ├┤ H ├───────■──»
# «       │                  │    │    │  ├───┤├─────┤├───┤            │    │                       │    │  ├───┤├───┤├───┤            │    │                       │    │  ├───┤├─────┤├───┤          »
# «q_6: ──┼──────────────────■────┼────┼──┤ H ├┤ SDG ├┤ H ├────────────■────┼───────────────────────■────┼──┤ H ├┤ S ├┤ H ├────────────■────┼───────────────────────■────┼──┤ H ├┤ SDG ├┤ H ├──────────»
# «       │                       │    │  ├───┤├─────┤├───┤                 │                            │  ├───┤├───┤├───┤                 │                            │  ├───┤└─────┘└───┘          »
# «q_7: ──┼───────────────────────■────┼──┤ H ├┤ SDG ├┤ H ├─────────────────■────────────────────────────■──┤ H ├┤ S ├┤ H ├─────────────────■────────────────────────────■──┤ H ├──────────────────────»
# «       │                            │  ├───┤└─────┘└───┘                                                 └───┘└───┘└───┘                                                 └───┘                      »
# «q_8: ──■────────────────────────────■──┤ H ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                                       └───┘                                                                                                                                                        »
# «     ┌───┐┌───────┐          ┌───┐┌───┐┌───┐┌───┐          ┌───┐┌───────┐          ┌───┐┌───┐┌─────┐         ┌───┐                             ┌───┐          ┌───────┐                         »
# «q_0: ┤ X ├┤ RZ(0) ├──────────┤ X ├┤ H ├┤ S ├┤ H ├──────────┤ X ├┤ RZ(0) ├──────────┤ X ├┤ H ├┤ SDG ├─────────┤ H ├─────────────────────────────┤ X ├──────────┤ RZ(0) ├─────────────────────────»
# «     └─┬─┘├───────┤     ┌───┐└─┬─┘├───┤├───┤├───┤     ┌───┐└─┬─┘├───────┤     ┌───┐└─┬─┘├───┤├─────┤         ├───┤               ┌───┐         └─┬─┘          ├───────┤                         »
# «q_1: ──┼──┤ RZ(0) ├─────┤ X ├──┼──┤ H ├┤ S ├┤ H ├─────┤ X ├──┼──┤ RZ(0) ├─────┤ X ├──┼──┤ H ├┤ SDG ├─────────┤ H ├───────────────┤ X ├───────────┼────────────┤ RZ(0) ├─────────────────────────»
# «       │  ├───────┤┌───┐└─┬─┘  │  ├───┤├───┤├───┤┌───┐└─┬─┘  │  ├───────┤┌───┐└─┬─┘  │  ├───┤├─────┤         ├───┤          ┌───┐└─┬─┘           │            ├───────┤          ┌───┐          »
# «q_2: ──┼──┤ RZ(0) ├┤ X ├──┼────┼──┤ H ├┤ S ├┤ H ├┤ X ├──┼────┼──┤ RZ(0) ├┤ X ├──┼────┼──┤ H ├┤ SDG ├─────────┤ H ├──────────┤ X ├──┼─────────────┼────────────┤ RZ(0) ├──────────┤ X ├──────────»
# «       │  └───────┘└─┬─┘  │    │  └───┘└───┘└───┘└─┬─┘  │    │  └───────┘└─┬─┘  │    │  └───┘└─────┘         └───┘          └─┬─┘  │             │            └───────┘          └─┬─┘          »
# «q_3: ──┼─────────────┼────┼────┼───────────────────┼────┼────┼─────────────┼────┼────┼────────────────────────────────────────■────┼─────────────┼─────────────────────────────────■────────────»
# «       │             │    │    │  ┌───┐┌───┐┌───┐  │    │    │             │    │    │  ┌───┐┌─────┐         ┌───┐                 │             │                                              »
# «q_4: ──┼─────────────■────┼────┼──┤ H ├┤ S ├┤ H ├──■────┼────┼─────────────■────┼────┼──┤ H ├┤ SDG ├─────────┤ H ├─────────────────■─────────────┼──────────────────────────────────────────────»
# «       │                  │    │  ├───┤├───┤├───┤       │    │                  │    │  ├───┤├─────┤         ├───┤                               │                                              »
# «q_5: ──┼──────────────────■────┼──┤ H ├┤ S ├┤ H ├───────■────┼──────────────────■────┼──┤ H ├┤ SDG ├─────────┤ H ├───────────────────────────────■──────────────────────────────────────────────»
# «       │                       │  ├───┤├───┤├───┤            │                       │  ├───┤└┬───┬┘┌────────┴───┴─────────┐┌───┐┌───┐┌──────────────────────┐  ┌───┐  ┌───────────────────────┐»
# «q_6: ──■───────────────────────■──┤ H ├┤ S ├┤ H ├────────────■───────────────────────■──┤ H ├─┤ X ├─┤ RZ(12.5597195485498) ├┤ X ├┤ X ├┤ RZ(12.5597195485498) ├──┤ X ├──┤ RZ(-18.1923909729127) ├»
# «                                  └───┘└───┘└───┘                                       └───┘ └─┬─┘ └──────────────────────┘└─┬─┘└─┬─┘└──────────────────────┘  └─┬─┘  └─────────┬───┬─────────┘»
# «q_7: ───────────────────────────────────────────────────────────────────────────────────────────■─────────────────────────────■────┼──────────────────────────────┼──────────────┤ X ├──────────»
# «                                                                                                                                   │                              │              └─┬─┘          »
# «q_8: ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────■──────────────────────────────■────────────────■────────────»
# «                                                                                                                                                                                                »
# «                             ┌───┐          ┌───┐           ┌───┐ ┌───┐                ┌───┐┌───────┐          ┌───┐   ┌───┐   ┌─────┐┌───┐       ┌───┐┌───────┐           ┌───┐┌───┐┌───┐┌───┐     »
# «q_0: ────────────────────────┤ X ├──────────┤ H ├───────────┤ S ├─┤ H ├────────────────┤ X ├┤ RZ(0) ├──────────┤ X ├───┤ H ├───┤ SDG ├┤ H ├───────┤ X ├┤ RZ(0) ├───────────┤ X ├┤ H ├┤ S ├┤ H ├─────»
# «              ┌───┐          └─┬─┘          ├───┤           ├───┤ ├───┤        ┌───┐   └─┬─┘├───────┤     ┌───┐└─┬─┘   ├───┤   ├─────┤├───┤ ┌───┐ └─┬─┘├───────┤   ┌───┐   └─┬─┘├───┤├───┤├───┤┌───┐»
# «q_1: ─────────┤ X ├────────────┼────────────┤ H ├───────────┤ S ├─┤ H ├────────┤ X ├─────┼──┤ RZ(0) ├─────┤ X ├──┼─────┤ H ├───┤ SDG ├┤ H ├─┤ X ├───┼──┤ RZ(0) ├───┤ X ├─────┼──┤ H ├┤ S ├┤ H ├┤ X ├»
# «              └─┬─┘            │            ├───┤           ├───┤ ├───┤┌───┐   └─┬─┘     │  ├───────┤┌───┐└─┬─┘  │     ├───┤   ├─────┤├───┤ └─┬─┘   │  └───────┘   └─┬─┘     │  └───┘└───┘└───┘└─┬─┘»
# «q_2: ───────────┼──────────────┼────────────┤ H ├───────────┤ S ├─┤ H ├┤ X ├─────┼───────┼──┤ RZ(0) ├┤ X ├──┼────┼─────┤ H ├───┤ SDG ├┤ H ├───┼─────┼────────────────┼───────┼───────────────────┼──»
# «                │              │            ├───┤           ├───┤ ├───┤└─┬─┘     │       │  └───────┘└─┬─┘  │    │     ├───┤   ├─────┤├───┤   │     │                │       │  ┌───┐┌───┐┌───┐  │  »
# «q_3: ───────────┼──────────────┼────────────┤ H ├───────────┤ S ├─┤ H ├──■───────┼───────┼─────────────■────┼────┼─────┤ H ├───┤ SDG ├┤ H ├───■─────┼────────────────■───────┼──┤ H ├┤ S ├┤ H ├──■──»
# «                │              │            ├───┤           ├───┤ ├───┤          │       │                  │    │     ├───┤   ├─────┤├───┤         │                        │  ├───┤├───┤├───┤     »
# «q_4: ───────────■──────────────┼────────────┤ H ├───────────┤ S ├─┤ H ├──────────■───────┼──────────────────■────┼─────┤ H ├───┤ SDG ├┤ H ├─────────■────────────────────────■──┤ H ├┤ S ├┤ H ├─────»
# «                               │            ├───┤           ├───┤ ├───┤                  │                       │     ├───┤   └─────┘└───┘                                     └───┘└───┘└───┘     »
# «q_5: ──────────────────────────■────────────┤ H ├───────────┤ S ├─┤ H ├──────────────────■───────────────────────■─────┤ H ├────────────────────────────────────────────────────────────────────────»
# «             ┌─────┐         ┌───┐          └───┘           └───┘ └───┘                                                └───┘                             ┌───┐  ┌─────────┐┌───┐┌───┐┌───┐┌───┐┌───┐»
# «q_6: ────────┤ SDG ├─────────┤ H ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├──┤ RZ(-2π) ├┤ X ├┤ H ├┤ S ├┤ H ├┤ X ├»
# «     ┌───────┴─────┴────────┐├───┤┌───────────────────────┐┌─────┐┌───┐┌───┐┌─────────┐┌───┐  ┌───┐  ┌───┐┌───┐┌───┐┌─────────┐ ┌───┐ ┌───┐┌─────┐┌───┐  └─┬─┘  └─────────┘└─┬─┘└───┘└───┘└───┘└─┬─┘»
# «q_7: ┤ RZ(13.7624468800499) ├┤ X ├┤ RZ(-19.4420222827308) ├┤ SDG ├┤ H ├┤ X ├┤ RZ(-2π) ├┤ X ├──┤ H ├──┤ S ├┤ H ├┤ X ├┤ RZ(-2π) ├─┤ X ├─┤ H ├┤ SDG ├┤ H ├────┼─────────────────┼───────────────────┼──»
# «     └──────────────────────┘└─┬─┘├───────────────────────┤├─────┤├───┤└─┬─┘└─────────┘└─┬─┘  ├───┤  ├───┤├───┤└─┬─┘└─────────┘ └─┬─┘ ├───┤├─────┤├───┤    │                 │  ┌───┐┌───┐┌───┐  │  »
# «q_8: ──────────────────────────■──┤ RZ(-19.4795800229045) ├┤ SDG ├┤ H ├──■───────────────■────┤ H ├──┤ S ├┤ H ├──■────────────────■───┤ H ├┤ SDG ├┤ H ├────■─────────────────■──┤ H ├┤ S ├┤ H ├──■──»
# «                                  └───────────────────────┘└─────┘└───┘                       └───┘  └───┘└───┘                       └───┘└─────┘└───┘                         └───┘└───┘└───┘     »
# «        ┌───┐   ┌───────┐      ┌───┐ ┌───┐┌─────┐   ┌───┐        ┌───┐┌───────┐     ┌───┐   ┌───┐   ┌───┐┌───┐       ┌───┐┌───────┐     ┌───┐┌───┐┌─────┐┌───┐┌───┐┌───────┐┌───┐┌───┐┌───┐┌───┐┌───┐»
# «q_0: ───┤ X ├───┤ RZ(0) ├──────┤ X ├─┤ H ├┤ SDG ├───┤ H ├────────┤ X ├┤ RZ(0) ├─────┤ X ├───┤ H ├───┤ S ├┤ H ├───────┤ X ├┤ RZ(0) ├─────┤ X ├┤ H ├┤ SDG ├┤ H ├┤ X ├┤ RZ(0) ├┤ X ├┤ H ├┤ S ├┤ H ├┤ X ├»
# «        └─┬─┘   ├───────┤┌───┐ └─┬─┘ ├───┤├─────┤   ├───┤   ┌───┐└─┬─┘├───────┤┌───┐└─┬─┘   ├───┤   ├───┤├───┤ ┌───┐ └─┬─┘├───────┤┌───┐└─┬─┘├───┤├─────┤├───┤└─┬─┘└───────┘└─┬─┘└───┘└───┘└───┘└─┬─┘»
# «q_1: ─────┼─────┤ RZ(0) ├┤ X ├───┼───┤ H ├┤ SDG ├───┤ H ├───┤ X ├──┼──┤ RZ(0) ├┤ X ├──┼─────┤ H ├───┤ S ├┤ H ├─┤ X ├───┼──┤ RZ(0) ├┤ X ├──┼──┤ H ├┤ SDG ├┤ H ├──┼─────────────┼───────────────────┼──»
# «          │     └───────┘└─┬─┘   │   └───┘└─────┘   └───┘   └─┬─┘  │  └───────┘└─┬─┘  │     ├───┤   ├───┤├───┤ └─┬─┘   │  └───────┘└─┬─┘  │  ├───┤├─────┤├───┤  │             │  ┌───┐┌───┐┌───┐  │  »
# «q_2: ─────┼────────────────┼─────┼────────────────────────────■────┼─────────────■────┼─────┤ H ├───┤ S ├┤ H ├───■─────┼─────────────■────┼──┤ H ├┤ SDG ├┤ H ├──■─────────────■──┤ H ├┤ S ├┤ H ├──■──»
# «          │                │     │   ┌───┐┌─────┐   ┌───┐          │                  │     ├───┤   ├───┤├───┤         │                  │  ├───┤└─────┘└───┘                   └───┘└───┘└───┘     »
# «q_3: ─────┼────────────────■─────┼───┤ H ├┤ SDG ├───┤ H ├──────────■──────────────────■─────┤ H ├───┤ S ├┤ H ├─────────■──────────────────■──┤ H ├───────────────────────────────────────────────────»
# «          │                      │   ├───┤└─────┘   └───┘                                   └───┘   └───┘└───┘                               └───┘                                                   »
# «q_4: ─────■──────────────────────■───┤ H ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                                     └───┘                                                                                                                                                           »
# «q_5: ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «     ┌─────────┐  ┌───┐  ┌───┐┌─────┐┌───┐ ┌───┐ ┌─────────┐┌───┐┌───┐  ┌───┐  ┌───┐┌───┐┌─────────┐┌───┐┌───┐┌─────┐┌───┐                                                                           »
# «q_6: ┤ RZ(-2π) ├──┤ X ├──┤ H ├┤ SDG ├┤ H ├─┤ X ├─┤ RZ(-2π) ├┤ X ├┤ H ├──┤ S ├──┤ H ├┤ X ├┤ RZ(-2π) ├┤ X ├┤ H ├┤ SDG ├┤ H ├───────────────────────────────────────────────────────────────────────────»
# «     └─────────┘  └─┬─┘  └───┘└─────┘└───┘ └─┬─┘ └─────────┘└─┬─┘├───┤  ├───┤  ├───┤└─┬─┘└─────────┘└─┬─┘├───┤├─────┤├───┤                                                                           »
# «q_7: ───────────────┼────────────────────────■────────────────■──┤ H ├──┤ S ├──┤ H ├──■───────────────■──┤ H ├┤ SDG ├┤ H ├───────────────────────────────────────────────────────────────────────────»
# «                    │    ┌───┐┌─────┐┌───┐                       └───┘  └───┘  └───┘                     └───┘└─────┘└───┘                                                                           »
# «q_8: ───────────────■────┤ H ├┤ SDG ├┤ H ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                         └───┘└─────┘└───┘                                                                                                                                                           »
# «     ┌───────┐┌───┐┌───┐┌─────┐┌───┐┌───┐┌───────┐┌───┐┌───┐┌───┐┌───┐┌───┐┌───────┐┌───┐┌───┐┌───┐┌──────────────────────┐┌───┐┌───┐┌──────────────────────┐┌───┐┌───┐┌──────────────────────┐»
# «q_0: ┤ RZ(0) ├┤ X ├┤ H ├┤ SDG ├┤ H ├┤ X ├┤ RZ(0) ├┤ X ├┤ H ├┤ S ├┤ H ├┤ X ├┤ RZ(0) ├┤ X ├┤ H ├┤ X ├┤ RZ(10.8989605745270) ├┤ X ├┤ X ├┤ RZ(10.8989605745270) ├┤ X ├┤ X ├┤ RZ(1.54936752330446) ├»
# «     └───────┘└─┬─┘└───┘└─────┘└───┘└─┬─┘└───────┘└─┬─┘├───┤├───┤├───┤└─┬─┘└───────┘└─┬─┘├───┤└─┬─┘└──────────────────────┘└─┬─┘└─┬─┘└──────────────────────┘└─┬─┘└─┬─┘└────────┬───┬─────────┘»
# «q_1: ───────────┼─────────────────────■─────────────■──┤ H ├┤ S ├┤ H ├──■─────────────■──┤ H ├──■────────────────────────────■────┼────────────────────────────┼────┼───────────┤ X ├──────────»
# «                │  ┌───┐                               └───┘└───┘└───┘                   └───┘                                    │                            │    │           └─┬─┘          »
# «q_2: ───────────■──┤ H ├──────────────────────────────────────────────────────────────────────────────────────────────────────────■────────────────────────────■────┼─────────────■────────────»
# «                   └───┘                                                                                                                                            │                          »
# «q_3: ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────■──────────────────────────»
# «                                                                                                                                                                                               »
# «q_4: ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                                                                                                               »
# «q_5: ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                                                                                                               »
# «q_6: ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                                                                                                               »
# «q_7: ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                                                                                                               »
# «q_8: ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                                                                                                               »
# «                             ┌───┐     ┌───┐┌───────────────────────┐                         ┌───┐     ┌───┐┌──────────────────────┐                                                 ┌───┐»
# «q_0: ────────────────────────┤ X ├─────┤ X ├┤ RZ(0.493208055464925) ├─────────────────────────┤ X ├─────┤ X ├┤ RZ(1.54936752330446) ├─────────────────────────────────────────────────┤ X ├»
# «     ┌──────────────────────┐└─┬─┘┌───┐└─┬─┘└─────────┬───┬─────────┘┌───────────────────────┐└─┬─┘┌───┐└─┬─┘└────────┬───┬─────────┘┌──────────────────────┐                         └─┬─┘»
# «q_1: ┤ RZ(12.0743874658674) ├──┼──┤ X ├──┼────────────┤ X ├──────────┤ RZ(0.529009645345227) ├──┼──┤ X ├──┼───────────┤ X ├──────────┤ RZ(1.62700256095995) ├───────────────────────────┼──»
# «     └──────────────────────┘  │  └─┬─┘  │            └─┬─┘          └───────────────────────┘  │  └─┬─┘  │           └─┬─┘          └────────┬───┬─────────┘┌───────────────────────┐  │  »
# «q_2: ──────────────────────────┼────■────┼──────────────┼───────────────────────────────────────┼────┼────┼─────────────┼─────────────────────┤ X ├──────────┤ RZ(0.493208055464925) ├──┼──»
# «                               │         │              │                                       │    │    │             │                     └─┬─┘          └───────────────────────┘  │  »
# «q_3: ──────────────────────────■─────────┼──────────────■───────────────────────────────────────┼────■────┼─────────────┼───────────────────────■───────────────────────────────────────┼──»
# «                                         │                                                      │         │             │                                                               │  »
# «q_4: ────────────────────────────────────■──────────────────────────────────────────────────────■─────────┼─────────────■───────────────────────────────────────────────────────────────┼──»
# «                                                                                                          │                                                                             │  »
# «q_5: ─────────────────────────────────────────────────────────────────────────────────────────────────────■─────────────────────────────────────────────────────────────────────────────■──»
# «                                                                                                                                                                                           »
# «q_6: ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                                                                                                           »
# «q_7: ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                                                                                                           »
# «q_8: ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                                                                                                           »
# «     ┌───────────────────────┐┌─────┐┌───┐                                                                                                                                           »
# «q_0: ┤ RZ(-16.5334792553702) ├┤ SDG ├┤ H ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «     └─────────┬───┬─────────┘└─────┘├───┤┌───────────────────────┐                        ┌───┐┌───────────────────────┐┌─────┐         ┌───┐                                       »
# «q_1: ──────────┤ X ├─────────────────┤ X ├┤ RZ(0.493208055464925) ├────────────────────────┤ X ├┤ RZ(-16.9212523197880) ├┤ SDG ├─────────┤ H ├───────────────────────────────────────»
# «               └─┬─┘           ┌───┐ └─┬─┘└─────────┬───┬─────────┘┌──────────────────────┐└─┬─┘└─────────┬───┬─────────┘└┬───┬┘┌────────┴───┴─────────┐                        ┌───┐»
# «q_2: ────────────┼─────────────┤ X ├───┼────────────┤ X ├──────────┤ RZ(1.59120097107965) ├──┼────────────┤ X ├───────────┤ X ├─┤ RZ(1.04920398170448) ├────────────────────────┤ X ├»
# «                 │             └─┬─┘   │            └─┬─┘          └──────────────────────┘  │            └─┬─┘           └─┬─┘ └────────┬───┬─────────┘┌──────────────────────┐└─┬─┘»
# «q_3: ────────────┼───────────────■─────┼──────────────┼──────────────────────────────────────┼──────────────┼───────────────┼────────────┤ X ├──────────┤ RZ(11.0527698092541) ├──┼──»
# «                 │                     │              │                                      │              │               │            └─┬─┘          └──────────────────────┘  │  »
# «q_4: ────────────■─────────────────────┼──────────────■──────────────────────────────────────┼──────────────■───────────────┼──────────────■──────────────────────────────────────┼──»
# «                                       │                                                     │                              │                                                     │  »
# «q_5: ──────────────────────────────────■─────────────────────────────────────────────────────■──────────────────────────────■─────────────────────────────────────────────────────■──»
# «                                                                                                                                                                                     »
# «q_6: ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                                                                                                     »
# «q_7: ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                                                                                                     »
# «q_8: ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                                                                                                     »
# «                                                                                                                                                                                                      »
# «q_0: ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                                                                                                                      »
# «q_1: ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «     ┌───────────────────────┐┌─────┐         ┌───┐                                                                                                                                                   »
# «q_2: ┤ RZ(-17.9258394026263) ├┤ SDG ├─────────┤ H ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «     └─────────┬───┬─────────┘└┬───┬┘┌────────┴───┴─────────┐┌───┐┌───────────────────────┐        ┌─────┐         ┌───┐                                                                              »
# «q_3: ──────────┤ X ├───────────┤ X ├─┤ RZ(12.1147600730587) ├┤ X ├┤ RZ(-17.0781717312422) ├────────┤ SDG ├─────────┤ H ├──────────────────────────────────────────────────────────────────────────────»
# «               └─┬─┘           └─┬─┘ └──────────────────────┘└─┬─┘└─────────┬───┬─────────┘┌───────┴─────┴────────┐├───┤┌───────────────────────┐┌─────┐┌───┐                                         »
# «q_4: ────────────■───────────────┼─────────────────────────────┼────────────┤ X ├──────────┤ RZ(11.0169682193738) ├┤ X ├┤ RZ(-17.1204073028770) ├┤ SDG ├┤ H ├─────────────────────────────────────────»
# «                                 │                             │            └─┬─┘          └──────────────────────┘└─┬─┘├───────────────────────┤├─────┤├───┤┌───┐┌─────────┐┌───┐┌───┐┌───┐┌───┐┌───┐»
# «q_5: ────────────────────────────■─────────────────────────────■──────────────■──────────────────────────────────────■──┤ RZ(-18.0827588140804) ├┤ SDG ├┤ H ├┤ X ├┤ RZ(-2π) ├┤ X ├┤ H ├┤ S ├┤ H ├┤ X ├»
# «                                                                                                                        └───────────────────────┘└─────┘└───┘└─┬─┘└─────────┘└─┬─┘└───┘└───┘└───┘└─┬─┘»
# «q_6: ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────┼───────────────────┼──»
# ...
# «q_4: ──■────┼────┼────┼──┤ H ├┤ SDG ├┤ H ├──■────┼────┼─────────────────────────────■────┼────┼──┤ H ├┤ S ├┤ H ├──■────┼────┼─────────────────────────────■────┼────┼──┤ H ├┤ SDG ├┤ H ├───────■──»
# «            │    │    │  ├───┤├─────┤├───┤       │    │                                  │    │  ├───┤├───┤├───┤       │    │                                  │    │  ├───┤├─────┤├───┤          »
# «q_5: ───────■────┼────┼──┤ H ├┤ SDG ├┤ H ├───────■────┼──────────────────────────────────■────┼──┤ H ├┤ S ├┤ H ├───────■────┼──────────────────────────────────■────┼──┤ H ├┤ SDG ├┤ H ├──────────»
# «                 │    │  ├───┤├─────┤├───┤            │                                       │  ├───┤├───┤├───┤            │                                       │  ├───┤└─────┘└───┘          »
# «q_6: ────────────■────┼──┤ H ├┤ SDG ├┤ H ├────────────■───────────────────────────────────────■──┤ H ├┤ S ├┤ H ├────────────■───────────────────────────────────────■──┤ H ├──────────────────────»
# «                      │  ├───┤└─────┘└───┘                                                       └───┘└───┘└───┘                                                       └───┘                      »
# «q_7: ─────────────────■──┤ H ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                         └───┘                                                                                                                                                                    »
# «q_8: ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                                                                                                                  »
# «     ┌───┐┌───────────────────────┐          ┌───┐┌───┐┌───┐┌───┐          ┌───┐┌───────────────────────┐          ┌───┐┌───┐┌─────┐┌───┐     ┌───┐┌───────────────────────┐     ┌───┐┌───┐┌───┐┌───┐»
# «q_0: ┤ X ├┤ RZ(-3.15080072494598) ├──────────┤ X ├┤ H ├┤ S ├┤ H ├──────────┤ X ├┤ RZ(-3.15080072494598) ├──────────┤ X ├┤ H ├┤ SDG ├┤ H ├─────┤ X ├┤ RZ(-3.15080072494598) ├─────┤ X ├┤ H ├┤ S ├┤ H ├»
# «     └─┬─┘├───────────────────────┤     ┌───┐└─┬─┘├───┤├───┤├───┤     ┌───┐└─┬─┘├───────────────────────┤     ┌───┐└─┬─┘├───┤├─────┤├───┤┌───┐└─┬─┘├───────────────────────┤┌───┐└─┬─┘├───┤├───┤├───┤»
# «q_1: ──┼──┤ RZ(-3.15080072494598) ├─────┤ X ├──┼──┤ H ├┤ S ├┤ H ├─────┤ X ├──┼──┤ RZ(-3.15080072494598) ├─────┤ X ├──┼──┤ H ├┤ SDG ├┤ H ├┤ X ├──┼──┤ RZ(-3.15080072494598) ├┤ X ├──┼──┤ H ├┤ S ├┤ H ├»
# «       │  ├───────────────────────┤┌───┐└─┬─┘  │  ├───┤├───┤├───┤┌───┐└─┬─┘  │  ├───────────────────────┤┌───┐└─┬─┘  │  ├───┤├─────┤├───┤└─┬─┘  │  └───────────────────────┘└─┬─┘  │  └───┘└───┘└───┘»
# «q_2: ──┼──┤ RZ(-3.15080072494598) ├┤ X ├──┼────┼──┤ H ├┤ S ├┤ H ├┤ X ├──┼────┼──┤ RZ(-3.15080072494598) ├┤ X ├──┼────┼──┤ H ├┤ SDG ├┤ H ├──┼────┼─────────────────────────────┼────┼─────────────────»
# «       │  └───────────────────────┘└─┬─┘  │    │  ├───┤├───┤├───┤└─┬─┘  │    │  └───────────────────────┘└─┬─┘  │    │  ├───┤├─────┤├───┤  │    │                             │    │  ┌───┐┌───┐┌───┐»
# «q_3: ──┼─────────────────────────────■────┼────┼──┤ H ├┤ S ├┤ H ├──■────┼────┼─────────────────────────────■────┼────┼──┤ H ├┤ SDG ├┤ H ├──■────┼─────────────────────────────■────┼──┤ H ├┤ S ├┤ H ├»
# «       │                                  │    │  ├───┤├───┤├───┤       │    │                                  │    │  ├───┤├─────┤├───┤       │                                  │  ├───┤├───┤├───┤»
# «q_4: ──┼──────────────────────────────────■────┼──┤ H ├┤ S ├┤ H ├───────■────┼──────────────────────────────────■────┼──┤ H ├┤ SDG ├┤ H ├───────■──────────────────────────────────■──┤ H ├┤ S ├┤ H ├»
# «       │                                       │  ├───┤├───┤├───┤            │                                       │  ├───┤└─────┘└───┘                                             └───┘└───┘└───┘»
# «q_5: ──■───────────────────────────────────────■──┤ H ├┤ S ├┤ H ├────────────■───────────────────────────────────────■──┤ H ├────────────────────────────────────────────────────────────────────────»
# «                                                  └───┘└───┘└───┘                                                       └───┘                                                                        »
# «q_6: ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                                                                                                                     »
# «q_7: ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                                                                                                                     »
# «q_8: ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                                                                                                                     »
# «          ┌───┐┌───────────────────────┐     ┌───┐┌───┐┌─────┐┌───┐     ┌───┐┌───────────────────────┐     ┌───┐┌───┐┌───┐┌───┐     ┌───┐┌───────────────────────┐     ┌───┐┌───┐┌─────┐┌───┐┌───┐»
# «q_0: ─────┤ X ├┤ RZ(-3.15080072494598) ├─────┤ X ├┤ H ├┤ SDG ├┤ H ├─────┤ X ├┤ RZ(-3.15080072494598) ├─────┤ X ├┤ H ├┤ S ├┤ H ├─────┤ X ├┤ RZ(-3.15080072494598) ├─────┤ X ├┤ H ├┤ SDG ├┤ H ├┤ X ├»
# «     ┌───┐└─┬─┘├───────────────────────┤┌───┐└─┬─┘├───┤├─────┤├───┤┌───┐└─┬─┘├───────────────────────┤┌───┐└─┬─┘├───┤├───┤├───┤┌───┐└─┬─┘├───────────────────────┤┌───┐└─┬─┘├───┤├─────┤├───┤└─┬─┘»
# «q_1: ┤ X ├──┼──┤ RZ(-3.15080072494598) ├┤ X ├──┼──┤ H ├┤ SDG ├┤ H ├┤ X ├──┼──┤ RZ(-3.15080072494598) ├┤ X ├──┼──┤ H ├┤ S ├┤ H ├┤ X ├──┼──┤ RZ(-3.15080072494598) ├┤ X ├──┼──┤ H ├┤ SDG ├┤ H ├──┼──»
# «     └─┬─┘  │  └───────────────────────┘└─┬─┘  │  └───┘└─────┘└───┘└─┬─┘  │  └───────────────────────┘└─┬─┘  │  ├───┤├───┤├───┤└─┬─┘  │  └───────────────────────┘└─┬─┘  │  ├───┤├─────┤├───┤  │  »
# «q_2: ──┼────┼─────────────────────────────┼────┼─────────────────────■────┼─────────────────────────────■────┼──┤ H ├┤ S ├┤ H ├──■────┼─────────────────────────────■────┼──┤ H ├┤ SDG ├┤ H ├──■──»
# «       │    │                             │    │  ┌───┐┌─────┐┌───┐       │                                  │  ├───┤├───┤├───┤       │                                  │  ├───┤└─────┘└───┘     »
# «q_3: ──■────┼─────────────────────────────■────┼──┤ H ├┤ SDG ├┤ H ├───────■──────────────────────────────────■──┤ H ├┤ S ├┤ H ├───────■──────────────────────────────────■──┤ H ├─────────────────»
# «            │                                  │  ├───┤└─────┘└───┘                                             └───┘└───┘└───┘                                             └───┘                 »
# «q_4: ───────■──────────────────────────────────■──┤ H ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                                                  └───┘                                                                                                                                           »
# «q_5: ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                                                                                                                  »
# «q_6: ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                                                                                                                  »
# «q_7: ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                                                                                                                  »
# «q_8: ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «                                                                                                                                                                                                  »
# «     ┌───────────────────────┐┌───┐┌───┐┌───┐┌───┐┌───┐┌───────────────────────┐┌───┐┌───┐┌─────┐┌───┐┌───┐┌───────────────────────┐┌───┐┌───┐┌───┐┌───┐┌───┐┌───────────────────────┐┌───┐┌───┐
# «q_0: ┤ RZ(-3.15080072494598) ├┤ X ├┤ H ├┤ S ├┤ H ├┤ X ├┤ RZ(-3.15080072494598) ├┤ X ├┤ H ├┤ SDG ├┤ H ├┤ X ├┤ RZ(-3.15080072494598) ├┤ X ├┤ H ├┤ S ├┤ H ├┤ X ├┤ RZ(-3.15080072494598) ├┤ X ├┤ H ├
# «     └───────────────────────┘└─┬─┘└───┘└───┘└───┘└─┬─┘└───────────────────────┘└─┬─┘└───┘└─────┘└───┘└─┬─┘└───────────────────────┘└─┬─┘├───┤├───┤├───┤└─┬─┘└───────────────────────┘└─┬─┘├───┤
# «q_1: ───────────────────────────┼───────────────────┼─────────────────────────────┼─────────────────────■─────────────────────────────■──┤ H ├┤ S ├┤ H ├──■─────────────────────────────■──┤ H ├
# «                                │  ┌───┐┌───┐┌───┐  │                             │  ┌───┐                                               └───┘└───┘└───┘                                   └───┘
# «q_2: ───────────────────────────■──┤ H ├┤ S ├┤ H ├──■─────────────────────────────■──┤ H ├──────────────────────────────────────────────────────────────────────────────────────────────────────
# «                                   └───┘└───┘└───┘                                   └───┘
# «q_3: ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# «
# «q_4: ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# «
# «q_5: ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# «
# «q_6: ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# «
# «q_7: ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# «
# «q_8: ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# «
# Minimum: 2.972330965212265, prob_s: 0.0382696392997337
# p=2
# Minim_exp_val_L: 2.9613219247413163, prob_s_L: 0.04046230458286011
# Comparison (t=1): B_next: 2.9042810741185505, B_before: 2.972330965212265
# Time for intialising with perturbed values 1 no. of times: 90.52836322784424
# Minim_exp_val_B: 2.9042810741185505, prob_s_B: 0.05092140802003463
# Length_B: 4
# Optimal_L: [0.23934911791302688, 1.3155159080259997, -1.4566775440530486, -0.6011150273330638]
# Optimal_B: [0.9348655276819583, 1.1670567957625892, 2.877406389815614, 1.2150117193441334], length: 4
# p=3
# Minim_exp_val_L: 2.9613219165109648, prob_s_L: 0.04046105434853806
# Comparison (t=1): B_next: 2.8004455831871535, B_before: 2.9042810741185505
# Time for intialising with perturbed values 1 no. of times: 191.608877658844
# Minim_exp_val_B: 2.8004455831871535, prob_s_B: 0.07809002034099967
# Length_B: 6
# Optimal_L: [0.13865583767877546, 0.7245558637000059, 1.4620528017749839, -1.5236116748948696, -1.112806504728394, -0.406379135084107]
# Optimal_B: [-1.5261021580914533, -2.227532080149361, -2.839039565232308, -2.987590952348388, -2.2494228166127224, -0.8125831436105951], length: 6
# p=4
# Minim_exp_val_L: 2.961321912533494, prob_s_L: 0.040462043909086004
# Comparison (t=1): B_next: 2.6872688437651586, B_before: 2.8004455831871535
# Time for intialising with perturbed values 1 no. of times: 363.92508363723755
# Minim_exp_val_B: 2.6872688437651586, prob_s_B: 0.08398667369290648
# Length_B: 8
# Optimal_L: [0.09814231405211474, 0.44924317032655464, 1.0316351047120278, 1.5165808545344173, -1.5472876495637462, -1.3098482586647036, -0.8734404769926672, -0.30626977437821756]
# Optimal_B: [-0.24519971698489895, -0.05088592405403661, 1.6742753316582697, 1.2012478142345167, 3.003253817607002, 2.630317924785707, 1.7532149416122997, 0.6530689668950237], length: 8
# p=5
# Minim_exp_val_L: 2.9613219092431518, prob_s_L: 0.04046123230483908
# Comparison (t=1): B_next: 2.6687517678021067, B_before: 2.6872688437651586
# Time for intialising with perturbed values 1 no. of times: 617.0630397796631
# Minim_exp_val_B: 2.6687517678021067, prob_s_B: 0.08492810954518114
# Length_B: 10
# Optimal_L: [0.07629573740451415, 0.3145324653857159, 0.7245557961315158, 1.2086824126204008, 1.5424100070866844, -1.558289131882701, -1.4044017176959784, -1.1128077237638798, -0.7133540923572581, -0.2455669690089546]
# Optimal_B: [1.0961131362542509, -1.5025312757078095, 1.7267380131911945, 1.2473906921800386, 1.2767267231671628, 3.0113708839177717, 2.8129766958416917, 2.221303455110829, 1.4528726325591441, 0.5215285282393248], length: 10
# [0.0382696392997337, 0.05092140802003463, 0.07809002034099967, 0.08398667369290648, 0.08492810954518114]
# Time Taken: 1303.5015070438385

# %%
def n_qbit_mixer(n):
    from qiskit.circuit.parameter import Parameter
#     from qiskit.circuit.parametervector import ParameterVector
    
    t = Parameter('t')
    s = Parameter('s')
    qc = QuantumCircuit(n)
    qc_two = QuantumCircuit(2)
    qc_two.sdg(1)
    qc_two.cx(1,0)
    qc_two.ry(-2*t,1)
    qc_two.cx(0,1)
    qc_two.ry(2*t,1)
    qc_two.cx(1,0)
    qc_two.s(0)
    if n%2:
        for i in range(int((n-1)/2)):
            qc.append(qc_two,(2*i,2*i+1))
            qc.swap(2*i,2*i+1)
        for i in range(int((n-1)/2)):
            qc.append(qc_two,(2*i+1,2*i+2))
            qc.swap(2*i+1,2*i+2)
        for i in range(int((n-1)/2)):
            qc.append(qc_two,(2*i,2*i+1))
            qc.swap(2*i,2*i+1)
        for i in range(int((n-1)/2)):
            qc.append(qc_two,(2*i+1,2*i+2))
    else:
        for i in range(int((n)/2)):
            qc.append(qc_two,(2*i,2*i+1))
            qc.swap(2*i,2*i+1)
        for i in range(1,int((n)/2)):
            qc.append(qc_two,(2*i-1,2*i))
            qc.swap(2*i-1,2*i)
        for i in range(int((n)/2)):
            qc.append(qc_two,(2*i,2*i+1))
            qc.swap(2*i,2*i+1)
        for i in range(1,int((n)/2)):
            qc.append(qc_two,(2*i-1,2*i))
    
    return qc

# %%
n=9
    t = Parameter('t')
    qc = QuantumCircuit(n)
    qc_two = QuantumCircuit(2)
    qc_two.sdg(1)
    qc_two.cx(1,0)
    qc_two.ry(-2*t,1)
    qc_two.cx(0,1)
    qc_two.ry(2*t,1)
    qc_two.cx(1,0)
    qc_two.s(0)
    if n%2:
        for i in range(int((n-1)/2)):
            qc.append(qc_two,(2*i,2*i+1))
            qc.swap(2*i,2*i+1)
        for i in range(int((n-1)/2)):
            qc.append(qc_two,(2*i+1,2*i+2))
            qc.swap(2*i+1,2*i+2)
        for i in range(int((n-1)/2)):
            qc.append(qc_two,(2*i,2*i+1))
            qc.swap(2*i,2*i+1)
        for i in range(int((n-1)/2)):
            qc.append(qc_two,(2*i+1,2*i+2))
    else:
        for i in range(int((n)/2)):
            qc.append(qc_two,(2*i,2*i+1))
            qc.swap(2*i,2*i+1)
        for i in range(1,int((n)/2)):
            qc.append(qc_two,(2*i-1,2*i))
            qc.swap(2*i-1,2*i)
        for i in range(int((n)/2)):
            qc.append(qc_two,(2*i,2*i+1))
            qc.swap(2*i,2*i+1)
        for i in range(1,int((n)/2)):
            qc.append(qc_two,(2*i-1,2*i))

# %%
qc.draw(fold=200)
# Out:
#      ┌─────────────────────┐                             ┌─────────────────────┐
# q_0: ┤0                    ├─X───────────────────────────┤0                    ├─X────────────────────────
#      │  circuit-8815597(t) │ │ ┌─────────────────────┐   │  circuit-8815597(t) │ │ ┌─────────────────────┐
# q_1: ┤1                    ├─X─┤0                    ├─X─┤1                    ├─X─┤0                    ├
#      ├─────────────────────┤   │  circuit-8815597(t) │ │ ├─────────────────────┤   │  circuit-8815597(t) │
# q_2: ┤0                    ├─X─┤1                    ├─X─┤0                    ├─X─┤1                    ├
#      │  circuit-8815597(t) │ │ ├─────────────────────┤   │  circuit-8815597(t) │ │ ├─────────────────────┤
# q_3: ┤1                    ├─X─┤0                    ├─X─┤1                    ├─X─┤0                    ├
#      ├─────────────────────┤   │  circuit-8815597(t) │ │ ├─────────────────────┤   │  circuit-8815597(t) │
# q_4: ┤0                    ├─X─┤1                    ├─X─┤0                    ├─X─┤1                    ├
#      │  circuit-8815597(t) │ │ ├─────────────────────┤   │  circuit-8815597(t) │ │ ├─────────────────────┤
# q_5: ┤1                    ├─X─┤0                    ├─X─┤1                    ├─X─┤0                    ├
#      ├─────────────────────┤   │  circuit-8815597(t) │ │ ├─────────────────────┤   │  circuit-8815597(t) │
# q_6: ┤0                    ├─X─┤1                    ├─X─┤0                    ├─X─┤1                    ├
#      │  circuit-8815597(t) │ │ ├─────────────────────┤   │  circuit-8815597(t) │ │ ├─────────────────────┤
# q_7: ┤1                    ├─X─┤0                    ├─X─┤1                    ├─X─┤0                    ├
#      └─────────────────────┘   │  circuit-8815597(t) │ │ └─────────────────────┘   │  circuit-8815597(t) │
# q_8: ──────────────────────────┤1                    ├─X───────────────────────────┤1                    ├
#                                └─────────────────────┘                             └─────────────────────┘

# %%
def ansatz(n, reps, operator):
    from qiskit.circuit.parameter import Parameter
#     from qiskit.circuit.parametervector import ParameterVector
    
    t = Parameter('t')
    s = Parameter('s')
    qc = QuantumCircuit(n)
    qc_two = QuantumCircuit(2)
    qc_two.sdg(1)
    qc_two.cx(1,0)
    qc_two.rz(2*s,0)
    qc_two.ry(-2*t,1)
    qc_two.cx(0,1)
    qc_two.ry(2*t,1)
    qc_two.cx(1,0)
    qc_two.s(0)
    for op in operator:
        op = op.to_pauli_op()
        op_str = str(op.primitive)
        op_coeff = op.coeff
        i_j = [n-i-1 for i in range(len(string)) if op_str.startswith('Z', i)]
        if op_str.count('Z') == 1:
            i = i_j[0]
            qc.rz(2*s*op_coeff, i)
            qc.rx(2*t, i)
        if op_str.count('Z') == 2:
            i, j = i_j
            qc.append(qc_two.assign_parameters({s:op_coeff*s}), (i,j))
    final = QuantumCircuit(n)
    for rep in range(reps):
        t_p = Parameter('t_{}'.format(rep))
        s_p = Parameter('s_{}'.format(rep))
        final.append(qc.assign_parameters({t:t_p, s:s_p}), range(n))
#     print(qc_two.draw(fold=200))
#     print(qc.draw(fold=200))
#     print(final.draw(fold=200))
    return final

def construct_initial_state(no_cars, no_routes):
    """[summary]

    Args:
        args ([type]): [description]

    Returns:
        [type]: [description]
    """
    R = no_routes
    N = no_cars
    #Using gates
    w_one = QuantumCircuit(R)
    for r in range(0,R-1):
        if r == 0:
            w_one.ry(2*np.arccos(1/np.sqrt(R-r)),r)
        elif r != R-1:
            w_one.cry(2*np.arccos(1/np.sqrt(R-r)), r-1, r)
    for r in range(1,R):
        w_one.cx(R-r-1,R-r)
    w_one.x(0)

    # #Using Initial Instruction
    # w_one = QuantumCircuit(R)
    # probs = [0 for _ in range(2**R)]
    # for i in range(R):
    #     probs[2**i] += 1/np.sqrt(R)
    # w_one.initialize(probs)

    #Tensor product for N cars
    initial_state = w_one.copy()
    for _ in range(0,N-1):
        initial_state = initial_state.tensor(w_one)
    return initial_state, w_one

# %%
with open('qubos_{}_car_{}_routes/qubo_{}.pkl'.format(3, 3, 3), 'rb') as f:
    qubo, max_coeff, operator, offset, routes = pkl.load(f)

classical_result = solve_classically(qubo)   
x_arr = classical_result.x
x_str = arr_to_str(x_arr)
no_qubits = len(x_arr)

sort_values = get_costs(qubo, no_qubits)

#         print("_"*50)
#         print("10 lowest states:")
#         avg = 0
#         for i in range(27):
#             print(sort_values[i])
#             avg += sort_values[i][1]
#         print("_"*50)
#         print("Avg: {}".format(avg/27))
ground_energy = sort_values[0][1]
x_s = [x_str]
for i in range(1,10):
    if np.round(sort_values[i][1], 4) == np.round(ground_energy, 4):
        print("Other ground state(s) found: '{}'".format(sort_values[i][0]))
        x_s.append(sort_values[i][0])
# Out:
# optimal function value: 3.960833000000001
# optimal value: [0. 1. 0. 1. 0. 0. 1. 0. 0.]
# status: SUCCESS
# Other ground state(s) found: '001010001'

# %%
from qiskit.algorithms import VQE

# %%
p=1
backend = Aer.get_backend('statevector_simulator')
quantum_instance = QuantumInstance(backend)
initial_state, _ = construct_initial_state(3,3)
qc = ansatz(9,p, operator)
initial_state.append(qc, range(3*3))
# print(transpile(initial_state, basis_gates = ['id', 'rx', 'ry', 'rz', 'cx']).draw(fold=200))
vqe = VQE(ansatz = initial_state, optimizer = Basin(), include_custom=True, quantum_instance = quantum_instance, initial_point = [np.random.rand() for _ in range(2*p)])

# %%
results = vqe.compute_minimum_eigenvalue(operator)

# %%
probs = Statevector(results.eigenstate).probabilities_dict()
p_s = 0
for string in x_s:
    p_s += probs[string] if string in probs else 0

# %%
p_s
# Out:
# 0.08110346961657475

# %%
next_point = interp_point(results.optimal_point)

# %%
p=2
backend = Aer.get_backend('statevector_simulator')
quantum_instance = QuantumInstance(backend)
initial_state, _ = construct_initial_state(3,3)
qc = ansatz(9,p, operator)
initial_state.append(qc, range(3*3))
# print(transpile(initial_state, basis_gates = ['id', 'rx', 'ry', 'rz', 'cx']).draw(fold=200))
vqe = VQE(ansatz = initial_state, optimizer = SLSQP(), include_custom=True, quantum_instance = quantum_instance, initial_point = next_point)
results = vqe.compute_minimum_eigenvalue(operator)
probs = Statevector(results.eigenstate).probabilities_dict()
p_s = 0
for string in x_s:
    p_s += probs[string] if string in probs else 0
print(p_s)
next_point = interp_point(results.optimal_point)
# Out:
# 0.09065994989428619

# %%
p=3
backend = Aer.get_backend('statevector_simulator')
quantum_instance = QuantumInstance(backend)
initial_state, _ = construct_initial_state(3,3)
qc = ansatz(9,p, operator)
initial_state.append(qc, range(3*3))
# print(transpile(initial_state, basis_gates = ['id', 'rx', 'ry', 'rz', 'cx']).draw(fold=200))
vqe = VQE(ansatz = initial_state, optimizer = SLSQP(), include_custom=True, quantum_instance = quantum_instance, initial_point = next_point)
results = vqe.compute_minimum_eigenvalue(operator)
probs = Statevector(results.eigenstate).probabilities_dict()
p_s = 0
for string in x_s:
    p_s += probs[string] if string in probs else 0
print(p_s)
next_point = interp_point(results.optimal_point)
# Out:
# 0.09034449870658118

# %%
p=4
backend = Aer.get_backend('statevector_simulator')
quantum_instance = QuantumInstance(backend)
initial_state, _ = construct_initial_state(3,3)
qc = ansatz(9,p, operator)
initial_state.append(qc, range(3*3))
# print(transpile(initial_state, basis_gates = ['id', 'rx', 'ry', 'rz', 'cx']).draw(fold=200))
vqe = VQE(ansatz = initial_state, optimizer = SLSQP(), include_custom=True, quantum_instance = quantum_instance, initial_point = next_point)
results = vqe.compute_minimum_eigenvalue(operator)
probs = Statevector(results.eigenstate).probabilities_dict()
p_s = 0
for string in x_s:
    p_s += probs[string] if string in probs else 0
print(p_s)
next_point = interp_point(results.optimal_point)
# Out:
# 0.09610226742493658

# %%
# This code is part of Qiskit.
#
# (C) Copyright IBM 2018, 2020.
#
# This code is licensed under the Apache License, Version 2.0. You may
# obtain a copy of this license in the LICENSE.txt file in the root directory
# of this source tree or at http://www.apache.org/licenses/LICENSE-2.0.
#
# Any modifications or derivative works of this code must retain this
# copyright notice, and modified files need to carry a notice indicating
# that they have been altered from the originals.

"""Sequential Least SQuares Programming optimizer"""

from typing import Optional

from scipy.optimize import minimize, basinhopping
from qiskit.algorithms.optimizers.optimizer import Optimizer, OptimizerSupportLevel

"""
scipy.optimize.minimize(fun, x0, args=(), method=None, jac=None, hess=None, hessp=None, bounds=None, constraints=(), tol=None, callback=None, options=None)
scipy.optimize.basinhopping(func, x0, niter=100, T=1.0, stepsize=0.5, minimizer_kwargs=None, take_step=None, accept_test=None, callback=None, interval=50, disp=False, niter_success=None, seed=None)[
"""
class Basin(Optimizer):

    _OPTIONS = ['maxiter', 'disp', 'ftol', 'eps']

    # pylint: disable=unused-argument
    def __init__(self,
                 maxiter: int = 100,
                 disp: bool = False,
                 ftol: float = 1e-06,
                 tol: Optional[float] = None,
                 eps: float = 1.4901161193847656e-08) -> None:
        """
        Args:
            maxiter: Maximum number of iterations.
            disp: Set to True to print convergence messages.
            ftol: Precision goal for the value of f in the stopping criterion.
            tol: Tolerance for termination.
            eps: Step size used for numerical approximation of the Jacobian.
        """
        super().__init__()
        for k, v in list(locals().items()):
            if k in self._OPTIONS:
                self._options[k] = v
        self._tol = tol

    def get_support_level(self):
        """ Return support level dictionary """
        return {
            'gradient': OptimizerSupportLevel.supported,
            'bounds': OptimizerSupportLevel.supported,
            'initial_point': OptimizerSupportLevel.required
        }

    def optimize(self, num_vars, objective_function, gradient_function=None,
                 variable_bounds=None, initial_point=None):
        super().optimize(num_vars, objective_function,
                         gradient_function, variable_bounds, initial_point)

        if gradient_function is None and self._max_evals_grouped > 1:
            epsilon = self._options['eps']
            gradient_function = Optimizer.wrap_function(Optimizer.gradient_num_diff,
                                                        (objective_function, epsilon,
                                                         self._max_evals_grouped))
        minimizer_kwargs = {"method": "slsqp", "jac":gradient_function, "tol":self._tol, "bounds":variable_bounds}
        res = basinhopping(objective_function, initial_point, niter=100, T=1.0, stepsize=0.05*np.pi, minimizer_kwargs=None, take_step=None, accept_test=None, callback=None, interval=50, disp=False, niter_success=None, seed=None)
        return res.x, res.fun, res.nfev


class Global_Optimizer(Optimizer):

    _OPTIONS = ['maxiter', 'disp', 'ftol', 'eps']

    # pylint: disable=unused-argument
    def __init__(self,
                 maxiter: int = 100,
                 disp: bool = False,
                 ftol: float = 1e-06,
                 tol: Optional[float] = None,
                 eps: float = 1.4901161193847656e-08,
                n_calls: int=100) -> None:
        """Iteration No: 1 started. Evaluating function at random point.
Iteration No: 1 ended. Evaluation done at random point.
Time taken: 0.2034
Function value obtained: 0
        Args:
            maxiter: Maximum number of iterations.
            disp: Set to True to print convergence messages.
            ftol: Precision goal for the value of f in the stopping criterion.
            tol: Tolerance for termination.
            eps: Step size used for numerical approximation of the Jacobian.
        """
        super().__init__()
        self.n_calls = n_calls
        for k, v in list(locals().items()):
            if k in self._OPTIONS:
                self._options[k] = v
        self._tol = tol

    def get_support_level(self):
        """ Return support level dictionary """
        return {
            'gradient': OptimizerSupportLevel.supported,
            'bounds': OptimizerSupportLevel.supported,
            'initial_point': OptimizerSupportLevel.required
        }

    def optimize(self, num_vars, objective_function, gradient_function=None,
                 variable_bounds=None, initial_point=None):
        super().optimize(num_vars, objective_function,
                         gradient_function, variable_bounds, initial_point)

        if gradient_function is None and self._max_evals_grouped > 1:
            epsilon = self._options['eps']
            gradient_function = Optimizer.wrap_function(Optimizer.gradient_num_diff,
                                                        (objective_function, epsilon,
                                                         self._max_evals_grouped))
        minimizer_kwargs = {"method": "slsqp", "jac":gradient_function, "tol":self._tol, "bounds":variable_bounds}
#         res = basinhopping(objective_function, initial_point, niter=100, T=1.0, stepsize=0.05*np.pi, minimizer_kwargs=None, take_step=None, accept_test=None, callback=None, interval=50, disp=False, niter_success=None, seed=None)
        res = gp_minimize(objective_function,
                  variable_bounds,      # the bounds on each dimension of x
                  acq_func="gp_hedge",      # the acquisition function
                  n_calls=self.n_calls,         # the number of evaluations of f
                  n_initial_points = 10,  # the number of random initialization points
                  noise="gaussian",       # the noise
                  random_state=1234, # the random seed
                    verbose = True,
                 n_jobs = -1)   
        return res.x, res.fun, -1

# %%
p=5
backend = Aer.get_backend('statevector_simulator')
quantum_instance = QuantumInstance(backend)
initial_state, _ = construct_initial_state(3,3)
qc = ansatz(9,p, operator)
initial_state.append(qc, range(3*3))
# print(transpile(initial_state, basis_gates = ['id', 'rx', 'ry', 'rz', 'cx']).draw(fold=200))
vqe = VQE(ansatz = initial_state, optimizer = SLSQP(), include_custom=True, quantum_instance = quantum_instance, initial_point = next_point)
results = vqe.compute_minimum_eigenvalue(operator)
probs = Statevector(results.eigenstate).probabilities_dict()
p_s = 0
for string in x_s:
    p_s += probs[string] if string in probs else 0
print(p_s)
next_point = interp_point(results.optimal_point)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-701-7418d71c2a23> in <module>
#       7 # print(transpile(initial_state, basis_gates = ['id', 'rx', 'ry', 'rz', 'cx']).draw(fold=200))
#       8 vqe = VQE(ansatz = initial_state, optimizer = SLSQP(), include_custom=True, quantum_instance = quantum_instance, initial_point = next_point)
# ----> 9 results = vqe.compute_minimum_eigenvalue(operator)
#      10 probs = Statevector(results.eigenstate).probabilities_dict()
#      11 p_s = 0
#
# ~/anaconda3/envs/ox/lib/python3.9/site-packages/qiskit/algorithms/minimum_eigen_solvers/vqe.py in compute_minimum_eigenvalue(self, operator, aux_operators)
#     410         if not self._expect_op:
#     411             self._expect_op = self.construct_expectation(self._ansatz_params, operator)
# --> 412         vqresult = self.find_minimum(initial_point=self.initial_point,
#     413                                      ansatz=self.ansatz,
#     414                                      cost_fn=self._energy_evaluation,
#
# ~/anaconda3/envs/ox/lib/python3.9/site-packages/qiskit/algorithms/variational_algorithm.py in find_minimum(self, initial_point, ansatz, cost_fn, optimizer, gradient_fn)
#     178
#     179         if initial_point is not None and len(initial_point) != nparms:
# --> 180             raise ValueError(
#     181                 'Initial point size {} and parameter size {} mismatch'.format(
#     182                     len(initial_point), nparms))
#
# ValueError: Initial point size 8 and parameter size 10 mismatch

# %%
p=6
backend = Aer.get_backend('statevector_simulator')
quantum_instance = QuantumInstance(backend)
initial_state, _ = construct_initial_state(3,3)
qc = ansatz(9,p, operator)
initial_state.append(qc, range(3*3))
# print(transpile(initial_state, basis_gates = ['id', 'rx', 'ry', 'rz', 'cx']).draw(fold=200))
vqe = VQE(ansatz = initial_state, optimizer = SLSQP(), include_custom=True, quantum_instance = quantum_instance, initial_point = next_point)
results = vqe.compute_minimum_eigenvalue(operator)
probs = Statevector(results.eigenstate).probabilities_dict()
p_s = 0
for string in x_s:
    p_s += probs[string] if string in probs else 0
print(p_s)
next_point = interp_point(results.optimal_point)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-702-c1acad7c44f3> in <module>
#       7 # print(transpile(initial_state, basis_gates = ['id', 'rx', 'ry', 'rz', 'cx']).draw(fold=200))
#       8 vqe = VQE(ansatz = initial_state, optimizer = SLSQP(), include_custom=True, quantum_instance = quantum_instance, initial_point = next_point)
# ----> 9 results = vqe.compute_minimum_eigenvalue(operator)
#      10 probs = Statevector(results.eigenstate).probabilities_dict()
#      11 p_s = 0
#
# ~/anaconda3/envs/ox/lib/python3.9/site-packages/qiskit/algorithms/minimum_eigen_solvers/vqe.py in compute_minimum_eigenvalue(self, operator, aux_operators)
#     410         if not self._expect_op:
#     411             self._expect_op = self.construct_expectation(self._ansatz_params, operator)
# --> 412         vqresult = self.find_minimum(initial_point=self.initial_point,
#     413                                      ansatz=self.ansatz,
#     414                                      cost_fn=self._energy_evaluation,
#
# ~/anaconda3/envs/ox/lib/python3.9/site-packages/qiskit/algorithms/variational_algorithm.py in find_minimum(self, initial_point, ansatz, cost_fn, optimizer, gradient_fn)
#     178
#     179         if initial_point is not None and len(initial_point) != nparms:
# --> 180             raise ValueError(
#     181                 'Initial point size {} and parameter size {} mismatch'.format(
#     182                     len(initial_point), nparms))
#
# ValueError: Initial point size 8 and parameter size 12 mismatch

# %%
p=7
backend = Aer.get_backend('statevector_simulator')
quantum_instance = QuantumInstance(backend)
initial_state, _ = construct_initial_state(3,3)
qc = ansatz(9,p, operator)
initial_state.append(qc, range(3*3))
# print(transpile(initial_state, basis_gates = ['id', 'rx', 'ry', 'rz', 'cx']).draw(fold=200))
vqe = VQE(ansatz = initial_state, optimizer = SLSQP(), include_custom=True, quantum_instance = quantum_instance, initial_point = next_point)
results = vqe.compute_minimum_eigenvalue(operator)
probs = Statevector(results.eigenstate).probabilities_dict()
p_s = 0
for string in x_s:
    p_s += probs[string] if string in probs else 0
print(p_s)
next_point = interp_point(results.optimal_point)
# Out:
# 0.14367295051505313

# %%
p=1
backend = Aer.get_backend('statevector_simulator')
quantum_instance = QuantumInstance(backend)
initial_state, _ = construct_initial_state(3,3)
qc = ansatz(9,p, operator)
initial_state.append(qc, range(3*3))
initial_state.parameter_bounds = [(-2*np.pi, 2*np.pi)]*initial_state.num_parameters
# print(transpile(initial_state, basis_gates = ['id', 'rx', 'ry', 'rz', 'cx']).draw(fold=200))
vqe = VQE(ansatz = initial_state, optimizer = Global_Optimizer(), include_custom=True, quantum_instance = quantum_instance, initial_point = [np.random.rand() for _ in range(2*p)])
results = vqe.compute_minimum_eigenvalue(operator)
probs = Statevector(results.eigenstate).probabilities_dict()
p_s = 0
for string in x_s:
    p_s += probs[string] if string in probs else 0
print(p_s)
next_point = list(results.optimal_point)
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 0.0594
# Function value obtained: 13.1202
# Current minimum: 13.1202
# Iteration No: 2 started. Evaluating function at random point.
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 0.0194
# Function value obtained: -8.6161
# Current minimum: -8.6161
# Iteration No: 3 started. Evaluating function at random point.
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 0.0181
# Function value obtained: 8.7978
# Current minimum: -8.6161
# Iteration No: 4 started. Evaluating function at random point.
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 0.0178
# Function value obtained: -0.3223
# Current minimum: -8.6161
# Iteration No: 5 started. Evaluating function at random point.
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 0.0176
# Function value obtained: 6.2805
# Current minimum: -8.6161
# Iteration No: 6 started. Evaluating function at random point.
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 0.0181
# Function value obtained: -15.2365
# Current minimum: -15.2365
# Iteration No: 7 started. Evaluating function at random point.
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 0.0181
# Function value obtained: 0.7951
# Current minimum: -15.2365
# Iteration No: 8 started. Evaluating function at random point.
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 0.0178
# Function value obtained: -3.2302
# Current minimum: -15.2365
# Iteration No: 9 started. Evaluating function at random point.
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 0.0188
# Function value obtained: -10.1996
# Current minimum: -15.2365
# Iteration No: 10 started. Evaluating function at random point.
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 1.1158
# Function value obtained: -18.0474
# Current minimum: -18.0474
# Iteration No: 11 started. Searching for the next optimal point.
# Iteration No: 11 ended. Search finished for the next optimal point.
# Time taken: 0.4290
# Function value obtained: -17.4414
# Current minimum: -18.0474
# Iteration No: 12 started. Searching for the next optimal point.
# Iteration No: 12 ended. Search finished for the next optimal point.
# Time taken: 0.4289
# Function value obtained: -12.1064
# Current minimum: -18.0474
# Iteration No: 13 started. Searching for the next optimal point.
# Iteration No: 13 ended. Search finished for the next optimal point.
# Time taken: 0.2031
# Function value obtained: -18.7104
# Current minimum: -18.7104
# Iteration No: 14 started. Searching for the next optimal point.
# Iteration No: 14 ended. Search finished for the next optimal point.
# Time taken: 0.2288
# Function value obtained: -19.0782
# Current minimum: -19.0782
# Iteration No: 15 started. Searching for the next optimal point.
# Iteration No: 15 ended. Search finished for the next optimal point.
# Time taken: 0.2298
# Function value obtained: -18.9753
# Current minimum: -19.0782
# Iteration No: 16 started. Searching for the next optimal point.
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 0.1988
# Function value obtained: -19.0968
# Current minimum: -19.0968
# Iteration No: 17 started. Searching for the next optimal point.
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 0.2965
# Function value obtained: -19.0960
# Current minimum: -19.0968
# Iteration No: 18 started. Searching for the next optimal point.
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 0.2722
# Function value obtained: -19.1044
# Current minimum: -19.1044
# Iteration No: 19 started. Searching for the next optimal point.
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 0.2416
# Function value obtained: -19.0993
# Current minimum: -19.1044
# Iteration No: 20 started. Searching for the next optimal point.
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 0.2540
# Function value obtained: -19.0535
# Current minimum: -19.1044
# Iteration No: 21 started. Searching for the next optimal point.
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 0.3072
# Function value obtained: -19.0422
# Current minimum: -19.1044
# Iteration No: 22 started. Searching for the next optimal point.
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 0.2545
# Function value obtained: -19.1033
# Current minimum: -19.1044
# Iteration No: 23 started. Searching for the next optimal point.
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 0.3462
# Function value obtained: -15.8910
# Current minimum: -19.1044
# Iteration No: 24 started. Searching for the next optimal point.
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 0.5422
# Function value obtained: -19.1095
# Current minimum: -19.1095
# Iteration No: 25 started. Searching for the next optimal point.
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 0.2625
# Function value obtained: -19.0969
# Current minimum: -19.1095
# Iteration No: 26 started. Searching for the next optimal point.
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 0.2704
# Function value obtained: -19.0481
# Current minimum: -19.1095
# Iteration No: 27 started. Searching for the next optimal point.
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 0.2773
# Function value obtained: -19.0793
# Current minimum: -19.1095
# Iteration No: 28 started. Searching for the next optimal point.
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 0.3073
# Function value obtained: -19.0537
# Current minimum: -19.1095
# Iteration No: 29 started. Searching for the next optimal point.
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 0.3128
# Function value obtained: -7.9188
# Current minimum: -19.1095
# Iteration No: 30 started. Searching for the next optimal point.
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 0.3088
# Function value obtained: -19.1027
# Current minimum: -19.1095
# Iteration No: 31 started. Searching for the next optimal point.
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 0.3084
# Function value obtained: -18.5730
# Current minimum: -19.1095
# Iteration No: 32 started. Searching for the next optimal point.
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 0.2954
# Function value obtained: -19.0969
# Current minimum: -19.1095
# Iteration No: 33 started. Searching for the next optimal point.
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 0.3835
# Function value obtained: -17.9809
# Current minimum: -19.1095
# Iteration No: 34 started. Searching for the next optimal point.
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 0.3789
# Function value obtained: -7.7412
# Current minimum: -19.1095
# Iteration No: 35 started. Searching for the next optimal point.
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 0.3245
# Function value obtained: -19.0853
# Current minimum: -19.1095
# Iteration No: 36 started. Searching for the next optimal point.
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 0.3252
# Function value obtained: -19.0518
# Current minimum: -19.1095
# Iteration No: 37 started. Searching for the next optimal point.
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 0.2887
# Function value obtained: -19.0900
# Current minimum: -19.1095
# Iteration No: 38 started. Searching for the next optimal point.
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 0.3231
# Function value obtained: -19.1022
# Current minimum: -19.1095
# Iteration No: 39 started. Searching for the next optimal point.
# Iteration No: 39 ended. Search finished for the next optimal point.
# Time taken: 0.3773
# Function value obtained: -19.0449
# Current minimum: -19.1095
# Iteration No: 40 started. Searching for the next optimal point.
# Iteration No: 40 ended. Search finished for the next optimal point.
# Time taken: 0.3276
# Function value obtained: -15.4742
# Current minimum: -19.1095
# Iteration No: 41 started. Searching for the next optimal point.
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 0.3745
# Function value obtained: -19.1027
# Current minimum: -19.1095
# Iteration No: 42 started. Searching for the next optimal point.
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 0.4036
# Function value obtained: 7.4368
# Current minimum: -19.1095
# Iteration No: 43 started. Searching for the next optimal point.
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 0.3850
# Function value obtained: 5.9774
# Current minimum: -19.1095
# Iteration No: 44 started. Searching for the next optimal point.
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 0.4479
# Function value obtained: -19.1027
# Current minimum: -19.1095
# Iteration No: 45 started. Searching for the next optimal point.
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 0.4857
# Function value obtained: 6.4338
# Current minimum: -19.1095
# Iteration No: 46 started. Searching for the next optimal point.
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 0.3086
# Function value obtained: -4.0024
# Current minimum: -19.1095
# Iteration No: 47 started. Searching for the next optimal point.
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 0.3938
# Function value obtained: 3.5339
# Current minimum: -19.1095
# Iteration No: 48 started. Searching for the next optimal point.
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 0.3911
# Function value obtained: -5.2619
# Current minimum: -19.1095
# Iteration No: 49 started. Searching for the next optimal point.
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 0.3922
# Function value obtained: 2.8910
# Current minimum: -19.1095
# Iteration No: 50 started. Searching for the next optimal point.
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 0.5256
# Function value obtained: -18.2241
# Current minimum: -19.1095
# Iteration No: 51 started. Searching for the next optimal point.
# Iteration No: 51 ended. Search finished for the next optimal point.
# Time taken: 0.3907
# Function value obtained: -18.8705
# Current minimum: -19.1095
# Iteration No: 52 started. Searching for the next optimal point.
# Iteration No: 52 ended. Search finished for the next optimal point.
# Time taken: 0.4361
# Function value obtained: -19.1027
# Current minimum: -19.1095
# Iteration No: 53 started. Searching for the next optimal point.
# Iteration No: 53 ended. Search finished for the next optimal point.
# Time taken: 0.4099
# Function value obtained: 1.5980
# Current minimum: -19.1095
# Iteration No: 54 started. Searching for the next optimal point.
# Iteration No: 54 ended. Search finished for the next optimal point.
# Time taken: 0.7091
# Function value obtained: -19.1027
# Current minimum: -19.1095
# Iteration No: 55 started. Searching for the next optimal point.
# Iteration No: 55 ended. Search finished for the next optimal point.
# Time taken: 0.3652
# Function value obtained: -4.7892
# Current minimum: -19.1095
# Iteration No: 56 started. Searching for the next optimal point.
# Iteration No: 56 ended. Search finished for the next optimal point.
# Time taken: 0.4491
# Function value obtained: -19.1027
# Current minimum: -19.1095
# Iteration No: 57 started. Searching for the next optimal point.
# Iteration No: 57 ended. Search finished for the next optimal point.
# Time taken: 0.5331
# Function value obtained: -19.0951
# Current minimum: -19.1095
# Iteration No: 58 started. Searching for the next optimal point.
# Iteration No: 58 ended. Search finished for the next optimal point.
# Time taken: 0.4928
# Function value obtained: -19.1027
# Current minimum: -19.1095
# Iteration No: 59 started. Searching for the next optimal point.
# Iteration No: 59 ended. Search finished for the next optimal point.
# Time taken: 0.5376
# Function value obtained: -19.1027
# Current minimum: -19.1095
# Iteration No: 60 started. Searching for the next optimal point.
# Iteration No: 60 ended. Search finished for the next optimal point.
# Time taken: 0.5724
# Function value obtained: -19.1027
# Current minimum: -19.1095
# Iteration No: 61 started. Searching for the next optimal point.
# Iteration No: 61 ended. Search finished for the next optimal point.
# Time taken: 0.5739
# Function value obtained: -18.8140
# Current minimum: -19.1095
# Iteration No: 62 started. Searching for the next optimal point.
# Iteration No: 62 ended. Search finished for the next optimal point.
# Time taken: 0.5181
# Function value obtained: 6.0366
# Current minimum: -19.1095
# Iteration No: 63 started. Searching for the next optimal point.
# Iteration No: 63 ended. Search finished for the next optimal point.
# Time taken: 0.5366
# Function value obtained: -18.5576
# Current minimum: -19.1095
# Iteration No: 64 started. Searching for the next optimal point.
# Iteration No: 64 ended. Search finished for the next optimal point.
# Time taken: 0.5161
# Function value obtained: -19.0270
# Current minimum: -19.1095
# Iteration No: 65 started. Searching for the next optimal point.
# Iteration No: 65 ended. Search finished for the next optimal point.
# Time taken: 0.5354
# Function value obtained: -19.0982
# Current minimum: -19.1095
# Iteration No: 66 started. Searching for the next optimal point.
# Iteration No: 66 ended. Search finished for the next optimal point.
# Time taken: 0.7018
# Function value obtained: -19.0613
# Current minimum: -19.1095
# Iteration No: 67 started. Searching for the next optimal point.
# Iteration No: 67 ended. Search finished for the next optimal point.
# Time taken: 0.5343
# Function value obtained: -19.1027
# Current minimum: -19.1095
# Iteration No: 68 started. Searching for the next optimal point.
# Iteration No: 68 ended. Search finished for the next optimal point.
# Time taken: 0.5713
# Function value obtained: -19.1017
# Current minimum: -19.1095
# Iteration No: 69 started. Searching for the next optimal point.
# Iteration No: 69 ended. Search finished for the next optimal point.
# Time taken: 0.5876
# Function value obtained: -19.0915
# Current minimum: -19.1095
# Iteration No: 70 started. Searching for the next optimal point.
# Iteration No: 70 ended. Search finished for the next optimal point.
# Time taken: 0.5947
# Function value obtained: -19.0980
# Current minimum: -19.1095
# Iteration No: 71 started. Searching for the next optimal point.
# Iteration No: 71 ended. Search finished for the next optimal point.
# Time taken: 0.6058
# Function value obtained: 9.0252
# Current minimum: -19.1095
# Iteration No: 72 started. Searching for the next optimal point.
# Iteration No: 72 ended. Search finished for the next optimal point.
# Time taken: 0.6638
# Function value obtained: -13.0609
# Current minimum: -19.1095
# Iteration No: 73 started. Searching for the next optimal point.
# Iteration No: 73 ended. Search finished for the next optimal point.
# Time taken: 0.8558
# Function value obtained: -19.0997
# Current minimum: -19.1095
# Iteration No: 74 started. Searching for the next optimal point.
# Iteration No: 74 ended. Search finished for the next optimal point.
# Time taken: 0.7078
# Function value obtained: -17.8687
# Current minimum: -19.1095
# Iteration No: 75 started. Searching for the next optimal point.
# Iteration No: 75 ended. Search finished for the next optimal point.
# Time taken: 0.5388
# Function value obtained: 5.2315
# Current minimum: -19.1095
# Iteration No: 76 started. Searching for the next optimal point.
# Iteration No: 76 ended. Search finished for the next optimal point.
# Time taken: 0.7034
# Function value obtained: -19.1021
# Current minimum: -19.1095
# Iteration No: 77 started. Searching for the next optimal point.
# Iteration No: 77 ended. Search finished for the next optimal point.
# Time taken: 0.5885
# Function value obtained: -19.1027
# Current minimum: -19.1095
# Iteration No: 78 started. Searching for the next optimal point.
# Iteration No: 78 ended. Search finished for the next optimal point.
# Time taken: 0.6925
# Function value obtained: 1.7646
# Current minimum: -19.1095
# Iteration No: 79 started. Searching for the next optimal point.
# Iteration No: 79 ended. Search finished for the next optimal point.
# Time taken: 0.5928
# Function value obtained: -19.1027
# Current minimum: -19.1095
# Iteration No: 80 started. Searching for the next optimal point.
# Iteration No: 80 ended. Search finished for the next optimal point.
# Time taken: 0.6814
# Function value obtained: -19.1038
# Current minimum: -19.1095
# Iteration No: 81 started. Searching for the next optimal point.
# Iteration No: 81 ended. Search finished for the next optimal point.
# Time taken: 0.6351
# Function value obtained: 9.8946
# Current minimum: -19.1095
# Iteration No: 82 started. Searching for the next optimal point.
# Iteration No: 82 ended. Search finished for the next optimal point.
# Time taken: 0.7025
# Function value obtained: -19.1027
# Current minimum: -19.1095
# Iteration No: 83 started. Searching for the next optimal point.
# Iteration No: 83 ended. Search finished for the next optimal point.
# Time taken: 0.6312
# Function value obtained: -4.6355
# Current minimum: -19.1095
# Iteration No: 84 started. Searching for the next optimal point.
# Iteration No: 84 ended. Search finished for the next optimal point.
# Time taken: 0.8545
# Function value obtained: -19.1027
# Current minimum: -19.1095
# Iteration No: 85 started. Searching for the next optimal point.
# Iteration No: 85 ended. Search finished for the next optimal point.
# Time taken: 0.6855
# Function value obtained: -19.1033
# Current minimum: -19.1095
# Iteration No: 86 started. Searching for the next optimal point.
# Iteration No: 86 ended. Search finished for the next optimal point.
# Time taken: 0.5232
# Function value obtained: -19.0979
# Current minimum: -19.1095
# Iteration No: 87 started. Searching for the next optimal point.
# Iteration No: 87 ended. Search finished for the next optimal point.
# Time taken: 0.7305
# Function value obtained: -12.0661
# Current minimum: -19.1095
# Iteration No: 88 started. Searching for the next optimal point.
# Iteration No: 88 ended. Search finished for the next optimal point.
# Time taken: 0.7051
# Function value obtained: -10.6199
# Current minimum: -19.1095
# Iteration No: 89 started. Searching for the next optimal point.
# Iteration No: 89 ended. Search finished for the next optimal point.
# Time taken: 0.6503
# Function value obtained: -19.1027
# Current minimum: -19.1095
# Iteration No: 90 started. Searching for the next optimal point.
# Iteration No: 90 ended. Search finished for the next optimal point.
# Time taken: 0.6494
# Function value obtained: -19.1027
# Current minimum: -19.1095
# Iteration No: 91 started. Searching for the next optimal point.
# Iteration No: 91 ended. Search finished for the next optimal point.
# Time taken: 0.6791
# Function value obtained: -19.1038
# Current minimum: -19.1095
# Iteration No: 92 started. Searching for the next optimal point.
# Iteration No: 92 ended. Search finished for the next optimal point.
# Time taken: 0.7059
# Function value obtained: -19.1003
# Current minimum: -19.1095
# Iteration No: 93 started. Searching for the next optimal point.
# Iteration No: 93 ended. Search finished for the next optimal point.
# Time taken: 0.6632
# Function value obtained: -19.1009
# Current minimum: -19.1095
# Iteration No: 94 started. Searching for the next optimal point.
# Iteration No: 94 ended. Search finished for the next optimal point.
# Time taken: 0.7478
# Function value obtained: -4.2259
# Current minimum: -19.1095
# Iteration No: 95 started. Searching for the next optimal point.
# Iteration No: 95 ended. Search finished for the next optimal point.
# Time taken: 0.7386
# Function value obtained: -19.1029
# Current minimum: -19.1095
# Iteration No: 96 started. Searching for the next optimal point.
# Iteration No: 96 ended. Search finished for the next optimal point.
# Time taken: 0.7009
# Function value obtained: -19.0966
# Current minimum: -19.1095
# Iteration No: 97 started. Searching for the next optimal point.
# Iteration No: 97 ended. Search finished for the next optimal point.
# Time taken: 0.7832
# Function value obtained: 4.9113
# Current minimum: -19.1095
# Iteration No: 98 started. Searching for the next optimal point.
# Iteration No: 98 ended. Search finished for the next optimal point.
# Time taken: 0.7206
# Function value obtained: -19.1027
# Current minimum: -19.1095
# Iteration No: 99 started. Searching for the next optimal point.
# Iteration No: 99 ended. Search finished for the next optimal point.
# Time taken: 0.8658
# Function value obtained: 11.4778
# Current minimum: -19.1095
# Iteration No: 100 started. Searching for the next optimal point.
# Iteration No: 100 ended. Search finished for the next optimal point.
# Time taken: 0.7999
# Function value obtained: -19.1027
# Current minimum: -19.1095
# 0.07853587513063197

# %%
p=2
backend = Aer.get_backend('statevector_simulator')
quantum_instance = QuantumInstance(backend)
initial_state, _ = construct_initial_state(3,3)
qc = ansatz(9,p, operator)
initial_state.append(qc, range(3*3))
initial_state.parameter_bounds = [(-2*np.pi, 2*np.pi)]*initial_state.num_parameters
# print(transpile(initial_state, basis_gates = ['id', 'rx', 'ry', 'rz', 'cx']).draw(fold=200))
vqe = VQE(ansatz = initial_state, optimizer = Global_Optimizer(), include_custom=True, quantum_instance = quantum_instance, initial_point = next_)
results = vqe.compute_minimum_eigenvalue(operator)
probs = Statevector(results.eigenstate).probabilities_dict()
p_s = 0
for string in x_s:
    p_s += probs[string] if string in probs else 0
print(p_s)
next_point = interp_point(results.optimal_point)
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 0.3703
# Function value obtained: 8.2366
# Current minimum: 8.2366
# Iteration No: 2 started. Evaluating function at random point.
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 0.0505
# Function value obtained: 0.2079
# Current minimum: 0.2079
# Iteration No: 3 started. Evaluating function at random point.
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 0.0351
# Function value obtained: -14.7961
# Current minimum: -14.7961
# Iteration No: 4 started. Evaluating function at random point.
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 0.0348
# Function value obtained: 5.2108
# Current minimum: -14.7961
# Iteration No: 5 started. Evaluating function at random point.
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 0.0341
# Function value obtained: -4.8632
# Current minimum: -14.7961
# Iteration No: 6 started. Evaluating function at random point.
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 0.0399
# Function value obtained: 8.4567
# Current minimum: -14.7961
# Iteration No: 7 started. Evaluating function at random point.
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 0.0351
# Function value obtained: -2.1406
# Current minimum: -14.7961
# Iteration No: 8 started. Evaluating function at random point.
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 0.0352
# Function value obtained: 4.1417
# Current minimum: -14.7961
# Iteration No: 9 started. Evaluating function at random point.
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 0.0344
# Function value obtained: 7.7416
# Current minimum: -14.7961
# Iteration No: 10 started. Evaluating function at random point.
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 0.2694
# Function value obtained: 3.9985
# Current minimum: -14.7961
# Iteration No: 11 started. Searching for the next optimal point.
# Iteration No: 11 ended. Search finished for the next optimal point.
# Time taken: 0.2609
# Function value obtained: -14.3256
# Current minimum: -14.7961
# Iteration No: 12 started. Searching for the next optimal point.
# Iteration No: 12 ended. Search finished for the next optimal point.
# Time taken: 0.2407
# Function value obtained: -10.8764
# Current minimum: -14.7961
# Iteration No: 13 started. Searching for the next optimal point.
# Iteration No: 13 ended. Search finished for the next optimal point.
# Time taken: 0.2215
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 14 started. Searching for the next optimal point.
# Iteration No: 14 ended. Search finished for the next optimal point.
# Time taken: 0.2770
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 15 started. Searching for the next optimal point.
# Iteration No: 15 ended. Search finished for the next optimal point.
# Time taken: 0.2350
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 16 started. Searching for the next optimal point.
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 0.2527
# Function value obtained: 11.0471
# Current minimum: -19.1027
# Iteration No: 17 started. Searching for the next optimal point.
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 0.2661
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 18 started. Searching for the next optimal point.
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 0.2432
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 19 started. Searching for the next optimal point.
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 0.2792
# Function value obtained: 7.7730
# Current minimum: -19.1027
# Iteration No: 20 started. Searching for the next optimal point.
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 0.3302
# Function value obtained: -9.8708
# Current minimum: -19.1027
# Iteration No: 21 started. Searching for the next optimal point.
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 0.2816
# Function value obtained: -19.0441
# Current minimum: -19.1027
# Iteration No: 22 started. Searching for the next optimal point.
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 0.2717
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 23 started. Searching for the next optimal point.
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 0.2942
# Function value obtained: -18.5484
# Current minimum: -19.1027
# Iteration No: 24 started. Searching for the next optimal point.
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 0.3193
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 25 started. Searching for the next optimal point.
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 0.2591
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 26 started. Searching for the next optimal point.
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 0.3463
# Function value obtained: -18.9151
# Current minimum: -19.1027
# Iteration No: 27 started. Searching for the next optimal point.
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 0.2572
# Function value obtained: 10.1216
# Current minimum: -19.1027
# Iteration No: 28 started. Searching for the next optimal point.
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 0.2578
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 29 started. Searching for the next optimal point.
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 0.5687
# Function value obtained: -6.0703
# Current minimum: -19.1027
# Iteration No: 30 started. Searching for the next optimal point.
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 0.3961
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 31 started. Searching for the next optimal point.
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 0.4412
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 32 started. Searching for the next optimal point.
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 0.4280
# Function value obtained: -14.5752
# Current minimum: -19.1027
# Iteration No: 33 started. Searching for the next optimal point.
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 0.3703
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 34 started. Searching for the next optimal point.
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 0.2956
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 35 started. Searching for the next optimal point.
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 0.3316
# Function value obtained: -6.8884
# Current minimum: -19.1027
# Iteration No: 36 started. Searching for the next optimal point.
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 0.3121
# Function value obtained: -10.2073
# Current minimum: -19.1027
# Iteration No: 37 started. Searching for the next optimal point.
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 0.3441
# Function value obtained: -0.7269
# Current minimum: -19.1027
# Iteration No: 38 started. Searching for the next optimal point.
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 0.4036
# Function value obtained: -0.7502
# Current minimum: -19.1027
# Iteration No: 39 started. Searching for the next optimal point.
# Iteration No: 39 ended. Search finished for the next optimal point.
# Time taken: 0.4674
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 40 started. Searching for the next optimal point.
# Iteration No: 40 ended. Search finished for the next optimal point.
# Time taken: 0.3791
# Function value obtained: 7.8484
# Current minimum: -19.1027
# Iteration No: 41 started. Searching for the next optimal point.
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 0.3885
# Function value obtained: 2.4445
# Current minimum: -19.1027
# Iteration No: 42 started. Searching for the next optimal point.
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 0.4002
# Function value obtained: -2.2743
# Current minimum: -19.1027
# Iteration No: 43 started. Searching for the next optimal point.
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 0.3197
# Function value obtained: -4.6379
# Current minimum: -19.1027
# Iteration No: 44 started. Searching for the next optimal point.
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 0.2932
# Function value obtained: -4.7295
# Current minimum: -19.1027
# Iteration No: 45 started. Searching for the next optimal point.
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 0.3985
# Function value obtained: 2.4465
# Current minimum: -19.1027
# Iteration No: 46 started. Searching for the next optimal point.
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 0.4156
# Function value obtained: 11.5460
# Current minimum: -19.1027
# Iteration No: 47 started. Searching for the next optimal point.
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 0.5651
# Function value obtained: -18.9898
# Current minimum: -19.1027
# Iteration No: 48 started. Searching for the next optimal point.
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 0.4717
# Function value obtained: -17.7866
# Current minimum: -19.1027
# Iteration No: 49 started. Searching for the next optimal point.
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 0.4403
# Function value obtained: -19.0825
# Current minimum: -19.1027
# Iteration No: 50 started. Searching for the next optimal point.
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 0.3746
# Function value obtained: -18.7404
# Current minimum: -19.1027
# Iteration No: 51 started. Searching for the next optimal point.
# Iteration No: 51 ended. Search finished for the next optimal point.
# Time taken: 0.4262
# Function value obtained: -2.4793
# Current minimum: -19.1027
# Iteration No: 52 started. Searching for the next optimal point.
# Iteration No: 52 ended. Search finished for the next optimal point.
# Time taken: 0.3744
# Function value obtained: 5.9664
# Current minimum: -19.1027
# Iteration No: 53 started. Searching for the next optimal point.
# Iteration No: 53 ended. Search finished for the next optimal point.
# Time taken: 0.4168
# Function value obtained: -2.5274
# Current minimum: -19.1027
# Iteration No: 54 started. Searching for the next optimal point.
# Iteration No: 54 ended. Search finished for the next optimal point.
# Time taken: 0.7296
# Function value obtained: -10.9497
# Current minimum: -19.1027
# Iteration No: 55 started. Searching for the next optimal point.
# Iteration No: 55 ended. Search finished for the next optimal point.
# Time taken: 0.4728
# Function value obtained: 4.3793
# Current minimum: -19.1027
# Iteration No: 56 started. Searching for the next optimal point.
# Iteration No: 56 ended. Search finished for the next optimal point.
# Time taken: 0.4800
# Function value obtained: -3.1570
# Current minimum: -19.1027
# Iteration No: 57 started. Searching for the next optimal point.
# Iteration No: 57 ended. Search finished for the next optimal point.
# Time taken: 0.4594
# Function value obtained: 10.2044
# Current minimum: -19.1027
# Iteration No: 58 started. Searching for the next optimal point.
# Iteration No: 58 ended. Search finished for the next optimal point.
# Time taken: 0.5125
# Function value obtained: -2.0540
# Current minimum: -19.1027
# Iteration No: 59 started. Searching for the next optimal point.
# Iteration No: 59 ended. Search finished for the next optimal point.
# Time taken: 0.4493
# Function value obtained: 6.4165
# Current minimum: -19.1027
# Iteration No: 60 started. Searching for the next optimal point.
# Iteration No: 60 ended. Search finished for the next optimal point.
# Time taken: 0.4418
# Function value obtained: -5.3230
# Current minimum: -19.1027
# Iteration No: 61 started. Searching for the next optimal point.
# Iteration No: 61 ended. Search finished for the next optimal point.
# Time taken: 0.5033
# Function value obtained: 8.9849
# Current minimum: -19.1027
# Iteration No: 62 started. Searching for the next optimal point.
# Iteration No: 62 ended. Search finished for the next optimal point.
# Time taken: 0.5226
# Function value obtained: -14.4878
# Current minimum: -19.1027
# Iteration No: 63 started. Searching for the next optimal point.
# Iteration No: 63 ended. Search finished for the next optimal point.
# Time taken: 0.5164
# Function value obtained: -7.6210
# Current minimum: -19.1027
# Iteration No: 64 started. Searching for the next optimal point.
# Iteration No: 64 ended. Search finished for the next optimal point.
# Time taken: 0.6628
# Function value obtained: -8.2339
# Current minimum: -19.1027
# Iteration No: 65 started. Searching for the next optimal point.
# Iteration No: 65 ended. Search finished for the next optimal point.
# Time taken: 0.7569
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 66 started. Searching for the next optimal point.
# Iteration No: 66 ended. Search finished for the next optimal point.
# Time taken: 0.6309
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 67 started. Searching for the next optimal point.
# Iteration No: 67 ended. Search finished for the next optimal point.
# Time taken: 0.7498
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 68 started. Searching for the next optimal point.
# Iteration No: 68 ended. Search finished for the next optimal point.
# Time taken: 0.9135
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 69 started. Searching for the next optimal point.
# Iteration No: 69 ended. Search finished for the next optimal point.
# Time taken: 0.6747
# Function value obtained: -1.9666
# Current minimum: -19.1027
# Iteration No: 70 started. Searching for the next optimal point.
# Iteration No: 70 ended. Search finished for the next optimal point.
# Time taken: 0.6025
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 71 started. Searching for the next optimal point.
# Iteration No: 71 ended. Search finished for the next optimal point.
# Time taken: 0.6786
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 72 started. Searching for the next optimal point.
# Iteration No: 72 ended. Search finished for the next optimal point.
# Time taken: 0.6535
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 73 started. Searching for the next optimal point.
# Iteration No: 73 ended. Search finished for the next optimal point.
# Time taken: 0.5803
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 74 started. Searching for the next optimal point.
# Iteration No: 74 ended. Search finished for the next optimal point.
# Time taken: 0.6143
# Function value obtained: -14.7015
# Current minimum: -19.1027
# Iteration No: 75 started. Searching for the next optimal point.
# Iteration No: 75 ended. Search finished for the next optimal point.
# Time taken: 0.6824
# Function value obtained: 8.4881
# Current minimum: -19.1027
# Iteration No: 76 started. Searching for the next optimal point.
# Iteration No: 76 ended. Search finished for the next optimal point.
# Time taken: 0.6632
# Function value obtained: 4.0245
# Current minimum: -19.1027
# Iteration No: 77 started. Searching for the next optimal point.
# Iteration No: 77 ended. Search finished for the next optimal point.
# Time taken: 0.7055
# Function value obtained: 2.3468
# Current minimum: -19.1027
# Iteration No: 78 started. Searching for the next optimal point.
# Iteration No: 78 ended. Search finished for the next optimal point.
# Time taken: 0.8544
# Function value obtained: 6.6550
# Current minimum: -19.1027
# Iteration No: 79 started. Searching for the next optimal point.
# Iteration No: 79 ended. Search finished for the next optimal point.
# Time taken: 0.7883
# Function value obtained: 11.8912
# Current minimum: -19.1027
# Iteration No: 80 started. Searching for the next optimal point.
# Iteration No: 80 ended. Search finished for the next optimal point.
# Time taken: 0.6357
# Function value obtained: 0.6863
# Current minimum: -19.1027
# Iteration No: 81 started. Searching for the next optimal point.
# Iteration No: 81 ended. Search finished for the next optimal point.
# Time taken: 0.6283
# Function value obtained: 5.1382
# Current minimum: -19.1027
# Iteration No: 82 started. Searching for the next optimal point.
# Iteration No: 82 ended. Search finished for the next optimal point.
# Time taken: 1.0149
# Function value obtained: -9.1496
# Current minimum: -19.1027
# Iteration No: 83 started. Searching for the next optimal point.
# Iteration No: 83 ended. Search finished for the next optimal point.
# Time taken: 0.6946
# Function value obtained: 0.3893
# Current minimum: -19.1027
# Iteration No: 84 started. Searching for the next optimal point.
# Iteration No: 84 ended. Search finished for the next optimal point.
# Time taken: 0.6112
# Function value obtained: 2.0046
# Current minimum: -19.1027
# Iteration No: 85 started. Searching for the next optimal point.
# Iteration No: 85 ended. Search finished for the next optimal point.
# Time taken: 0.6667
# Function value obtained: -1.9536
# Current minimum: -19.1027
# Iteration No: 86 started. Searching for the next optimal point.
# Iteration No: 86 ended. Search finished for the next optimal point.
# Time taken: 0.6353
# Function value obtained: -1.9201
# Current minimum: -19.1027
# Iteration No: 87 started. Searching for the next optimal point.
# Iteration No: 87 ended. Search finished for the next optimal point.
# Time taken: 0.5946
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 88 started. Searching for the next optimal point.
# Iteration No: 88 ended. Search finished for the next optimal point.
# Time taken: 0.5696
# Function value obtained: 9.1325
# Current minimum: -19.1027
# Iteration No: 89 started. Searching for the next optimal point.
# Iteration No: 89 ended. Search finished for the next optimal point.
# Time taken: 0.6962
# Function value obtained: -2.0386
# Current minimum: -19.1027
# Iteration No: 90 started. Searching for the next optimal point.
# Iteration No: 90 ended. Search finished for the next optimal point.
# Time taken: 0.6422
# Function value obtained: -9.9051
# Current minimum: -19.1027
# Iteration No: 91 started. Searching for the next optimal point.
# Iteration No: 91 ended. Search finished for the next optimal point.
# Time taken: 0.7249
# Function value obtained: 6.6036
# Current minimum: -19.1027
# Iteration No: 92 started. Searching for the next optimal point.
# Iteration No: 92 ended. Search finished for the next optimal point.
# Time taken: 0.6708
# Function value obtained: 10.1092
# Current minimum: -19.1027
# Iteration No: 93 started. Searching for the next optimal point.
# Iteration No: 93 ended. Search finished for the next optimal point.
# Time taken: 0.7897
# Function value obtained: -8.3194
# Current minimum: -19.1027
# Iteration No: 94 started. Searching for the next optimal point.
# Iteration No: 94 ended. Search finished for the next optimal point.
# Time taken: 0.9361
# Function value obtained: -15.8293
# Current minimum: -19.1027
# Iteration No: 95 started. Searching for the next optimal point.
# Iteration No: 95 ended. Search finished for the next optimal point.
# Time taken: 0.8879
# Function value obtained: -8.8182
# Current minimum: -19.1027
# Iteration No: 96 started. Searching for the next optimal point.
# Iteration No: 96 ended. Search finished for the next optimal point.
# Time taken: 0.7092
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 97 started. Searching for the next optimal point.
# Iteration No: 97 ended. Search finished for the next optimal point.
# Time taken: 0.8596
# Function value obtained: -12.0238
# Current minimum: -19.1027
# Iteration No: 98 started. Searching for the next optimal point.
# Iteration No: 98 ended. Search finished for the next optimal point.
# Time taken: 0.7965
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 99 started. Searching for the next optimal point.
# Iteration No: 99 ended. Search finished for the next optimal point.
# Time taken: 0.9036
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 100 started. Searching for the next optimal point.
# Iteration No: 100 ended. Search finished for the next optimal point.
# Time taken: 0.7827
# Function value obtained: -19.1027
# Current minimum: -19.1027
# 0.0740740740740744

# %%
p=3
backend = Aer.get_backend('statevector_simulator')
quantum_instance = QuantumInstance(backend)
initial_state, _ = construct_initial_state(3,3)
qc = ansatz(9,p, operator)
initial_state.append(qc, range(3*3))
initial_state.parameter_bounds = [(-2*np.pi, 2*np.pi)]*initial_state.num_parameters
# print(transpile(initial_state, basis_gates = ['id', 'rx', 'ry', 'rz', 'cx']).draw(fold=200))
vqe = VQE(ansatz = initial_state, optimizer = Global_Optimizer(), include_custom=True, quantum_instance = quantum_instance, initial_point = next_point)
results = vqe.compute_minimum_eigenvalue(operator)
probs = Statevector(results.eigenstate).probabilities_dict()
p_s = 0
for string in x_s:
    p_s += probs[string] if string in probs else 0
print(p_s)
print(results.eigenvalue+offset)
next_point = interp_point(results.optimal_point)
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 0.1530
# Function value obtained: -8.4219
# Current minimum: -8.4219
# Iteration No: 2 started. Evaluating function at random point.
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 0.0528
# Function value obtained: 10.8959
# Current minimum: -8.4219
# Iteration No: 3 started. Evaluating function at random point.
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 0.0503
# Function value obtained: 1.1508
# Current minimum: -8.4219
# Iteration No: 4 started. Evaluating function at random point.
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 0.0528
# Function value obtained: -12.0046
# Current minimum: -12.0046
# Iteration No: 5 started. Evaluating function at random point.
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 0.0503
# Function value obtained: 0.8946
# Current minimum: -12.0046
# Iteration No: 6 started. Evaluating function at random point.
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 0.0506
# Function value obtained: 3.6349
# Current minimum: -12.0046
# Iteration No: 7 started. Evaluating function at random point.
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 0.0513
# Function value obtained: 1.2693
# Current minimum: -12.0046
# Iteration No: 8 started. Evaluating function at random point.
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 0.0498
# Function value obtained: -3.1690
# Current minimum: -12.0046
# Iteration No: 9 started. Evaluating function at random point.
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 0.0498
# Function value obtained: 1.3870
# Current minimum: -12.0046
# Iteration No: 10 started. Evaluating function at random point.
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 0.2174
# Function value obtained: 8.9301
# Current minimum: -12.0046
# Iteration No: 11 started. Searching for the next optimal point.
# Iteration No: 11 ended. Search finished for the next optimal point.
# Time taken: 0.2396
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 12 started. Searching for the next optimal point.
# Iteration No: 12 ended. Search finished for the next optimal point.
# Time taken: 0.2492
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 13 started. Searching for the next optimal point.
# Iteration No: 13 ended. Search finished for the next optimal point.
# Time taken: 0.2681
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 14 started. Searching for the next optimal point.
# Iteration No: 14 ended. Search finished for the next optimal point.
# Time taken: 0.3160
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 15 started. Searching for the next optimal point.
# Iteration No: 15 ended. Search finished for the next optimal point.
# Time taken: 0.2911
# Function value obtained: -15.2006
# Current minimum: -19.1027
# Iteration No: 16 started. Searching for the next optimal point.
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 0.2915
# Function value obtained: 1.8575
# Current minimum: -19.1027
# Iteration No: 17 started. Searching for the next optimal point.
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 0.4042
# Function value obtained: 10.6493
# Current minimum: -19.1027
# Iteration No: 18 started. Searching for the next optimal point.
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 0.2927
# Function value obtained: -11.6034
# Current minimum: -19.1027
# Iteration No: 19 started. Searching for the next optimal point.
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 0.3029
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 20 started. Searching for the next optimal point.
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 0.6010
# Function value obtained: 9.6359
# Current minimum: -19.1027
# Iteration No: 21 started. Searching for the next optimal point.
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 0.4200
# Function value obtained: 3.4604
# Current minimum: -19.1027
# Iteration No: 22 started. Searching for the next optimal point.
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 0.3073
# Function value obtained: -6.9071
# Current minimum: -19.1027
# Iteration No: 23 started. Searching for the next optimal point.
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 0.3250
# Function value obtained: -13.8479
# Current minimum: -19.1027
# Iteration No: 24 started. Searching for the next optimal point.
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 0.4256
# Function value obtained: -1.0307
# Current minimum: -19.1027
# Iteration No: 25 started. Searching for the next optimal point.
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 0.3736
# Function value obtained: -0.9809
# Current minimum: -19.1027
# Iteration No: 26 started. Searching for the next optimal point.
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 0.3955
# Function value obtained: 1.1769
# Current minimum: -19.1027
# Iteration No: 27 started. Searching for the next optimal point.
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 0.4096
# Function value obtained: -8.3965
# Current minimum: -19.1027
# Iteration No: 28 started. Searching for the next optimal point.
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 0.4344
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 29 started. Searching for the next optimal point.
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 0.3116
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 30 started. Searching for the next optimal point.
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 0.4918
# Function value obtained: -17.8293
# Current minimum: -19.1027
# Iteration No: 31 started. Searching for the next optimal point.
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 0.4401
# Function value obtained: -6.1606
# Current minimum: -19.1027
# Iteration No: 32 started. Searching for the next optimal point.
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 0.5001
# Function value obtained: 9.1471
# Current minimum: -19.1027
# Iteration No: 33 started. Searching for the next optimal point.
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 0.5257
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 34 started. Searching for the next optimal point.
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 0.5165
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 35 started. Searching for the next optimal point.
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 0.4861
# Function value obtained: -0.6552
# Current minimum: -19.1027
# Iteration No: 36 started. Searching for the next optimal point.
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 0.5071
# Function value obtained: 8.1373
# Current minimum: -19.1027
# Iteration No: 37 started. Searching for the next optimal point.
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 0.4902
# Function value obtained: 7.6513
# Current minimum: -19.1027
# Iteration No: 38 started. Searching for the next optimal point.
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 0.6415
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 39 started. Searching for the next optimal point.
# Iteration No: 39 ended. Search finished for the next optimal point.
# Time taken: 0.4500
# Function value obtained: 8.4799
# Current minimum: -19.1027
# Iteration No: 40 started. Searching for the next optimal point.
# Iteration No: 40 ended. Search finished for the next optimal point.
# Time taken: 0.4928
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 41 started. Searching for the next optimal point.
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 0.5497
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 42 started. Searching for the next optimal point.
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 0.5920
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 43 started. Searching for the next optimal point.
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 0.8785
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 44 started. Searching for the next optimal point.
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 0.5947
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 45 started. Searching for the next optimal point.
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 0.4875
# Function value obtained: -19.0566
# Current minimum: -19.1027
# Iteration No: 46 started. Searching for the next optimal point.
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 0.4957
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 47 started. Searching for the next optimal point.
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 0.5337
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 48 started. Searching for the next optimal point.
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 0.6488
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 49 started. Searching for the next optimal point.
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 0.6251
# Function value obtained: -18.7075
# Current minimum: -19.1027
# Iteration No: 50 started. Searching for the next optimal point.
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 0.5130
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 51 started. Searching for the next optimal point.
# Iteration No: 51 ended. Search finished for the next optimal point.
# Time taken: 0.5522
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 52 started. Searching for the next optimal point.
# Iteration No: 52 ended. Search finished for the next optimal point.
# Time taken: 0.6130
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 53 started. Searching for the next optimal point.
# Iteration No: 53 ended. Search finished for the next optimal point.
# Time taken: 0.6227
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 54 started. Searching for the next optimal point.
# Iteration No: 54 ended. Search finished for the next optimal point.
# Time taken: 0.5004
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 55 started. Searching for the next optimal point.
# Iteration No: 55 ended. Search finished for the next optimal point.
# Time taken: 0.6121
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 56 started. Searching for the next optimal point.
# Iteration No: 56 ended. Search finished for the next optimal point.
# Time taken: 0.6172
# Function value obtained: -19.0335
# Current minimum: -19.1027
# Iteration No: 57 started. Searching for the next optimal point.
# Iteration No: 57 ended. Search finished for the next optimal point.
# Time taken: 0.6170
# Function value obtained: -18.5488
# Current minimum: -19.1027
# Iteration No: 58 started. Searching for the next optimal point.
# Iteration No: 58 ended. Search finished for the next optimal point.
# Time taken: 0.6221
# Function value obtained: -12.8658
# Current minimum: -19.1027
# Iteration No: 59 started. Searching for the next optimal point.
# Iteration No: 59 ended. Search finished for the next optimal point.
# Time taken: 0.5782
# Function value obtained: -17.4804
# Current minimum: -19.1027
# Iteration No: 60 started. Searching for the next optimal point.
# Iteration No: 60 ended. Search finished for the next optimal point.
# Time taken: 0.5978
# Function value obtained: -18.9958
# Current minimum: -19.1027
# Iteration No: 61 started. Searching for the next optimal point.
# Iteration No: 61 ended. Search finished for the next optimal point.
# Time taken: 0.6238
# Function value obtained: -8.0093
# Current minimum: -19.1027
# Iteration No: 62 started. Searching for the next optimal point.
# Iteration No: 62 ended. Search finished for the next optimal point.
# Time taken: 0.6151
# Function value obtained: -18.7385
# Current minimum: -19.1027
# Iteration No: 63 started. Searching for the next optimal point.
# Iteration No: 63 ended. Search finished for the next optimal point.
# Time taken: 0.9680
# Function value obtained: -6.9152
# Current minimum: -19.1027
# Iteration No: 64 started. Searching for the next optimal point.
# Iteration No: 64 ended. Search finished for the next optimal point.
# Time taken: 0.6374
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 65 started. Searching for the next optimal point.
# Iteration No: 65 ended. Search finished for the next optimal point.
# Time taken: 0.6259
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 66 started. Searching for the next optimal point.
# Iteration No: 66 ended. Search finished for the next optimal point.
# Time taken: 0.7382
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 67 started. Searching for the next optimal point.
# Iteration No: 67 ended. Search finished for the next optimal point.
# Time taken: 0.5452
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 68 started. Searching for the next optimal point.
# Iteration No: 68 ended. Search finished for the next optimal point.
# Time taken: 0.6332
# Function value obtained: -18.9997
# Current minimum: -19.1027
# Iteration No: 69 started. Searching for the next optimal point.
# Iteration No: 69 ended. Search finished for the next optimal point.
# Time taken: 0.7610
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 70 started. Searching for the next optimal point.
# Iteration No: 70 ended. Search finished for the next optimal point.
# Time taken: 0.6371
# Function value obtained: -8.9217
# Current minimum: -19.1027
# Iteration No: 71 started. Searching for the next optimal point.
# Iteration No: 71 ended. Search finished for the next optimal point.
# Time taken: 0.7074
# Function value obtained: -2.3723
# Current minimum: -19.1027
# Iteration No: 72 started. Searching for the next optimal point.
# Iteration No: 72 ended. Search finished for the next optimal point.
# Time taken: 0.7322
# Function value obtained: 0.3339
# Current minimum: -19.1027
# Iteration No: 73 started. Searching for the next optimal point.
# Iteration No: 73 ended. Search finished for the next optimal point.
# Time taken: 0.8235
# Function value obtained: -9.5076
# Current minimum: -19.1027
# Iteration No: 74 started. Searching for the next optimal point.
# Iteration No: 74 ended. Search finished for the next optimal point.
# Time taken: 0.7623
# Function value obtained: 1.1405
# Current minimum: -19.1027
# Iteration No: 75 started. Searching for the next optimal point.
# Iteration No: 75 ended. Search finished for the next optimal point.
# Time taken: 0.9470
# Function value obtained: -10.6890
# Current minimum: -19.1027
# Iteration No: 76 started. Searching for the next optimal point.
# Iteration No: 76 ended. Search finished for the next optimal point.
# Time taken: 0.8548
# Function value obtained: 7.4679
# Current minimum: -19.1027
# Iteration No: 77 started. Searching for the next optimal point.
# Iteration No: 77 ended. Search finished for the next optimal point.
# Time taken: 0.9510
# Function value obtained: 3.9325
# Current minimum: -19.1027
# Iteration No: 78 started. Searching for the next optimal point.
# Iteration No: 78 ended. Search finished for the next optimal point.
# Time taken: 0.6794
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 79 started. Searching for the next optimal point.
# Iteration No: 79 ended. Search finished for the next optimal point.
# Time taken: 0.8329
# Function value obtained: 5.6730
# Current minimum: -19.1027
# Iteration No: 80 started. Searching for the next optimal point.
# Iteration No: 80 ended. Search finished for the next optimal point.
# Time taken: 1.0178
# Function value obtained: 0.8691
# Current minimum: -19.1027
# Iteration No: 81 started. Searching for the next optimal point.
# Iteration No: 81 ended. Search finished for the next optimal point.
# Time taken: 0.8249
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 82 started. Searching for the next optimal point.
# Iteration No: 82 ended. Search finished for the next optimal point.
# Time taken: 0.9075
# Function value obtained: 5.9130
# Current minimum: -19.1027
# Iteration No: 83 started. Searching for the next optimal point.
# Iteration No: 83 ended. Search finished for the next optimal point.
# Time taken: 0.7475
# Function value obtained: 4.6496
# Current minimum: -19.1027
# Iteration No: 84 started. Searching for the next optimal point.
# Iteration No: 84 ended. Search finished for the next optimal point.
# Time taken: 0.7239
# Function value obtained: -3.1574
# Current minimum: -19.1027
# Iteration No: 85 started. Searching for the next optimal point.
# Iteration No: 85 ended. Search finished for the next optimal point.
# Time taken: 0.7857
# Function value obtained: 5.3526
# Current minimum: -19.1027
# Iteration No: 86 started. Searching for the next optimal point.
# Iteration No: 86 ended. Search finished for the next optimal point.
# Time taken: 0.7501
# Function value obtained: -13.4568
# Current minimum: -19.1027
# Iteration No: 87 started. Searching for the next optimal point.
# Iteration No: 87 ended. Search finished for the next optimal point.
# Time taken: 0.8909
# Function value obtained: -1.4716
# Current minimum: -19.1027
# Iteration No: 88 started. Searching for the next optimal point.
# Iteration No: 88 ended. Search finished for the next optimal point.
# Time taken: 1.0222
# Function value obtained: -6.4933
# Current minimum: -19.1027
# Iteration No: 89 started. Searching for the next optimal point.
# Iteration No: 89 ended. Search finished for the next optimal point.
# Time taken: 0.8032
# Function value obtained: 0.1685
# Current minimum: -19.1027
# Iteration No: 90 started. Searching for the next optimal point.
# Iteration No: 90 ended. Search finished for the next optimal point.
# Time taken: 0.8559
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 91 started. Searching for the next optimal point.
# Iteration No: 91 ended. Search finished for the next optimal point.
# Time taken: 0.8153
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 92 started. Searching for the next optimal point.
# Iteration No: 92 ended. Search finished for the next optimal point.
# Time taken: 0.8785
# Function value obtained: -9.1622
# Current minimum: -19.1027
# Iteration No: 93 started. Searching for the next optimal point.
# Iteration No: 93 ended. Search finished for the next optimal point.
# Time taken: 0.8494
# Function value obtained: 0.0403
# Current minimum: -19.1027
# Iteration No: 94 started. Searching for the next optimal point.
# Iteration No: 94 ended. Search finished for the next optimal point.
# Time taken: 0.8013
# Function value obtained: -1.6752
# Current minimum: -19.1027
# Iteration No: 95 started. Searching for the next optimal point.
# Iteration No: 95 ended. Search finished for the next optimal point.
# Time taken: 0.7970
# Function value obtained: 0.0608
# Current minimum: -19.1027
# Iteration No: 96 started. Searching for the next optimal point.
# Iteration No: 96 ended. Search finished for the next optimal point.
# Time taken: 0.8630
# Function value obtained: -6.8745
# Current minimum: -19.1027
# Iteration No: 97 started. Searching for the next optimal point.
# Iteration No: 97 ended. Search finished for the next optimal point.
# Time taken: 0.9109
# Function value obtained: 0.7412
# Current minimum: -19.1027
# Iteration No: 98 started. Searching for the next optimal point.
# Iteration No: 98 ended. Search finished for the next optimal point.
# Time taken: 0.8424
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 99 started. Searching for the next optimal point.
# Iteration No: 99 ended. Search finished for the next optimal point.
# Time taken: 1.1011
# Function value obtained: 0.9247
# Current minimum: -19.1027
# Iteration No: 100 started. Searching for the next optimal point.
# Iteration No: 100 ended. Search finished for the next optimal point.
# Time taken: 1.0208
# Function value obtained: -0.3818
# Current minimum: -19.1027
# 0.07407407407407374
# 4.725099888888902

# %%
p=4
backend = Aer.get_backend('statevector_simulator')
quantum_instance = QuantumInstance(backend)
initial_state, _ = construct_initial_state(3,3)
qc = ansatz(9,p, operator)
initial_state.append(qc, range(3*3))
initial_state.parameter_bounds = [(-2*np.pi, 2*np.pi)]*initial_state.num_parameters
# print(transpile(initial_state, basis_gates = ['id', 'rx', 'ry', 'rz', 'cx']).draw(fold=200))
vqe = VQE(ansatz = initial_state, optimizer = Basin(), include_custom=True, quantum_instance = quantum_instance, initial_point = next_point)
results = vqe.compute_minimum_eigenvalue(operator)
probs = Statevector(results.eigenstate).probabilities_dict()
p_s = 0
for string in x_s:
    p_s += probs[string] if string in probs else 0
print(p_s)
print(results.eigenvalue+offset)
next_point = results.optimal_point[0:p]+[0]+results.optimal_point[p:2*p]+[0]
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 0.2096
# Function value obtained: 0.6335
# Current minimum: 0.6335
# Iteration No: 2 started. Evaluating function at random point.
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 0.0719
# Function value obtained: 0.7329
# Current minimum: 0.6335
# Iteration No: 3 started. Evaluating function at random point.
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 0.0713
# Function value obtained: -8.2291
# Current minimum: -8.2291
# Iteration No: 4 started. Evaluating function at random point.
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 0.0778
# Function value obtained: 0.5756
# Current minimum: -8.2291
# Iteration No: 5 started. Evaluating function at random point.
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 0.0714
# Function value obtained: 0.3696
# Current minimum: -8.2291
# Iteration No: 6 started. Evaluating function at random point.
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 0.0733
# Function value obtained: -1.3746
# Current minimum: -8.2291
# Iteration No: 7 started. Evaluating function at random point.
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 0.0736
# Function value obtained: -1.5889
# Current minimum: -8.2291
# Iteration No: 8 started. Evaluating function at random point.
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 0.0948
# Function value obtained: -5.5214
# Current minimum: -8.2291
# Iteration No: 9 started. Evaluating function at random point.
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 0.0693
# Function value obtained: -2.3226
# Current minimum: -8.2291
# Iteration No: 10 started. Evaluating function at random point.
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 0.2278
# Function value obtained: -0.5501
# Current minimum: -8.2291
# Iteration No: 11 started. Searching for the next optimal point.
# Iteration No: 11 ended. Search finished for the next optimal point.
# Time taken: 0.2339
# Function value obtained: 5.5799
# Current minimum: -8.2291
# Iteration No: 12 started. Searching for the next optimal point.
# Iteration No: 12 ended. Search finished for the next optimal point.
# Time taken: 0.2446
# Function value obtained: 0.8457
# Current minimum: -8.2291
# Iteration No: 13 started. Searching for the next optimal point.
# Iteration No: 13 ended. Search finished for the next optimal point.
# Time taken: 0.6196
# Function value obtained: 8.7535
# Current minimum: -8.2291
# Iteration No: 14 started. Searching for the next optimal point.
# Iteration No: 14 ended. Search finished for the next optimal point.
# Time taken: 0.3704
# Function value obtained: 0.3738
# Current minimum: -8.2291
# Iteration No: 15 started. Searching for the next optimal point.
# Iteration No: 15 ended. Search finished for the next optimal point.
# Time taken: 0.2282
# Function value obtained: -11.1130
# Current minimum: -11.1130
# Iteration No: 16 started. Searching for the next optimal point.
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 0.2605
# Function value obtained: -1.0085
# Current minimum: -11.1130
# Iteration No: 17 started. Searching for the next optimal point.
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 0.4013
# Function value obtained: -4.9558
# Current minimum: -11.1130
# Iteration No: 18 started. Searching for the next optimal point.
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 0.2690
# Function value obtained: 2.1652
# Current minimum: -11.1130
# Iteration No: 19 started. Searching for the next optimal point.
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 0.3295
# Function value obtained: 3.2510
# Current minimum: -11.1130
# Iteration No: 20 started. Searching for the next optimal point.
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 0.2555
# Function value obtained: -1.4416
# Current minimum: -11.1130
# Iteration No: 21 started. Searching for the next optimal point.
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 0.3003
# Function value obtained: 0.0610
# Current minimum: -11.1130
# Iteration No: 22 started. Searching for the next optimal point.
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 0.3457
# Function value obtained: 4.7486
# Current minimum: -11.1130
# Iteration No: 23 started. Searching for the next optimal point.
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 0.3874
# Function value obtained: 3.7536
# Current minimum: -11.1130
# Iteration No: 24 started. Searching for the next optimal point.
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 0.3107
# Function value obtained: -1.7144
# Current minimum: -11.1130
# Iteration No: 25 started. Searching for the next optimal point.
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 0.3176
# Function value obtained: -0.2148
# Current minimum: -11.1130
# Iteration No: 26 started. Searching for the next optimal point.
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 0.3268
# Function value obtained: 10.6577
# Current minimum: -11.1130
# Iteration No: 27 started. Searching for the next optimal point.
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 0.3083
# Function value obtained: 8.6138
# Current minimum: -11.1130
# Iteration No: 28 started. Searching for the next optimal point.
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 0.3878
# Function value obtained: -5.9689
# Current minimum: -11.1130
# Iteration No: 29 started. Searching for the next optimal point.
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 0.3525
# Function value obtained: -0.8723
# Current minimum: -11.1130
# Iteration No: 30 started. Searching for the next optimal point.
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 0.4083
# Function value obtained: 0.4254
# Current minimum: -11.1130
# Iteration No: 31 started. Searching for the next optimal point.
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 0.3835
# Function value obtained: -4.7967
# Current minimum: -11.1130
# Iteration No: 32 started. Searching for the next optimal point.
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 0.3875
# Function value obtained: -5.7374
# Current minimum: -11.1130
# Iteration No: 33 started. Searching for the next optimal point.
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 0.4004
# Function value obtained: -9.5741
# Current minimum: -11.1130
# Iteration No: 34 started. Searching for the next optimal point.
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 0.4397
# Function value obtained: 5.6790
# Current minimum: -11.1130
# Iteration No: 35 started. Searching for the next optimal point.
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 0.7444
# Function value obtained: 1.0239
# Current minimum: -11.1130
# Iteration No: 36 started. Searching for the next optimal point.
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 0.6486
# Function value obtained: -9.0529
# Current minimum: -11.1130
# Iteration No: 37 started. Searching for the next optimal point.
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 0.5759
# Function value obtained: -0.8154
# Current minimum: -11.1130
# Iteration No: 38 started. Searching for the next optimal point.
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 0.5521
# Function value obtained: -9.4513
# Current minimum: -11.1130
# Iteration No: 39 started. Searching for the next optimal point.
# Iteration No: 39 ended. Search finished for the next optimal point.
# Time taken: 0.5328
# Function value obtained: -3.9574
# Current minimum: -11.1130
# Iteration No: 40 started. Searching for the next optimal point.
# Iteration No: 40 ended. Search finished for the next optimal point.
# Time taken: 0.6799
# Function value obtained: -10.7645
# Current minimum: -11.1130
# Iteration No: 41 started. Searching for the next optimal point.
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 0.6216
# Function value obtained: 4.7670
# Current minimum: -11.1130
# Iteration No: 42 started. Searching for the next optimal point.
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 0.6925
# Function value obtained: 2.5575
# Current minimum: -11.1130
# Iteration No: 43 started. Searching for the next optimal point.
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 0.5950
# Function value obtained: -3.8430
# Current minimum: -11.1130
# Iteration No: 44 started. Searching for the next optimal point.
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 0.4673
# Function value obtained: -9.6162
# Current minimum: -11.1130
# Iteration No: 45 started. Searching for the next optimal point.
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 0.5021
# Function value obtained: 2.6541
# Current minimum: -11.1130
# Iteration No: 46 started. Searching for the next optimal point.
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 0.6321
# Function value obtained: -0.2950
# Current minimum: -11.1130
# Iteration No: 47 started. Searching for the next optimal point.
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 0.6784
# Function value obtained: 9.0152
# Current minimum: -11.1130
# Iteration No: 48 started. Searching for the next optimal point.
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 0.5425
# Function value obtained: -8.5846
# Current minimum: -11.1130
# Iteration No: 49 started. Searching for the next optimal point.
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 0.5623
# Function value obtained: -12.7388
# Current minimum: -12.7388
# Iteration No: 50 started. Searching for the next optimal point.
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 0.7282
# Function value obtained: 6.6756
# Current minimum: -12.7388
# Iteration No: 51 started. Searching for the next optimal point.
# Iteration No: 51 ended. Search finished for the next optimal point.
# Time taken: 0.8712
# Function value obtained: 7.2333
# Current minimum: -12.7388
# Iteration No: 52 started. Searching for the next optimal point.
# Iteration No: 52 ended. Search finished for the next optimal point.
# Time taken: 0.7994
# Function value obtained: -4.2642
# Current minimum: -12.7388
# Iteration No: 53 started. Searching for the next optimal point.
# Iteration No: 53 ended. Search finished for the next optimal point.
# Time taken: 0.8090
# Function value obtained: -0.7207
# Current minimum: -12.7388
# Iteration No: 54 started. Searching for the next optimal point.
# Iteration No: 54 ended. Search finished for the next optimal point.
# Time taken: 0.8362
# Function value obtained: -5.2335
# Current minimum: -12.7388
# Iteration No: 55 started. Searching for the next optimal point.
# Iteration No: 55 ended. Search finished for the next optimal point.
# Time taken: 0.9471
# Function value obtained: -6.4513
# Current minimum: -12.7388
# Iteration No: 56 started. Searching for the next optimal point.
# Iteration No: 56 ended. Search finished for the next optimal point.
# Time taken: 0.8020
# Function value obtained: -7.3617
# Current minimum: -12.7388
# Iteration No: 57 started. Searching for the next optimal point.
# Iteration No: 57 ended. Search finished for the next optimal point.
# Time taken: 0.7429
# Function value obtained: 11.9402
# Current minimum: -12.7388
# Iteration No: 58 started. Searching for the next optimal point.
# Iteration No: 58 ended. Search finished for the next optimal point.
# Time taken: 0.8025
# Function value obtained: -11.4280
# Current minimum: -12.7388
# Iteration No: 59 started. Searching for the next optimal point.
# Iteration No: 59 ended. Search finished for the next optimal point.
# Time taken: 0.9568
# Function value obtained: -11.3644
# Current minimum: -12.7388
# Iteration No: 60 started. Searching for the next optimal point.
# Iteration No: 60 ended. Search finished for the next optimal point.
# Time taken: 0.8664
# Function value obtained: -5.8122
# Current minimum: -12.7388
# Iteration No: 61 started. Searching for the next optimal point.
# Iteration No: 61 ended. Search finished for the next optimal point.
# Time taken: 0.8124
# Function value obtained: 9.4227
# Current minimum: -12.7388
# Iteration No: 62 started. Searching for the next optimal point.
# Iteration No: 62 ended. Search finished for the next optimal point.
# Time taken: 0.9157
# Function value obtained: 11.0264
# Current minimum: -12.7388
# Iteration No: 63 started. Searching for the next optimal point.
# Iteration No: 63 ended. Search finished for the next optimal point.
# Time taken: 0.9510
# Function value obtained: -1.5091
# Current minimum: -12.7388
# Iteration No: 64 started. Searching for the next optimal point.
# Iteration No: 64 ended. Search finished for the next optimal point.
# Time taken: 0.8661
# Function value obtained: 10.4361
# Current minimum: -12.7388
# Iteration No: 65 started. Searching for the next optimal point.
# Iteration No: 65 ended. Search finished for the next optimal point.
# Time taken: 0.7308
# Function value obtained: 9.7425
# Current minimum: -12.7388
# Iteration No: 66 started. Searching for the next optimal point.
# Iteration No: 66 ended. Search finished for the next optimal point.
# Time taken: 1.0042
# Function value obtained: 3.0466
# Current minimum: -12.7388
# Iteration No: 67 started. Searching for the next optimal point.
# Iteration No: 67 ended. Search finished for the next optimal point.
# Time taken: 0.9109
# Function value obtained: -9.0401
# Current minimum: -12.7388
# Iteration No: 68 started. Searching for the next optimal point.
# Iteration No: 68 ended. Search finished for the next optimal point.
# Time taken: 0.7549
# Function value obtained: -2.9311
# Current minimum: -12.7388
# Iteration No: 69 started. Searching for the next optimal point.
# Iteration No: 69 ended. Search finished for the next optimal point.
# Time taken: 0.9414
# Function value obtained: -4.3362
# Current minimum: -12.7388
# Iteration No: 70 started. Searching for the next optimal point.
# Iteration No: 70 ended. Search finished for the next optimal point.
# Time taken: 0.9266
# Function value obtained: 5.1658
# Current minimum: -12.7388
# Iteration No: 71 started. Searching for the next optimal point.
# Iteration No: 71 ended. Search finished for the next optimal point.
# Time taken: 1.0831
# Function value obtained: -12.8737
# Current minimum: -12.8737
# Iteration No: 72 started. Searching for the next optimal point.
# Iteration No: 72 ended. Search finished for the next optimal point.
# Time taken: 1.0835
# Function value obtained: -14.1430
# Current minimum: -14.1430
# Iteration No: 73 started. Searching for the next optimal point.
# Iteration No: 73 ended. Search finished for the next optimal point.
# Time taken: 1.1687
# Function value obtained: 1.1564
# Current minimum: -14.1430
# Iteration No: 74 started. Searching for the next optimal point.
# Iteration No: 74 ended. Search finished for the next optimal point.
# Time taken: 1.1578
# Function value obtained: -12.7068
# Current minimum: -14.1430
# Iteration No: 75 started. Searching for the next optimal point.
# Iteration No: 75 ended. Search finished for the next optimal point.
# Time taken: 1.0772
# Function value obtained: -1.8583
# Current minimum: -14.1430
# Iteration No: 76 started. Searching for the next optimal point.
# Iteration No: 76 ended. Search finished for the next optimal point.
# Time taken: 1.0530
# Function value obtained: -9.2890
# Current minimum: -14.1430
# Iteration No: 77 started. Searching for the next optimal point.
# Iteration No: 77 ended. Search finished for the next optimal point.
# Time taken: 1.5688
# Function value obtained: -7.3269
# Current minimum: -14.1430
# Iteration No: 78 started. Searching for the next optimal point.
# Iteration No: 78 ended. Search finished for the next optimal point.
# Time taken: 1.3228
# Function value obtained: -12.4534
# Current minimum: -14.1430
# Iteration No: 79 started. Searching for the next optimal point.
# Iteration No: 79 ended. Search finished for the next optimal point.
# Time taken: 1.5871
# Function value obtained: -12.6671
# Current minimum: -14.1430
# Iteration No: 80 started. Searching for the next optimal point.
# Iteration No: 80 ended. Search finished for the next optimal point.
# Time taken: 1.2193
# Function value obtained: -13.0933
# Current minimum: -14.1430
# Iteration No: 81 started. Searching for the next optimal point.
# Iteration No: 81 ended. Search finished for the next optimal point.
# Time taken: 1.4694
# Function value obtained: -12.6467
# Current minimum: -14.1430
# Iteration No: 82 started. Searching for the next optimal point.
# Iteration No: 82 ended. Search finished for the next optimal point.
# Time taken: 1.3039
# Function value obtained: -1.8782
# Current minimum: -14.1430
# Iteration No: 83 started. Searching for the next optimal point.
# Iteration No: 83 ended. Search finished for the next optimal point.
# Time taken: 1.0401
# Function value obtained: 12.2459
# Current minimum: -14.1430
# Iteration No: 84 started. Searching for the next optimal point.
# Iteration No: 84 ended. Search finished for the next optimal point.
# Time taken: 1.2039
# Function value obtained: 9.7031
# Current minimum: -14.1430
# Iteration No: 85 started. Searching for the next optimal point.
# Iteration No: 85 ended. Search finished for the next optimal point.
# Time taken: 1.1849
# Function value obtained: -17.7232
# Current minimum: -17.7232
# Iteration No: 86 started. Searching for the next optimal point.
# Iteration No: 86 ended. Search finished for the next optimal point.
# Time taken: 1.2327
# Function value obtained: -2.6695
# Current minimum: -17.7232
# Iteration No: 87 started. Searching for the next optimal point.
# Iteration No: 87 ended. Search finished for the next optimal point.
# Time taken: 1.2616
# Function value obtained: -15.7964
# Current minimum: -17.7232
# Iteration No: 88 started. Searching for the next optimal point.
# Iteration No: 88 ended. Search finished for the next optimal point.
# Time taken: 1.3267
# Function value obtained: -16.4646
# Current minimum: -17.7232
# Iteration No: 89 started. Searching for the next optimal point.
# Iteration No: 89 ended. Search finished for the next optimal point.
# Time taken: 1.6577
# Function value obtained: -16.7476
# Current minimum: -17.7232
# Iteration No: 90 started. Searching for the next optimal point.
# Iteration No: 90 ended. Search finished for the next optimal point.
# Time taken: 1.3054
# Function value obtained: -11.8718
# Current minimum: -17.7232
# Iteration No: 91 started. Searching for the next optimal point.
# Iteration No: 91 ended. Search finished for the next optimal point.
# Time taken: 1.1214
# Function value obtained: -13.2131
# Current minimum: -17.7232
# Iteration No: 92 started. Searching for the next optimal point.
# Iteration No: 92 ended. Search finished for the next optimal point.
# Time taken: 1.5576
# Function value obtained: 7.3091
# Current minimum: -17.7232
# Iteration No: 93 started. Searching for the next optimal point.
# Iteration No: 93 ended. Search finished for the next optimal point.
# Time taken: 1.3927
# Function value obtained: -9.1053
# Current minimum: -17.7232
# Iteration No: 94 started. Searching for the next optimal point.
# Iteration No: 94 ended. Search finished for the next optimal point.
# Time taken: 1.2849
# Function value obtained: -4.8004
# Current minimum: -17.7232
# Iteration No: 95 started. Searching for the next optimal point.
# Iteration No: 95 ended. Search finished for the next optimal point.
# Time taken: 1.5089
# Function value obtained: -16.4416
# Current minimum: -17.7232
# Iteration No: 96 started. Searching for the next optimal point.
# Iteration No: 96 ended. Search finished for the next optimal point.
# Time taken: 1.3832
# Function value obtained: -12.4280
# Current minimum: -17.7232
# Iteration No: 97 started. Searching for the next optimal point.
# Iteration No: 97 ended. Search finished for the next optimal point.
# Time taken: 1.5499
# Function value obtained: -3.9510
# Current minimum: -17.7232
# Iteration No: 98 started. Searching for the next optimal point.
# Iteration No: 98 ended. Search finished for the next optimal point.
# Time taken: 1.8343
# Function value obtained: -10.3246
# Current minimum: -17.7232
# Iteration No: 99 started. Searching for the next optimal point.
# Iteration No: 99 ended. Search finished for the next optimal point.
# Time taken: 1.8358
# Function value obtained: -6.9286
# Current minimum: -17.7232
# Iteration No: 100 started. Searching for the next optimal point.
# Iteration No: 100 ended. Search finished for the next optimal point.
# Time taken: 1.9678
# Function value obtained: 1.6961
# Current minimum: -17.7232
# 0.04126998111938252
# 6.104575529126478

# %%
p=5
backend = Aer.get_backend('statevector_simulator')
quantum_instance = QuantumInstance(backend)
initial_state, _ = construct_initial_state(3,3)
qc = ansatz(9,p, operator)
initial_state.append(qc, range(3*3))
initial_state.parameter_bounds = [(-2*np.pi, 2*np.pi)]*initial_state.num_parameters
# print(transpile(initial_state, basis_gates = ['id', 'rx', 'ry', 'rz', 'cx']).draw(fold=200))
vqe = VQE(ansatz = initial_state, optimizer = Global_Optimizer(), include_custom=True, quantum_instance = quantum_instance, initial_point = next_point)
results = vqe.compute_minimum_eigenvalue(operator)
probs = Statevector(results.eigenstate).probabilities_dict()
p_s = 0
for string in x_s:
    p_s += probs[string] if string in probs else 0
print(p_s)
print(results.eigenvalue+offset)
next_point = results.optimal_point[0:p]+[0]+results.optimal_point[p:2*p]+[0]
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 0.5224
# Function value obtained: 0.2406
# Current minimum: 0.2406
# Iteration No: 2 started. Evaluating function at random point.
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 0.0844
# Function value obtained: -1.0568
# Current minimum: -1.0568
# Iteration No: 3 started. Evaluating function at random point.
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 0.0799
# Function value obtained: 0.1762
# Current minimum: -1.0568
# Iteration No: 4 started. Evaluating function at random point.
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 0.0799
# Function value obtained: 1.5055
# Current minimum: -1.0568
# Iteration No: 5 started. Evaluating function at random point.
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 0.0812
# Function value obtained: -1.1012
# Current minimum: -1.1012
# Iteration No: 6 started. Evaluating function at random point.
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 0.0815
# Function value obtained: -1.5905
# Current minimum: -1.5905
# Iteration No: 7 started. Evaluating function at random point.
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 0.0814
# Function value obtained: 2.1567
# Current minimum: -1.5905
# Iteration No: 8 started. Evaluating function at random point.
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 0.0897
# Function value obtained: 1.4177
# Current minimum: -1.5905
# Iteration No: 9 started. Evaluating function at random point.
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 0.0824
# Function value obtained: -1.7141
# Current minimum: -1.7141
# Iteration No: 10 started. Evaluating function at random point.
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 1.2621
# Function value obtained: -0.7712
# Current minimum: -1.7141
# Iteration No: 11 started. Searching for the next optimal point.
# Iteration No: 11 ended. Search finished for the next optimal point.
# Time taken: 0.4647
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 12 started. Searching for the next optimal point.
# Iteration No: 12 ended. Search finished for the next optimal point.
# Time taken: 0.3181
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 13 started. Searching for the next optimal point.
# Iteration No: 13 ended. Search finished for the next optimal point.
# Time taken: 0.2613
# Function value obtained: 1.4636
# Current minimum: -19.1027
# Iteration No: 14 started. Searching for the next optimal point.
# Iteration No: 14 ended. Search finished for the next optimal point.
# Time taken: 0.3414
# Function value obtained: -5.2509
# Current minimum: -19.1027
# Iteration No: 15 started. Searching for the next optimal point.
# Iteration No: 15 ended. Search finished for the next optimal point.
# Time taken: 0.3228
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 16 started. Searching for the next optimal point.
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 0.3252
# Function value obtained: -2.4581
# Current minimum: -19.1027
# Iteration No: 17 started. Searching for the next optimal point.
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 0.3661
# Function value obtained: -9.9609
# Current minimum: -19.1027
# Iteration No: 18 started. Searching for the next optimal point.
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 0.3441
# Function value obtained: 7.6089
# Current minimum: -19.1027
# Iteration No: 19 started. Searching for the next optimal point.
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 0.5768
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 20 started. Searching for the next optimal point.
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 0.3449
# Function value obtained: -12.8305
# Current minimum: -19.1027
# Iteration No: 21 started. Searching for the next optimal point.
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 0.3106
# Function value obtained: 3.7811
# Current minimum: -19.1027
# Iteration No: 22 started. Searching for the next optimal point.
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 0.4860
# Function value obtained: -11.5912
# Current minimum: -19.1027
# Iteration No: 23 started. Searching for the next optimal point.
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 0.4193
# Function value obtained: -0.2287
# Current minimum: -19.1027
# Iteration No: 24 started. Searching for the next optimal point.
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 0.4898
# Function value obtained: -5.6703
# Current minimum: -19.1027
# Iteration No: 25 started. Searching for the next optimal point.
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 0.4187
# Function value obtained: 8.9776
# Current minimum: -19.1027
# Iteration No: 26 started. Searching for the next optimal point.
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 0.3654
# Function value obtained: -0.6666
# Current minimum: -19.1027
# Iteration No: 27 started. Searching for the next optimal point.
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 0.3346
# Function value obtained: 0.9022
# Current minimum: -19.1027
# Iteration No: 28 started. Searching for the next optimal point.
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 0.4378
# Function value obtained: 4.0880
# Current minimum: -19.1027
# Iteration No: 29 started. Searching for the next optimal point.
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 0.4391
# Function value obtained: -0.7229
# Current minimum: -19.1027
# Iteration No: 30 started. Searching for the next optimal point.
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 0.4235
# Function value obtained: -2.2718
# Current minimum: -19.1027
# Iteration No: 31 started. Searching for the next optimal point.
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 0.4502
# Function value obtained: -0.5062
# Current minimum: -19.1027
# Iteration No: 32 started. Searching for the next optimal point.
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 0.6012
# Function value obtained: -0.3161
# Current minimum: -19.1027
# Iteration No: 33 started. Searching for the next optimal point.
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 0.4603
# Function value obtained: -3.3639
# Current minimum: -19.1027
# Iteration No: 34 started. Searching for the next optimal point.
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 0.5894
# Function value obtained: -2.4487
# Current minimum: -19.1027
# Iteration No: 35 started. Searching for the next optimal point.
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 0.5447
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 36 started. Searching for the next optimal point.
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 0.4540
# Function value obtained: 2.1147
# Current minimum: -19.1027
# Iteration No: 37 started. Searching for the next optimal point.
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 0.5032
# Function value obtained: -2.2298
# Current minimum: -19.1027
# Iteration No: 38 started. Searching for the next optimal point.
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 0.5464
# Function value obtained: 4.0528
# Current minimum: -19.1027
# Iteration No: 39 started. Searching for the next optimal point.
# Iteration No: 39 ended. Search finished for the next optimal point.
# Time taken: 0.4325
# Function value obtained: -1.0894
# Current minimum: -19.1027
# Iteration No: 40 started. Searching for the next optimal point.
# Iteration No: 40 ended. Search finished for the next optimal point.
# Time taken: 0.4610
# Function value obtained: 2.6484
# Current minimum: -19.1027
# Iteration No: 41 started. Searching for the next optimal point.
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 0.6118
# Function value obtained: -1.2854
# Current minimum: -19.1027
# Iteration No: 42 started. Searching for the next optimal point.
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 0.8450
# Function value obtained: 6.3186
# Current minimum: -19.1027
# Iteration No: 43 started. Searching for the next optimal point.
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 0.6321
# Function value obtained: -1.1760
# Current minimum: -19.1027
# Iteration No: 44 started. Searching for the next optimal point.
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 0.5836
# Function value obtained: 0.4172
# Current minimum: -19.1027
# Iteration No: 45 started. Searching for the next optimal point.
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 0.6802
# Function value obtained: 9.9037
# Current minimum: -19.1027
# Iteration No: 46 started. Searching for the next optimal point.
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 0.6944
# Function value obtained: 3.8771
# Current minimum: -19.1027
# Iteration No: 47 started. Searching for the next optimal point.
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 0.6272
# Function value obtained: -0.0075
# Current minimum: -19.1027
# Iteration No: 48 started. Searching for the next optimal point.
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 0.6743
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 49 started. Searching for the next optimal point.
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 0.6932
# Function value obtained: 1.2717
# Current minimum: -19.1027
# Iteration No: 50 started. Searching for the next optimal point.
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 0.6911
# Function value obtained: -4.1509
# Current minimum: -19.1027
# Iteration No: 51 started. Searching for the next optimal point.
# Iteration No: 51 ended. Search finished for the next optimal point.
# Time taken: 0.6742
# Function value obtained: 2.9355
# Current minimum: -19.1027
# Iteration No: 52 started. Searching for the next optimal point.
# Iteration No: 52 ended. Search finished for the next optimal point.
# Time taken: 0.7493
# Function value obtained: 1.1628
# Current minimum: -19.1027
# Iteration No: 53 started. Searching for the next optimal point.
# Iteration No: 53 ended. Search finished for the next optimal point.
# Time taken: 0.7202
# Function value obtained: -3.2364
# Current minimum: -19.1027
# Iteration No: 54 started. Searching for the next optimal point.
# Iteration No: 54 ended. Search finished for the next optimal point.
# Time taken: 0.6206
# Function value obtained: 4.1605
# Current minimum: -19.1027
# Iteration No: 55 started. Searching for the next optimal point.
# Iteration No: 55 ended. Search finished for the next optimal point.
# Time taken: 0.5824
# Function value obtained: 6.2521
# Current minimum: -19.1027
# Iteration No: 56 started. Searching for the next optimal point.
# Iteration No: 56 ended. Search finished for the next optimal point.
# Time taken: 0.5452
# Function value obtained: -0.6112
# Current minimum: -19.1027
# Iteration No: 57 started. Searching for the next optimal point.
# Iteration No: 57 ended. Search finished for the next optimal point.
# Time taken: 0.6072
# Function value obtained: 6.1110
# Current minimum: -19.1027
# Iteration No: 58 started. Searching for the next optimal point.
# Iteration No: 58 ended. Search finished for the next optimal point.
# Time taken: 0.6227
# Function value obtained: 0.4308
# Current minimum: -19.1027
# Iteration No: 59 started. Searching for the next optimal point.
# Iteration No: 59 ended. Search finished for the next optimal point.
# Time taken: 0.4924
# Function value obtained: -1.3043
# Current minimum: -19.1027
# Iteration No: 60 started. Searching for the next optimal point.
# Iteration No: 60 ended. Search finished for the next optimal point.
# Time taken: 0.6649
# Function value obtained: -0.0401
# Current minimum: -19.1027
# Iteration No: 61 started. Searching for the next optimal point.
# Iteration No: 61 ended. Search finished for the next optimal point.
# Time taken: 0.6125
# Function value obtained: -1.4555
# Current minimum: -19.1027
# Iteration No: 62 started. Searching for the next optimal point.
# Iteration No: 62 ended. Search finished for the next optimal point.
# Time taken: 0.6062
# Function value obtained: 0.1176
# Current minimum: -19.1027
# Iteration No: 63 started. Searching for the next optimal point.
# Iteration No: 63 ended. Search finished for the next optimal point.
# Time taken: 1.0484
# Function value obtained: -0.2187
# Current minimum: -19.1027
# Iteration No: 64 started. Searching for the next optimal point.
# Iteration No: 64 ended. Search finished for the next optimal point.
# Time taken: 0.8936
# Function value obtained: 0.4990
# Current minimum: -19.1027
# Iteration No: 65 started. Searching for the next optimal point.
# Iteration No: 65 ended. Search finished for the next optimal point.
# Time taken: 0.8729
# Function value obtained: -9.5912
# Current minimum: -19.1027
# Iteration No: 66 started. Searching for the next optimal point.
# Iteration No: 66 ended. Search finished for the next optimal point.
# Time taken: 0.7252
# Function value obtained: 0.6729
# Current minimum: -19.1027
# Iteration No: 67 started. Searching for the next optimal point.
# Iteration No: 67 ended. Search finished for the next optimal point.
# Time taken: 0.7716
# Function value obtained: 7.7430
# Current minimum: -19.1027
# Iteration No: 68 started. Searching for the next optimal point.
# Iteration No: 68 ended. Search finished for the next optimal point.
# Time taken: 0.7998
# Function value obtained: 0.8798
# Current minimum: -19.1027
# Iteration No: 69 started. Searching for the next optimal point.
# Iteration No: 69 ended. Search finished for the next optimal point.
# Time taken: 0.8504
# Function value obtained: 1.1959
# Current minimum: -19.1027
# Iteration No: 70 started. Searching for the next optimal point.
# Iteration No: 70 ended. Search finished for the next optimal point.
# Time taken: 0.8820
# Function value obtained: 8.5494
# Current minimum: -19.1027
# Iteration No: 71 started. Searching for the next optimal point.
# Iteration No: 71 ended. Search finished for the next optimal point.
# Time taken: 0.7872
# Function value obtained: -0.5186
# Current minimum: -19.1027
# Iteration No: 72 started. Searching for the next optimal point.
# Iteration No: 72 ended. Search finished for the next optimal point.
# Time taken: 0.7786
# Function value obtained: 5.7674
# Current minimum: -19.1027
# Iteration No: 73 started. Searching for the next optimal point.
# Iteration No: 73 ended. Search finished for the next optimal point.
# Time taken: 0.9773
# Function value obtained: 1.0649
# Current minimum: -19.1027
# Iteration No: 74 started. Searching for the next optimal point.
# Iteration No: 74 ended. Search finished for the next optimal point.
# Time taken: 0.8275
# Function value obtained: 1.7309
# Current minimum: -19.1027
# Iteration No: 75 started. Searching for the next optimal point.
# Iteration No: 75 ended. Search finished for the next optimal point.
# Time taken: 0.7937
# Function value obtained: -7.3853
# Current minimum: -19.1027
# Iteration No: 76 started. Searching for the next optimal point.
# Iteration No: 76 ended. Search finished for the next optimal point.
# Time taken: 0.7960
# Function value obtained: 3.3350
# Current minimum: -19.1027
# Iteration No: 77 started. Searching for the next optimal point.
# Iteration No: 77 ended. Search finished for the next optimal point.
# Time taken: 0.7315
# Function value obtained: -1.6486
# Current minimum: -19.1027
# Iteration No: 78 started. Searching for the next optimal point.
# Iteration No: 78 ended. Search finished for the next optimal point.
# Time taken: 0.7821
# Function value obtained: 0.6556
# Current minimum: -19.1027
# Iteration No: 79 started. Searching for the next optimal point.
# Iteration No: 79 ended. Search finished for the next optimal point.
# Time taken: 0.7095
# Function value obtained: 1.5484
# Current minimum: -19.1027
# Iteration No: 80 started. Searching for the next optimal point.
# Iteration No: 80 ended. Search finished for the next optimal point.
# Time taken: 0.7790
# Function value obtained: 0.1572
# Current minimum: -19.1027
# Iteration No: 81 started. Searching for the next optimal point.
# Iteration No: 81 ended. Search finished for the next optimal point.
# Time taken: 0.7331
# Function value obtained: -1.0575
# Current minimum: -19.1027
# Iteration No: 82 started. Searching for the next optimal point.
# Iteration No: 82 ended. Search finished for the next optimal point.
# Time taken: 0.9712
# Function value obtained: -0.6599
# Current minimum: -19.1027
# Iteration No: 83 started. Searching for the next optimal point.
# Iteration No: 83 ended. Search finished for the next optimal point.
# Time taken: 0.8006
# Function value obtained: -2.4449
# Current minimum: -19.1027
# Iteration No: 84 started. Searching for the next optimal point.
# Iteration No: 84 ended. Search finished for the next optimal point.
# Time taken: 0.9714
# Function value obtained: -1.2280
# Current minimum: -19.1027
# Iteration No: 85 started. Searching for the next optimal point.
# Iteration No: 85 ended. Search finished for the next optimal point.
# Time taken: 1.3151
# Function value obtained: 0.5946
# Current minimum: -19.1027
# Iteration No: 86 started. Searching for the next optimal point.
# Iteration No: 86 ended. Search finished for the next optimal point.
# Time taken: 1.1924
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 87 started. Searching for the next optimal point.
# Iteration No: 87 ended. Search finished for the next optimal point.
# Time taken: 1.0153
# Function value obtained: 0.9087
# Current minimum: -19.1027
# Iteration No: 88 started. Searching for the next optimal point.
# Iteration No: 88 ended. Search finished for the next optimal point.
# Time taken: 0.8433
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 89 started. Searching for the next optimal point.
# Iteration No: 89 ended. Search finished for the next optimal point.
# Time taken: 0.7895
# Function value obtained: -6.2784
# Current minimum: -19.1027
# Iteration No: 90 started. Searching for the next optimal point.
# Iteration No: 90 ended. Search finished for the next optimal point.
# Time taken: 0.9455
# Function value obtained: 7.7252
# Current minimum: -19.1027
# Iteration No: 91 started. Searching for the next optimal point.
# Iteration No: 91 ended. Search finished for the next optimal point.
# Time taken: 1.1109
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 92 started. Searching for the next optimal point.
# Iteration No: 92 ended. Search finished for the next optimal point.
# Time taken: 1.1156
# Function value obtained: -9.5762
# Current minimum: -19.1027
# Iteration No: 93 started. Searching for the next optimal point.
# Iteration No: 93 ended. Search finished for the next optimal point.
# Time taken: 0.9149
# Function value obtained: 11.2530
# Current minimum: -19.1027
# Iteration No: 94 started. Searching for the next optimal point.
# Iteration No: 94 ended. Search finished for the next optimal point.
# Time taken: 0.9769
# Function value obtained: 6.3815
# Current minimum: -19.1027
# Iteration No: 95 started. Searching for the next optimal point.
# Iteration No: 95 ended. Search finished for the next optimal point.
# Time taken: 1.1692
# Function value obtained: -4.1035
# Current minimum: -19.1027
# Iteration No: 96 started. Searching for the next optimal point.
# Iteration No: 96 ended. Search finished for the next optimal point.
# Time taken: 0.9371
# Function value obtained: -2.8685
# Current minimum: -19.1027
# Iteration No: 97 started. Searching for the next optimal point.
# Iteration No: 97 ended. Search finished for the next optimal point.
# Time taken: 1.4069
# Function value obtained: 2.5630
# Current minimum: -19.1027
# Iteration No: 98 started. Searching for the next optimal point.
# Iteration No: 98 ended. Search finished for the next optimal point.
# Time taken: 1.0342
# Function value obtained: 0.2081
# Current minimum: -19.1027
# Iteration No: 99 started. Searching for the next optimal point.
# Iteration No: 99 ended. Search finished for the next optimal point.
# Time taken: 1.1250
# Function value obtained: 3.0654
# Current minimum: -19.1027
# Iteration No: 100 started. Searching for the next optimal point.
# Iteration No: 100 ended. Search finished for the next optimal point.
# Time taken: 1.1094
# Function value obtained: -6.2650
# Current minimum: -19.1027
# 0.07407407407407367
# 4.72509988888887

# %%
p=6
backend = Aer.get_backend('statevector_simulator')
quantum_instance = QuantumInstance(backend)
initial_state, _ = construct_initial_state(3,3)
qc = ansatz(9,p, operator)
initial_state.append(qc, range(3*3))
initial_state.parameter_bounds = [(-2*np.pi, 2*np.pi)]*initial_state.num_parameters
# print(transpile(initial_state, basis_gates = ['id', 'rx', 'ry', 'rz', 'cx']).draw(fold=200))
vqe = VQE(ansatz = initial_state, optimizer = Global_Optimizer(), include_custom=True, quantum_instance = quantum_instance, initial_point = next_point)
results = vqe.compute_minimum_eigenvalue(operator)
probs = Statevector(results.eigenstate).probabilities_dict()
p_s = 0
for string in x_s:
    p_s += probs[string] if string in probs else 0
print(p_s)
print(results.eigenvalue+offset)
next_point = results.optimal_point[0:p]+[0]+results.optimal_point[p:2*p]+[0]
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 0.3057
# Function value obtained: -0.7017
# Current minimum: -0.7017
# Iteration No: 2 started. Evaluating function at random point.
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 0.0944
# Function value obtained: -4.7634
# Current minimum: -4.7634
# Iteration No: 3 started. Evaluating function at random point.
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 0.0925
# Function value obtained: -0.5341
# Current minimum: -4.7634
# Iteration No: 4 started. Evaluating function at random point.
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 0.0917
# Function value obtained: -1.2528
# Current minimum: -4.7634
# Iteration No: 5 started. Evaluating function at random point.
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 0.0901
# Function value obtained: 0.0745
# Current minimum: -4.7634
# Iteration No: 6 started. Evaluating function at random point.
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 0.0896
# Function value obtained: -0.3875
# Current minimum: -4.7634
# Iteration No: 7 started. Evaluating function at random point.
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 0.0934
# Function value obtained: 0.1597
# Current minimum: -4.7634
# Iteration No: 8 started. Evaluating function at random point.
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 0.0910
# Function value obtained: 0.2510
# Current minimum: -4.7634
# Iteration No: 9 started. Evaluating function at random point.
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 0.0900
# Function value obtained: -0.2444
# Current minimum: -4.7634
# Iteration No: 10 started. Evaluating function at random point.
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 0.2795
# Function value obtained: 0.9496
# Current minimum: -4.7634
# Iteration No: 11 started. Searching for the next optimal point.
# Iteration No: 11 ended. Search finished for the next optimal point.
# Time taken: 0.3687
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 12 started. Searching for the next optimal point.
# Iteration No: 12 ended. Search finished for the next optimal point.
# Time taken: 0.2630
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 13 started. Searching for the next optimal point.
# Iteration No: 13 ended. Search finished for the next optimal point.
# Time taken: 0.3127
# Function value obtained: 0.4630
# Current minimum: -19.1027
# Iteration No: 14 started. Searching for the next optimal point.
# Iteration No: 14 ended. Search finished for the next optimal point.
# Time taken: 0.6161
# Function value obtained: 2.6806
# Current minimum: -19.1027
# Iteration No: 15 started. Searching for the next optimal point.
# Iteration No: 15 ended. Search finished for the next optimal point.
# Time taken: 0.3355
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 16 started. Searching for the next optimal point.
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 0.4054
# Function value obtained: -0.3088
# Current minimum: -19.1027
# Iteration No: 17 started. Searching for the next optimal point.
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 0.3812
# Function value obtained: -18.3480
# Current minimum: -19.1027
# Iteration No: 18 started. Searching for the next optimal point.
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 0.4490
# Function value obtained: -1.9560
# Current minimum: -19.1027
# Iteration No: 19 started. Searching for the next optimal point.
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 0.3604
# Function value obtained: 8.6467
# Current minimum: -19.1027
# Iteration No: 20 started. Searching for the next optimal point.
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 0.3271
# Function value obtained: 10.5030
# Current minimum: -19.1027
# Iteration No: 21 started. Searching for the next optimal point.
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 0.3285
# Function value obtained: 0.4247
# Current minimum: -19.1027
# Iteration No: 22 started. Searching for the next optimal point.
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 0.4239
# Function value obtained: 4.0694
# Current minimum: -19.1027
# Iteration No: 23 started. Searching for the next optimal point.
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 0.3694
# Function value obtained: -5.0454
# Current minimum: -19.1027
# Iteration No: 24 started. Searching for the next optimal point.
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 0.3378
# Function value obtained: -0.7493
# Current minimum: -19.1027
# Iteration No: 25 started. Searching for the next optimal point.
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 0.3399
# Function value obtained: -2.1512
# Current minimum: -19.1027
# Iteration No: 26 started. Searching for the next optimal point.
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 0.3469
# Function value obtained: -0.3860
# Current minimum: -19.1027
# Iteration No: 27 started. Searching for the next optimal point.
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 0.3258
# Function value obtained: -0.5262
# Current minimum: -19.1027
# Iteration No: 28 started. Searching for the next optimal point.
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 0.4307
# Function value obtained: 3.3524
# Current minimum: -19.1027
# Iteration No: 29 started. Searching for the next optimal point.
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 0.6699
# Function value obtained: -0.3301
# Current minimum: -19.1027
# Iteration No: 30 started. Searching for the next optimal point.
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 0.3596
# Function value obtained: 2.2969
# Current minimum: -19.1027
# Iteration No: 31 started. Searching for the next optimal point.
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 0.4265
# Function value obtained: -1.2462
# Current minimum: -19.1027
# Iteration No: 32 started. Searching for the next optimal point.
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 0.3590
# Function value obtained: -0.3822
# Current minimum: -19.1027
# Iteration No: 33 started. Searching for the next optimal point.
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 0.4823
# Function value obtained: -0.3638
# Current minimum: -19.1027
# Iteration No: 34 started. Searching for the next optimal point.
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 0.4877
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 35 started. Searching for the next optimal point.
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 0.4271
# Function value obtained: 0.7447
# Current minimum: -19.1027
# Iteration No: 36 started. Searching for the next optimal point.
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 0.4146
# Function value obtained: -1.2855
# Current minimum: -19.1027
# Iteration No: 37 started. Searching for the next optimal point.
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 0.4495
# Function value obtained: -0.1689
# Current minimum: -19.1027
# Iteration No: 38 started. Searching for the next optimal point.
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 0.4388
# Function value obtained: -1.4576
# Current minimum: -19.1027
# Iteration No: 39 started. Searching for the next optimal point.
# Iteration No: 39 ended. Search finished for the next optimal point.
# Time taken: 0.4334
# Function value obtained: -0.2647
# Current minimum: -19.1027
# Iteration No: 40 started. Searching for the next optimal point.
# Iteration No: 40 ended. Search finished for the next optimal point.
# Time taken: 0.4889
# Function value obtained: 0.7315
# Current minimum: -19.1027
# Iteration No: 41 started. Searching for the next optimal point.
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 0.5286
# Function value obtained: -0.6669
# Current minimum: -19.1027
# Iteration No: 42 started. Searching for the next optimal point.
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 0.5482
# Function value obtained: -1.7154
# Current minimum: -19.1027
# Iteration No: 43 started. Searching for the next optimal point.
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 0.5606
# Function value obtained: 0.2858
# Current minimum: -19.1027
# Iteration No: 44 started. Searching for the next optimal point.
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 0.5275
# Function value obtained: -0.3931
# Current minimum: -19.1027
# Iteration No: 45 started. Searching for the next optimal point.
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 0.5186
# Function value obtained: 0.9139
# Current minimum: -19.1027
# Iteration No: 46 started. Searching for the next optimal point.
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 0.6661
# Function value obtained: -4.3200
# Current minimum: -19.1027
# Iteration No: 47 started. Searching for the next optimal point.
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 0.4886
# Function value obtained: -0.3043
# Current minimum: -19.1027
# Iteration No: 48 started. Searching for the next optimal point.
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 0.9412
# Function value obtained: 0.6564
# Current minimum: -19.1027
# Iteration No: 49 started. Searching for the next optimal point.
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 0.6717
# Function value obtained: 10.2672
# Current minimum: -19.1027
# Iteration No: 50 started. Searching for the next optimal point.
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 0.7285
# Function value obtained: 4.9616
# Current minimum: -19.1027
# Iteration No: 51 started. Searching for the next optimal point.
# Iteration No: 51 ended. Search finished for the next optimal point.
# Time taken: 1.0426
# Function value obtained: -1.0901
# Current minimum: -19.1027
# Iteration No: 52 started. Searching for the next optimal point.
# Iteration No: 52 ended. Search finished for the next optimal point.
# Time taken: 0.6693
# Function value obtained: -1.0163
# Current minimum: -19.1027
# Iteration No: 53 started. Searching for the next optimal point.
# Iteration No: 53 ended. Search finished for the next optimal point.
# Time taken: 0.6642
# Function value obtained: 5.1840
# Current minimum: -19.1027
# Iteration No: 54 started. Searching for the next optimal point.
# Iteration No: 54 ended. Search finished for the next optimal point.
# Time taken: 0.5586
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 55 started. Searching for the next optimal point.
# Iteration No: 55 ended. Search finished for the next optimal point.
# Time taken: 0.7394
# Function value obtained: 0.0559
# Current minimum: -19.1027
# Iteration No: 56 started. Searching for the next optimal point.
# Iteration No: 56 ended. Search finished for the next optimal point.
# Time taken: 0.5865
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 57 started. Searching for the next optimal point.
# Iteration No: 57 ended. Search finished for the next optimal point.
# Time taken: 0.6945
# Function value obtained: -1.4822
# Current minimum: -19.1027
# Iteration No: 58 started. Searching for the next optimal point.
# Iteration No: 58 ended. Search finished for the next optimal point.
# Time taken: 0.7324
# Function value obtained: -0.2750
# Current minimum: -19.1027
# Iteration No: 59 started. Searching for the next optimal point.
# Iteration No: 59 ended. Search finished for the next optimal point.
# Time taken: 0.6902
# Function value obtained: 1.0899
# Current minimum: -19.1027
# Iteration No: 60 started. Searching for the next optimal point.
# Iteration No: 60 ended. Search finished for the next optimal point.
# Time taken: 0.7411
# Function value obtained: 6.5904
# Current minimum: -19.1027
# Iteration No: 61 started. Searching for the next optimal point.
# Iteration No: 61 ended. Search finished for the next optimal point.
# Time taken: 0.8549
# Function value obtained: 1.0714
# Current minimum: -19.1027
# Iteration No: 62 started. Searching for the next optimal point.
# Iteration No: 62 ended. Search finished for the next optimal point.
# Time taken: 0.9469
# Function value obtained: -1.0764
# Current minimum: -19.1027
# Iteration No: 63 started. Searching for the next optimal point.
# Iteration No: 63 ended. Search finished for the next optimal point.
# Time taken: 0.7541
# Function value obtained: 0.2574
# Current minimum: -19.1027
# Iteration No: 64 started. Searching for the next optimal point.
# Iteration No: 64 ended. Search finished for the next optimal point.
# Time taken: 0.7820
# Function value obtained: -0.8180
# Current minimum: -19.1027
# Iteration No: 65 started. Searching for the next optimal point.
# Iteration No: 65 ended. Search finished for the next optimal point.
# Time taken: 0.6209
# Function value obtained: 4.6354
# Current minimum: -19.1027
# Iteration No: 66 started. Searching for the next optimal point.
# Iteration No: 66 ended. Search finished for the next optimal point.
# Time taken: 0.7215
# Function value obtained: 0.9714
# Current minimum: -19.1027
# Iteration No: 67 started. Searching for the next optimal point.
# Iteration No: 67 ended. Search finished for the next optimal point.
# Time taken: 0.7081
# Function value obtained: 0.5974
# Current minimum: -19.1027
# Iteration No: 68 started. Searching for the next optimal point.
# Iteration No: 68 ended. Search finished for the next optimal point.
# Time taken: 0.9383
# Function value obtained: -0.9967
# Current minimum: -19.1027
# Iteration No: 69 started. Searching for the next optimal point.
# Iteration No: 69 ended. Search finished for the next optimal point.
# Time taken: 1.0183
# Function value obtained: 0.3961
# Current minimum: -19.1027
# Iteration No: 70 started. Searching for the next optimal point.
# Iteration No: 70 ended. Search finished for the next optimal point.
# Time taken: 0.8299
# Function value obtained: -0.7549
# Current minimum: -19.1027
# Iteration No: 71 started. Searching for the next optimal point.
# Iteration No: 71 ended. Search finished for the next optimal point.
# Time taken: 0.8555
# Function value obtained: 3.8393
# Current minimum: -19.1027
# Iteration No: 72 started. Searching for the next optimal point.
# Iteration No: 72 ended. Search finished for the next optimal point.
# Time taken: 0.8487
# Function value obtained: 1.4554
# Current minimum: -19.1027
# Iteration No: 73 started. Searching for the next optimal point.
# Iteration No: 73 ended. Search finished for the next optimal point.
# Time taken: 0.8890
# Function value obtained: -1.2931
# Current minimum: -19.1027
# Iteration No: 74 started. Searching for the next optimal point.
# Iteration No: 74 ended. Search finished for the next optimal point.
# Time taken: 0.9519
# Function value obtained: 2.5548
# Current minimum: -19.1027
# Iteration No: 75 started. Searching for the next optimal point.
# Iteration No: 75 ended. Search finished for the next optimal point.
# Time taken: 0.8587
# Function value obtained: -0.9450
# Current minimum: -19.1027
# Iteration No: 76 started. Searching for the next optimal point.
# Iteration No: 76 ended. Search finished for the next optimal point.
# Time taken: 0.9425
# Function value obtained: -0.4395
# Current minimum: -19.1027
# Iteration No: 77 started. Searching for the next optimal point.
# Iteration No: 77 ended. Search finished for the next optimal point.
# Time taken: 0.7925
# Function value obtained: -16.5513
# Current minimum: -19.1027
# Iteration No: 78 started. Searching for the next optimal point.
# Iteration No: 78 ended. Search finished for the next optimal point.
# Time taken: 1.0185
# Function value obtained: 2.8149
# Current minimum: -19.1027
# Iteration No: 79 started. Searching for the next optimal point.
# Iteration No: 79 ended. Search finished for the next optimal point.
# Time taken: 0.9150
# Function value obtained: -0.2291
# Current minimum: -19.1027
# Iteration No: 80 started. Searching for the next optimal point.
# Iteration No: 80 ended. Search finished for the next optimal point.
# Time taken: 0.9909
# Function value obtained: 1.9790
# Current minimum: -19.1027
# Iteration No: 81 started. Searching for the next optimal point.
# Iteration No: 81 ended. Search finished for the next optimal point.
# Time taken: 0.8609
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 82 started. Searching for the next optimal point.
# Iteration No: 82 ended. Search finished for the next optimal point.
# Time taken: 0.8284
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 83 started. Searching for the next optimal point.
# Iteration No: 83 ended. Search finished for the next optimal point.
# Time taken: 0.8030
# Function value obtained: 1.9793
# Current minimum: -19.1027
# Iteration No: 84 started. Searching for the next optimal point.
# Iteration No: 84 ended. Search finished for the next optimal point.
# Time taken: 0.9120
# Function value obtained: 0.8386
# Current minimum: -19.1027
# Iteration No: 85 started. Searching for the next optimal point.
# Iteration No: 85 ended. Search finished for the next optimal point.
# Time taken: 0.8298
# Function value obtained: -0.5404
# Current minimum: -19.1027
# Iteration No: 86 started. Searching for the next optimal point.
# Iteration No: 86 ended. Search finished for the next optimal point.
# Time taken: 0.9107
# Function value obtained: 1.1342
# Current minimum: -19.1027
# Iteration No: 87 started. Searching for the next optimal point.
# Iteration No: 87 ended. Search finished for the next optimal point.
# Time taken: 1.1720
# Function value obtained: -1.4280
# Current minimum: -19.1027
# Iteration No: 88 started. Searching for the next optimal point.
# Iteration No: 88 ended. Search finished for the next optimal point.
# Time taken: 0.9189
# Function value obtained: -0.5263
# Current minimum: -19.1027
# Iteration No: 89 started. Searching for the next optimal point.
# Iteration No: 89 ended. Search finished for the next optimal point.
# Time taken: 0.8965
# Function value obtained: -0.8905
# Current minimum: -19.1027
# Iteration No: 90 started. Searching for the next optimal point.
# Iteration No: 90 ended. Search finished for the next optimal point.
# Time taken: 1.0197
# Function value obtained: 0.2879
# Current minimum: -19.1027
# Iteration No: 91 started. Searching for the next optimal point.
# Iteration No: 91 ended. Search finished for the next optimal point.
# Time taken: 1.0223
# Function value obtained: -4.4987
# Current minimum: -19.1027
# Iteration No: 92 started. Searching for the next optimal point.
# Iteration No: 92 ended. Search finished for the next optimal point.
# Time taken: 0.9835
# Function value obtained: 0.6534
# Current minimum: -19.1027
# Iteration No: 93 started. Searching for the next optimal point.
# Iteration No: 93 ended. Search finished for the next optimal point.
# Time taken: 1.0017
# Function value obtained: -6.2294
# Current minimum: -19.1027
# Iteration No: 94 started. Searching for the next optimal point.
# Iteration No: 94 ended. Search finished for the next optimal point.
# Time taken: 1.0955
# Function value obtained: -4.5520
# Current minimum: -19.1027
# Iteration No: 95 started. Searching for the next optimal point.
# Iteration No: 95 ended. Search finished for the next optimal point.
# Time taken: 1.0517
# Function value obtained: 0.2752
# Current minimum: -19.1027
# Iteration No: 96 started. Searching for the next optimal point.
# Iteration No: 96 ended. Search finished for the next optimal point.
# Time taken: 1.1112
# Function value obtained: 0.3417
# Current minimum: -19.1027
# Iteration No: 97 started. Searching for the next optimal point.
# Iteration No: 97 ended. Search finished for the next optimal point.
# Time taken: 1.0020
# Function value obtained: 1.3345
# Current minimum: -19.1027
# Iteration No: 98 started. Searching for the next optimal point.
# Iteration No: 98 ended. Search finished for the next optimal point.
# Time taken: 1.0296
# Function value obtained: 0.0028
# Current minimum: -19.1027
# Iteration No: 99 started. Searching for the next optimal point.
# Iteration No: 99 ended. Search finished for the next optimal point.
# Time taken: 1.0255
# Function value obtained: -0.4250
# Current minimum: -19.1027
# Iteration No: 100 started. Searching for the next optimal point.
# Iteration No: 100 ended. Search finished for the next optimal point.
# Time taken: 1.2136
# Function value obtained: -19.1027
# Current minimum: -19.1027
# 0.07407407407407429
# 4.725099888888977

# %%
p=7
backend = Aer.get_backend('statevector_simulator')
quantum_instance = QuantumInstance(backend)
initial_state, _ = construct_initial_state(3,3)
qc = ansatz(9,p, operator)
initial_state.append(qc, range(3*3))
initial_state.parameter_bounds = [(-2*np.pi, 2*np.pi)]*initial_state.num_parameters
# print(transpile(initial_state, basis_gates = ['id', 'rx', 'ry', 'rz', 'cx']).draw(fold=200))
vqe = VQE(ansatz = initial_state, optimizer = Global_Optimizer(), include_custom=True, quantum_instance = quantum_instance, initial_point = next_point)
results = vqe.compute_minimum_eigenvalue(operator)
probs = Statevector(results.eigenstate).probabilities_dict()
p_s = 0
for string in x_s:
    p_s += probs[string] if string in probs else 0
print(p_s)
print(results.eigenvalue+offset)
next_point = results.optimal_point[0:p]+[0]+results.optimal_point[p:2*p]+[0]
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 0.3398
# Function value obtained: 0.6751
# Current minimum: 0.6751
# Iteration No: 2 started. Evaluating function at random point.
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 0.1101
# Function value obtained: 2.6669
# Current minimum: 0.6751
# Iteration No: 3 started. Evaluating function at random point.
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 0.1061
# Function value obtained: 0.5625
# Current minimum: 0.5625
# Iteration No: 4 started. Evaluating function at random point.
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 0.1056
# Function value obtained: -0.1833
# Current minimum: -0.1833
# Iteration No: 5 started. Evaluating function at random point.
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 0.1041
# Function value obtained: -2.3251
# Current minimum: -2.3251
# Iteration No: 6 started. Evaluating function at random point.
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 0.1045
# Function value obtained: 0.4966
# Current minimum: -2.3251
# Iteration No: 7 started. Evaluating function at random point.
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 0.1018
# Function value obtained: -0.2538
# Current minimum: -2.3251
# Iteration No: 8 started. Evaluating function at random point.
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 0.1033
# Function value obtained: 1.0847
# Current minimum: -2.3251
# Iteration No: 9 started. Evaluating function at random point.
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 0.1020
# Function value obtained: 1.6104
# Current minimum: -2.3251
# Iteration No: 10 started. Evaluating function at random point.
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 0.6353
# Function value obtained: -0.2374
# Current minimum: -2.3251
# Iteration No: 11 started. Searching for the next optimal point.
# Iteration No: 11 ended. Search finished for the next optimal point.
# Time taken: 0.3273
# Function value obtained: 0.9346
# Current minimum: -2.3251
# Iteration No: 12 started. Searching for the next optimal point.
# Iteration No: 12 ended. Search finished for the next optimal point.
# Time taken: 0.3575
# Function value obtained: -3.1772
# Current minimum: -3.1772
# Iteration No: 13 started. Searching for the next optimal point.
# Iteration No: 13 ended. Search finished for the next optimal point.
# Time taken: 0.4091
# Function value obtained: -4.6698
# Current minimum: -4.6698
# Iteration No: 14 started. Searching for the next optimal point.
# Iteration No: 14 ended. Search finished for the next optimal point.
# Time taken: 0.4276
# Function value obtained: -2.0193
# Current minimum: -4.6698
# Iteration No: 15 started. Searching for the next optimal point.
# Iteration No: 15 ended. Search finished for the next optimal point.
# Time taken: 0.3620
# Function value obtained: 2.3012
# Current minimum: -4.6698
# Iteration No: 16 started. Searching for the next optimal point.
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 0.3889
# Function value obtained: 2.3934
# Current minimum: -4.6698
# Iteration No: 17 started. Searching for the next optimal point.
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 0.4436
# Function value obtained: -0.8511
# Current minimum: -4.6698
# Iteration No: 18 started. Searching for the next optimal point.
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 0.4606
# Function value obtained: -0.2195
# Current minimum: -4.6698
# Iteration No: 19 started. Searching for the next optimal point.
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 0.4282
# Function value obtained: -0.7576
# Current minimum: -4.6698
# Iteration No: 20 started. Searching for the next optimal point.
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 0.5437
# Function value obtained: -1.1800
# Current minimum: -4.6698
# Iteration No: 21 started. Searching for the next optimal point.
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 0.4691
# Function value obtained: -2.8199
# Current minimum: -4.6698
# Iteration No: 22 started. Searching for the next optimal point.
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 0.5045
# Function value obtained: 1.5423
# Current minimum: -4.6698
# Iteration No: 23 started. Searching for the next optimal point.
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 0.4693
# Function value obtained: -0.3192
# Current minimum: -4.6698
# Iteration No: 24 started. Searching for the next optimal point.
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 0.5410
# Function value obtained: 0.8806
# Current minimum: -4.6698
# Iteration No: 25 started. Searching for the next optimal point.
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 0.5843
# Function value obtained: 0.3526
# Current minimum: -4.6698
# Iteration No: 26 started. Searching for the next optimal point.
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 0.9391
# Function value obtained: -0.2666
# Current minimum: -4.6698
# Iteration No: 27 started. Searching for the next optimal point.
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 0.6118
# Function value obtained: -0.0174
# Current minimum: -4.6698
# Iteration No: 28 started. Searching for the next optimal point.
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 0.6380
# Function value obtained: -0.5208
# Current minimum: -4.6698
# Iteration No: 29 started. Searching for the next optimal point.
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 0.6236
# Function value obtained: 1.2321
# Current minimum: -4.6698
# Iteration No: 30 started. Searching for the next optimal point.
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 0.7212
# Function value obtained: -0.3005
# Current minimum: -4.6698
# Iteration No: 31 started. Searching for the next optimal point.
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 0.5616
# Function value obtained: -0.5687
# Current minimum: -4.6698
# Iteration No: 32 started. Searching for the next optimal point.
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 0.7051
# Function value obtained: -1.2446
# Current minimum: -4.6698
# Iteration No: 33 started. Searching for the next optimal point.
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 0.7286
# Function value obtained: 6.6975
# Current minimum: -4.6698
# Iteration No: 34 started. Searching for the next optimal point.
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 0.7513
# Function value obtained: -0.8397
# Current minimum: -4.6698
# Iteration No: 35 started. Searching for the next optimal point.
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 0.7619
# Function value obtained: 1.6370
# Current minimum: -4.6698
# Iteration No: 36 started. Searching for the next optimal point.
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 0.9024
# Function value obtained: -0.1014
# Current minimum: -4.6698
# Iteration No: 37 started. Searching for the next optimal point.
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 0.6057
# Function value obtained: 0.7544
# Current minimum: -4.6698
# Iteration No: 38 started. Searching for the next optimal point.
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 0.8239
# Function value obtained: 0.1870
# Current minimum: -4.6698
# Iteration No: 39 started. Searching for the next optimal point.
# Iteration No: 39 ended. Search finished for the next optimal point.
# Time taken: 0.8234
# Function value obtained: 0.1131
# Current minimum: -4.6698
# Iteration No: 40 started. Searching for the next optimal point.
# Iteration No: 40 ended. Search finished for the next optimal point.
# Time taken: 0.7492
# Function value obtained: 0.6418
# Current minimum: -4.6698
# Iteration No: 41 started. Searching for the next optimal point.
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 0.8056
# Function value obtained: -1.8034
# Current minimum: -4.6698
# Iteration No: 42 started. Searching for the next optimal point.
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 0.8739
# Function value obtained: -1.7201
# Current minimum: -4.6698
# Iteration No: 43 started. Searching for the next optimal point.
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 1.1950
# Function value obtained: -1.3864
# Current minimum: -4.6698
# Iteration No: 44 started. Searching for the next optimal point.
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 1.0763
# Function value obtained: 0.7874
# Current minimum: -4.6698
# Iteration No: 45 started. Searching for the next optimal point.
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 0.8473
# Function value obtained: 0.4436
# Current minimum: -4.6698
# Iteration No: 46 started. Searching for the next optimal point.
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 1.0402
# Function value obtained: -0.6085
# Current minimum: -4.6698
# Iteration No: 47 started. Searching for the next optimal point.
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 0.7698
# Function value obtained: 1.0529
# Current minimum: -4.6698
# Iteration No: 48 started. Searching for the next optimal point.
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 0.8102
# Function value obtained: -1.6807
# Current minimum: -4.6698
# Iteration No: 49 started. Searching for the next optimal point.
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 0.9308
# Function value obtained: 1.6092
# Current minimum: -4.6698
# Iteration No: 50 started. Searching for the next optimal point.
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 1.0549
# Function value obtained: -0.5956
# Current minimum: -4.6698
# Iteration No: 51 started. Searching for the next optimal point.
# Iteration No: 51 ended. Search finished for the next optimal point.
# Time taken: 0.8230
# Function value obtained: -1.0318
# Current minimum: -4.6698
# Iteration No: 52 started. Searching for the next optimal point.
# Iteration No: 52 ended. Search finished for the next optimal point.
# Time taken: 0.9218
# Function value obtained: 0.4222
# Current minimum: -4.6698
# Iteration No: 53 started. Searching for the next optimal point.
# Iteration No: 53 ended. Search finished for the next optimal point.
# Time taken: 0.9952
# Function value obtained: 0.7353
# Current minimum: -4.6698
# Iteration No: 54 started. Searching for the next optimal point.
# Iteration No: 54 ended. Search finished for the next optimal point.
# Time taken: 0.8601
# Function value obtained: 1.4429
# Current minimum: -4.6698
# Iteration No: 55 started. Searching for the next optimal point.
# Iteration No: 55 ended. Search finished for the next optimal point.
# Time taken: 0.9005
# Function value obtained: 0.7395
# Current minimum: -4.6698
# Iteration No: 56 started. Searching for the next optimal point.
# Iteration No: 56 ended. Search finished for the next optimal point.
# Time taken: 0.8288
# Function value obtained: 7.0577
# Current minimum: -4.6698
# Iteration No: 57 started. Searching for the next optimal point.
# Iteration No: 57 ended. Search finished for the next optimal point.
# Time taken: 1.0384
# Function value obtained: -2.9855
# Current minimum: -4.6698
# Iteration No: 58 started. Searching for the next optimal point.
# Iteration No: 58 ended. Search finished for the next optimal point.
# Time taken: 0.7463
# Function value obtained: 0.9258
# Current minimum: -4.6698
# Iteration No: 59 started. Searching for the next optimal point.
# Iteration No: 59 ended. Search finished for the next optimal point.
# Time taken: 0.7605
# Function value obtained: 0.5920
# Current minimum: -4.6698
# Iteration No: 60 started. Searching for the next optimal point.
# Iteration No: 60 ended. Search finished for the next optimal point.
# Time taken: 1.0514
# Function value obtained: -0.1223
# Current minimum: -4.6698
# Iteration No: 61 started. Searching for the next optimal point.
# Iteration No: 61 ended. Search finished for the next optimal point.
# Time taken: 0.8294
# Function value obtained: 0.5828
# Current minimum: -4.6698
# Iteration No: 62 started. Searching for the next optimal point.
# Iteration No: 62 ended. Search finished for the next optimal point.
# Time taken: 0.7871
# Function value obtained: 0.7545
# Current minimum: -4.6698
# Iteration No: 63 started. Searching for the next optimal point.
# Iteration No: 63 ended. Search finished for the next optimal point.
# Time taken: 1.0222
# Function value obtained: 2.0954
# Current minimum: -4.6698
# Iteration No: 64 started. Searching for the next optimal point.
# Iteration No: 64 ended. Search finished for the next optimal point.
# Time taken: 0.8304
# Function value obtained: 0.4935
# Current minimum: -4.6698
# Iteration No: 65 started. Searching for the next optimal point.
# Iteration No: 65 ended. Search finished for the next optimal point.
# Time taken: 0.8426
# Function value obtained: -0.3691
# Current minimum: -4.6698
# Iteration No: 66 started. Searching for the next optimal point.
# Iteration No: 66 ended. Search finished for the next optimal point.
# Time taken: 0.8922
# Function value obtained: 1.0736
# Current minimum: -4.6698
# Iteration No: 67 started. Searching for the next optimal point.
# Iteration No: 67 ended. Search finished for the next optimal point.
# Time taken: 0.7931
# Function value obtained: -0.9262
# Current minimum: -4.6698
# Iteration No: 68 started. Searching for the next optimal point.
# Iteration No: 68 ended. Search finished for the next optimal point.
# Time taken: 0.8675
# Function value obtained: 0.8629
# Current minimum: -4.6698
# Iteration No: 69 started. Searching for the next optimal point.
# Iteration No: 69 ended. Search finished for the next optimal point.
# Time taken: 0.9570
# Function value obtained: 0.6165
# Current minimum: -4.6698
# Iteration No: 70 started. Searching for the next optimal point.
# Iteration No: 70 ended. Search finished for the next optimal point.
# Time taken: 0.9879
# Function value obtained: -0.1074
# Current minimum: -4.6698
# Iteration No: 71 started. Searching for the next optimal point.
# Iteration No: 71 ended. Search finished for the next optimal point.
# Time taken: 1.1240
# Function value obtained: -0.3035
# Current minimum: -4.6698
# Iteration No: 72 started. Searching for the next optimal point.
# Iteration No: 72 ended. Search finished for the next optimal point.
# Time taken: 0.8813
# Function value obtained: -1.1107
# Current minimum: -4.6698
# Iteration No: 73 started. Searching for the next optimal point.
# Iteration No: 73 ended. Search finished for the next optimal point.
# Time taken: 0.8349
# Function value obtained: -1.2474
# Current minimum: -4.6698
# Iteration No: 74 started. Searching for the next optimal point.
# Iteration No: 74 ended. Search finished for the next optimal point.
# Time taken: 1.3849
# Function value obtained: 2.3973
# Current minimum: -4.6698
# Iteration No: 75 started. Searching for the next optimal point.
# Iteration No: 75 ended. Search finished for the next optimal point.
# Time taken: 0.7679
# Function value obtained: -0.5229
# Current minimum: -4.6698
# Iteration No: 76 started. Searching for the next optimal point.
# Iteration No: 76 ended. Search finished for the next optimal point.
# Time taken: 1.2311
# Function value obtained: -0.0495
# Current minimum: -4.6698
# Iteration No: 77 started. Searching for the next optimal point.
# Iteration No: 77 ended. Search finished for the next optimal point.
# Time taken: 1.3700
# Function value obtained: 0.8302
# Current minimum: -4.6698
# Iteration No: 78 started. Searching for the next optimal point.
# Iteration No: 78 ended. Search finished for the next optimal point.
# Time taken: 1.3268
# Function value obtained: -0.6881
# Current minimum: -4.6698
# Iteration No: 79 started. Searching for the next optimal point.
# Iteration No: 79 ended. Search finished for the next optimal point.
# Time taken: 1.0275
# Function value obtained: 0.8289
# Current minimum: -4.6698
# Iteration No: 80 started. Searching for the next optimal point.
# Iteration No: 80 ended. Search finished for the next optimal point.
# Time taken: 1.3471
# Function value obtained: 3.4580
# Current minimum: -4.6698
# Iteration No: 81 started. Searching for the next optimal point.
# Iteration No: 81 ended. Search finished for the next optimal point.
# Time taken: 1.1755
# Function value obtained: 1.2351
# Current minimum: -4.6698
# Iteration No: 82 started. Searching for the next optimal point.
# Iteration No: 82 ended. Search finished for the next optimal point.
# Time taken: 1.2923
# Function value obtained: 0.1046
# Current minimum: -4.6698
# Iteration No: 83 started. Searching for the next optimal point.
# Iteration No: 83 ended. Search finished for the next optimal point.
# Time taken: 1.6824
# Function value obtained: -0.2633
# Current minimum: -4.6698
# Iteration No: 84 started. Searching for the next optimal point.
# Iteration No: 84 ended. Search finished for the next optimal point.
# Time taken: 1.2772
# Function value obtained: 1.8906
# Current minimum: -4.6698
# Iteration No: 85 started. Searching for the next optimal point.
# Iteration No: 85 ended. Search finished for the next optimal point.
# Time taken: 1.2596
# Function value obtained: -0.3316
# Current minimum: -4.6698
# Iteration No: 86 started. Searching for the next optimal point.
# Iteration No: 86 ended. Search finished for the next optimal point.
# Time taken: 1.2720
# Function value obtained: 0.4787
# Current minimum: -4.6698
# Iteration No: 87 started. Searching for the next optimal point.
# Iteration No: 87 ended. Search finished for the next optimal point.
# Time taken: 1.3386
# Function value obtained: 0.5413
# Current minimum: -4.6698
# Iteration No: 88 started. Searching for the next optimal point.
# Iteration No: 88 ended. Search finished for the next optimal point.
# Time taken: 1.2881
# Function value obtained: -0.5669
# Current minimum: -4.6698
# Iteration No: 89 started. Searching for the next optimal point.
# Iteration No: 89 ended. Search finished for the next optimal point.
# Time taken: 1.3234
# Function value obtained: -1.3757
# Current minimum: -4.6698
# Iteration No: 90 started. Searching for the next optimal point.
# Iteration No: 90 ended. Search finished for the next optimal point.
# Time taken: 1.3962
# Function value obtained: 1.0148
# Current minimum: -4.6698
# Iteration No: 91 started. Searching for the next optimal point.
# Iteration No: 91 ended. Search finished for the next optimal point.
# Time taken: 1.4466
# Function value obtained: -0.7283
# Current minimum: -4.6698
# Iteration No: 92 started. Searching for the next optimal point.
# Iteration No: 92 ended. Search finished for the next optimal point.
# Time taken: 1.7819
# Function value obtained: 0.6345
# Current minimum: -4.6698
# Iteration No: 93 started. Searching for the next optimal point.
# Iteration No: 93 ended. Search finished for the next optimal point.
# Time taken: 1.7391
# Function value obtained: 0.5773
# Current minimum: -4.6698
# Iteration No: 94 started. Searching for the next optimal point.
# Iteration No: 94 ended. Search finished for the next optimal point.
# Time taken: 1.8595
# Function value obtained: -4.7759
# Current minimum: -4.7759
# Iteration No: 95 started. Searching for the next optimal point.
# Iteration No: 95 ended. Search finished for the next optimal point.
# Time taken: 1.8540
# Function value obtained: 0.1570
# Current minimum: -4.7759
# Iteration No: 96 started. Searching for the next optimal point.
# Iteration No: 96 ended. Search finished for the next optimal point.
# Time taken: 1.7610
# Function value obtained: 1.5250
# Current minimum: -4.7759
# Iteration No: 97 started. Searching for the next optimal point.
# Iteration No: 97 ended. Search finished for the next optimal point.
# Time taken: 1.8213
# Function value obtained: -0.1993
# Current minimum: -4.7759
# Iteration No: 98 started. Searching for the next optimal point.
# Iteration No: 98 ended. Search finished for the next optimal point.
# Time taken: 1.5618
# Function value obtained: 0.1039
# Current minimum: -4.7759
# Iteration No: 99 started. Searching for the next optimal point.
# Iteration No: 99 ended. Search finished for the next optimal point.
# Time taken: 1.7530
# Function value obtained: -3.3554
# Current minimum: -4.7759
# Iteration No: 100 started. Searching for the next optimal point.
# Iteration No: 100 ended. Search finished for the next optimal point.
# Time taken: 1.2329
# Function value obtained: 3.3738
# Current minimum: -4.7759
# 0.0075324152983947705
# 19.05190851132111

# %%
p=8
backend = Aer.get_backend('statevector_simulator')
quantum_instance = QuantumInstance(backend)
initial_state, _ = construct_initial_state(3,3)
qc = ansatz(9,p, operator)
initial_state.append(qc, range(3*3))
initial_state.parameter_bounds = [(-2*np.pi, 2*np.pi)]*initial_state.num_parameters
# print(transpile(initial_state, basis_gates = ['id', 'rx', 'ry', 'rz', 'cx']).draw(fold=200))
vqe = VQE(ansatz = initial_state, optimizer = Global_Optimizer(n_calls=200), include_custom=True, quantum_instance = quantum_instance, initial_point = next_point)
results = vqe.compute_minimum_eigenvalue(operator)
probs = Statevector(results.eigenstate).probabilities_dict()
p_s = 0
for string in x_s:
    p_s += probs[string] if string in probs else 0
print(p_s)
print(results.eigenvalue+offset)
next_point = results.optimal_point[0:p]+[0]+results.optimal_point[p:2*p]+[0]
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 0.6862
# Function value obtained: 0.3065
# Current minimum: 0.3065
# Iteration No: 2 started. Evaluating function at random point.
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 0.1143
# Function value obtained: 0.3320
# Current minimum: 0.3065
# Iteration No: 3 started. Evaluating function at random point.
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 0.1146
# Function value obtained: 0.8632
# Current minimum: 0.3065
# Iteration No: 4 started. Evaluating function at random point.
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 0.1164
# Function value obtained: -0.9614
# Current minimum: -0.9614
# Iteration No: 5 started. Evaluating function at random point.
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 0.1157
# Function value obtained: -0.6041
# Current minimum: -0.9614
# Iteration No: 6 started. Evaluating function at random point.
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 0.1222
# Function value obtained: -0.6313
# Current minimum: -0.9614
# Iteration No: 7 started. Evaluating function at random point.
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 0.1165
# Function value obtained: 0.0662
# Current minimum: -0.9614
# Iteration No: 8 started. Evaluating function at random point.
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 0.1300
# Function value obtained: -0.7779
# Current minimum: -0.9614
# Iteration No: 9 started. Evaluating function at random point.
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 0.1198
# Function value obtained: -0.5332
# Current minimum: -0.9614
# Iteration No: 10 started. Evaluating function at random point.
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 0.4576
# Function value obtained: -0.2920
# Current minimum: -0.9614
# Iteration No: 11 started. Searching for the next optimal point.
# Iteration No: 11 ended. Search finished for the next optimal point.
# Time taken: 0.8431
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 12 started. Searching for the next optimal point.
# Iteration No: 12 ended. Search finished for the next optimal point.
# Time taken: 0.3979
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 13 started. Searching for the next optimal point.
# Iteration No: 13 ended. Search finished for the next optimal point.
# Time taken: 0.3688
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 14 started. Searching for the next optimal point.
# Iteration No: 14 ended. Search finished for the next optimal point.
# Time taken: 0.4652
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 15 started. Searching for the next optimal point.
# Iteration No: 15 ended. Search finished for the next optimal point.
# Time taken: 0.4294
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 16 started. Searching for the next optimal point.
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 0.3434
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 17 started. Searching for the next optimal point.
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 0.3850
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 18 started. Searching for the next optimal point.
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 0.4642
# Function value obtained: -0.6763
# Current minimum: -19.1027
# Iteration No: 19 started. Searching for the next optimal point.
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 0.4528
# Function value obtained: -0.1883
# Current minimum: -19.1027
# Iteration No: 20 started. Searching for the next optimal point.
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 0.5406
# Function value obtained: -6.0154
# Current minimum: -19.1027
# Iteration No: 21 started. Searching for the next optimal point.
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 0.3851
# Function value obtained: -2.7806
# Current minimum: -19.1027
# Iteration No: 22 started. Searching for the next optimal point.
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 0.4625
# Function value obtained: -5.7864
# Current minimum: -19.1027
# Iteration No: 23 started. Searching for the next optimal point.
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 0.4738
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 24 started. Searching for the next optimal point.
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 0.4900
# Function value obtained: -0.7091
# Current minimum: -19.1027
# Iteration No: 25 started. Searching for the next optimal point.
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 0.3551
# Function value obtained: 0.2027
# Current minimum: -19.1027
# Iteration No: 26 started. Searching for the next optimal point.
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 0.5011
# Function value obtained: 0.3940
# Current minimum: -19.1027
# Iteration No: 27 started. Searching for the next optimal point.
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 0.7180
# Function value obtained: 0.1261
# Current minimum: -19.1027
# Iteration No: 28 started. Searching for the next optimal point.
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 0.4247
# Function value obtained: 0.5163
# Current minimum: -19.1027
# Iteration No: 29 started. Searching for the next optimal point.
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 0.5808
# Function value obtained: 1.7217
# Current minimum: -19.1027
# Iteration No: 30 started. Searching for the next optimal point.
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 0.4034
# Function value obtained: -6.6900
# Current minimum: -19.1027
# Iteration No: 31 started. Searching for the next optimal point.
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 0.4795
# Function value obtained: -1.1907
# Current minimum: -19.1027
# Iteration No: 32 started. Searching for the next optimal point.
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 0.6123
# Function value obtained: -0.0268
# Current minimum: -19.1027
# Iteration No: 33 started. Searching for the next optimal point.
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 0.6402
# Function value obtained: -19.1027
# Current minimum: -19.1027
# Iteration No: 34 started. Searching for the next optimal point.
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 0.5734
# Function value obtained: 0.5143
# Current minimum: -19.1027
# Iteration No: 35 started. Searching for the next optimal point.
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 0.5453
# Function value obtained: -0.4532
# Current minimum: -19.1027
# Iteration No: 36 started. Searching for the next optimal point.
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 0.5071
# Function value obtained: 1.2415
# Current minimum: -19.1027
# Iteration No: 37 started. Searching for the next optimal point.
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 0.5407
# Function value obtained: 0.0864
# Current minimum: -19.1027
# Iteration No: 38 started. Searching for the next optimal point.
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 0.6895
# Function value obtained: -0.0922
# Current minimum: -19.1027
# Iteration No: 39 started. Searching for the next optimal point.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-740-7cca67a5fb14> in <module>
#       8 # print(transpile(initial_state, basis_gates = ['id', 'rx', 'ry', 'rz', 'cx']).draw(fold=200))
#       9 vqe = VQE(ansatz = initial_state, optimizer = Global_Optimizer(n_calls=200), include_custom=True, quantum_instance = quantum_instance, initial_point = next_point)
# ---> 10 results = vqe.compute_minimum_eigenvalue(operator)
#      11 probs = Statevector(results.eigenstate).probabilities_dict()
#      12 p_s = 0
#
# ~/anaconda3/envs/ox/lib/python3.9/site-packages/qiskit/algorithms/minimum_eigen_solvers/vqe.py in compute_minimum_eigenvalue(self, operator, aux_operators)
#     410         if not self._expect_op:
#     411             self._expect_op = self.construct_expectation(self._ansatz_params, operator)
# --> 412         vqresult = self.find_minimum(initial_point=self.initial_point,
#     413                                      ansatz=self.ansatz,
#     414                                      cost_fn=self._energy_evaluation,
#
# ~/anaconda3/envs/ox/lib/python3.9/site-packages/qiskit/algorithms/variational_algorithm.py in find_minimum(self, initial_point, ansatz, cost_fn, optimizer, gradient_fn)
#     214
#     215         logger.info('Starting optimizer.\nbounds=%s\ninitial point=%s', bounds, initial_point)
# --> 216         opt_params, opt_val, num_optimizer_evals = optimizer.optimize(nparms,
#     217                                                                       cost_fn,
#     218                                                                       variable_bounds=bounds,
#
# <ipython-input-738-fdb8782fc345> in optimize(self, num_vars, objective_function, gradient_function, variable_bounds, initial_point)
#     120         minimizer_kwargs = {"method": "slsqp", "jac":gradient_function, "tol":self._tol, "bounds":variable_bounds}
#     121 #         res = basinhopping(objective_function, initial_point, niter=100, T=1.0, stepsize=0.05*np.pi, minimizer_kwargs=None, take_step=None, accept_test=None, callback=None, interval=50, disp=False, niter_success=None, seed=None)
# --> 122         res = gp_minimize(objective_function,
#     123                   variable_bounds,      # the bounds on each dimension of x
#     124                   acq_func="gp_hedge",      # the acquisition function
#
# ~/anaconda3/envs/ox/lib/python3.9/site-packages/skopt/optimizer/gp.py in gp_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, noise, n_jobs, model_queue_size)
#     257             noise=noise)
#     258
# --> 259     return base_minimize(
#     260         func, space, base_estimator=base_estimator,
#     261         acq_func=acq_func,
#
# ~/anaconda3/envs/ox/lib/python3.9/site-packages/skopt/optimizer/base.py in base_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, n_jobs, model_queue_size)
#     300         next_x = optimizer.ask()
#     301         next_y = func(next_x)
# --> 302         result = optimizer.tell(next_x, next_y)
#     303         result.specs = specs
#     304         if eval_callbacks(callbacks, result):
#
# ~/anaconda3/envs/ox/lib/python3.9/site-packages/skopt/optimizer/optimizer.py in tell(self, x, y, fit)
#     491                 y[1] = log(y[1])
#     492
# --> 493         return self._tell(x, y, fit=fit)
#     494
#     495     def _tell(self, x, y, fit=True):
#
# ~/anaconda3/envs/ox/lib/python3.9/site-packages/skopt/optimizer/optimizer.py in _tell(self, x, y, fit)
#     572                     with warnings.catch_warnings():
#     573                         warnings.simplefilter("ignore")
# --> 574                         results = Parallel(n_jobs=self.n_jobs)(
#     575                             delayed(fmin_l_bfgs_b)(
#     576                                 gaussian_acquisition_1D, x,
#
# ~/anaconda3/envs/ox/lib/python3.9/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1052
#    1053             with self._backend.retrieval_context():
# -> 1054                 self.retrieve()
#    1055             # Make sure that we get a last message telling us we are done
#    1056             elapsed_time = time.time() - self._start_time
#
# ~/anaconda3/envs/ox/lib/python3.9/site-packages/joblib/parallel.py in retrieve(self)
#     931             try:
#     932                 if getattr(self._backend, 'supports_timeout', False):
# --> 933                     self._output.extend(job.get(timeout=self.timeout))
#     934                 else:
#     935                     self._output.extend(job.get())
#
# ~/anaconda3/envs/ox/lib/python3.9/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# ~/anaconda3/envs/ox/lib/python3.9/concurrent/futures/_base.py in result(self, timeout)
#     438                     return self.__get_result()
#     439
# --> 440                 self._condition.wait(timeout)
#     441
#     442                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# ~/anaconda3/envs/ox/lib/python3.9/threading.py in wait(self, timeout)
#     310         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311             if timeout is None:
# --> 312                 waiter.acquire()
#     313                 gotit = True
#     314             else:
#
# KeyboardInterrupt:
